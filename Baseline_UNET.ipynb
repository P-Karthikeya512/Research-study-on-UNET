# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Modifications_in_skip_connections_of_UNET_UNET-/blob/main/Baseline_UNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

prabhalakarthikeya_isic2018_task1_path = kagglehub.dataset_download('prabhalakarthikeya/isic2018-task1')

print('Data source import complete.')

# %%
import tensorflow as tf

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy("mixed_float16")

# %%
import os
import glob
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split
dataset_path = "/kaggle/input/datasets/prabhalakarthikeya/isic2018-task1/Unet_implementation"

print(os.listdir(dataset_path))
TRAIN_IMAGES = dataset_path + "/images/train"
TRAIN_MASKS  = dataset_path + "/masks/train"

VAL_IMAGES   = dataset_path + "/images/val"
VAL_MASKS    = dataset_path + "/masks/val"

TEST_IMAGES  = dataset_path + "/images/test"
TEST_MASKS   = dataset_path + "/masks/test"

print("Train Images :", len(os.listdir(TRAIN_IMAGES)))
print("Train Masks  :", len(os.listdir(TRAIN_MASKS)))

print("Val Images   :", len(os.listdir(VAL_IMAGES)))
print("Val Masks    :", len(os.listdir(VAL_MASKS)))

print("Test Images  :", len(os.listdir(TEST_IMAGES)))
print("Test Masks   :", len(os.listdir(TEST_MASKS)))

IMG_HEIGHT = 128
IMG_WIDTH = 128

BATCH_SIZE = 32
EPOCHS = 50
AUTOTUNE = tf.data.AUTOTUNE
# Out:
# ['images', 'masks']
# Train Images : 2596
# Train Masks  : 2596
# Val Images   : 102
# Val Masks    : 102
# Test Images  : 1002
# Test Masks   : 1002

# %%
image_files = sorted([
    f for f in os.listdir(TRAIN_IMAGES)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
])

mask_files = sorted([
    f for f in os.listdir(TRAIN_MASKS)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
])

print(image_files[:5])
print(mask_files[:5])

img_name = image_files[0]
mask_name = mask_files[0]

image = cv2.cvtColor(
    cv2.imread(os.path.join(TRAIN_IMAGES, img_name)),
    cv2.COLOR_BGR2RGB
)

mask = cv2.imread(
    os.path.join(TRAIN_MASKS, mask_name),
    cv2.IMREAD_GRAYSCALE
)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(image)
plt.title(img_name)
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(mask, cmap="gray")
plt.title(mask_name)
plt.axis("off")

plt.show()
# Out:
# ['ISIC_0000000.jpg', 'ISIC_0000001.jpg', 'ISIC_0000003.jpg', 'ISIC_0000004.jpg', 'ISIC_0000006.jpg']
# ['ISIC_0000000_segmentation.png', 'ISIC_0000001_segmentation.png', 'ISIC_0000003_segmentation.png', 'ISIC_0000004_segmentation.png', 'ISIC_0000006_segmentation.png']

# %%
def create_pairs(image_dir, mask_dir):
    image_paths = sorted(
        glob.glob(os.path.join(image_dir, "*.jpg")) +
        glob.glob(os.path.join(image_dir, "*.jpeg")) +
        glob.glob(os.path.join(image_dir, "*.png"))
    )

    pairs = []
    for img_path in image_paths:
        image_name = os.path.basename(img_path)
        stem, _ = os.path.splitext(image_name)

        # ISIC 2018 masks usually follow: <image_id>_segmentation.png
        mask_path_png = os.path.join(mask_dir, stem + "_segmentation.png")
        mask_path_jpg = os.path.join(mask_dir, stem + "_segmentation.jpg")
        mask_path_jpeg = os.path.join(mask_dir, stem + "_segmentation.jpeg")

        if os.path.exists(mask_path_png):
            pairs.append((img_path, mask_path_png))
        elif os.path.exists(mask_path_jpg):
            pairs.append((img_path, mask_path_jpg))
        elif os.path.exists(mask_path_jpeg):
            pairs.append((img_path, mask_path_jpeg))

    return pairs

train_pairs = create_pairs(TRAIN_IMAGES, TRAIN_MASKS)
val_pairs   = create_pairs(VAL_IMAGES, VAL_MASKS)
test_pairs  = create_pairs(TEST_IMAGES, TEST_MASKS)

print("\nPaired samples:")
print("Train pairs:", len(train_pairs))
print("Val pairs  :", len(val_pairs))
print("Test pairs :", len(test_pairs))

print("First train pair:", train_pairs[0] if len(train_pairs) > 0 else "No pairs found")
# Out:
# Paired samples:
# Train pairs: 2594
# Val pairs  : 100
# Test pairs : 1000
# First train pair: ('/kaggle/input/datasets/prabhalakarthikeya/isic2018-task1/Unet_implementation/images/train/ISIC_0000000.jpg', '/kaggle/input/datasets/prabhalakarthikeya/isic2018-task1/Unet_implementation/masks/train/ISIC_0000000_segmentation.png')

# %%
# =========================
# Read functions
# =========================
def read_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (IMG_HEIGHT, IMG_WIDTH))
    image = tf.cast(image, tf.float32) / 255.0
    return image

def read_mask(path):
    mask = tf.io.read_file(path)
    # ISIC masks are commonly PNG; if your masks are JPG, decode_jpeg can be used instead
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, (IMG_HEIGHT, IMG_WIDTH), method="nearest")
    mask = tf.cast(mask, tf.float32) / 255.0
    mask = tf.where(mask > 0.5, 1.0, 0.0)
    return mask
def load_data(image_path, mask_path):
    image = read_image(image_path)
    mask = read_mask(mask_path)
    return image, mask

# =========================
# Quick sanity check
# =========================
if len(train_pairs) > 0:
    image = read_image(train_pairs[0][0])
    mask = read_mask(train_pairs[0][1])
    print("\nSingle sample shapes:")
    print("Image:", image.shape)
    print("Mask :", mask.shape)

# =========================
# Convert pairs to path lists
# =========================
train_images = [x[0] for x in train_pairs]
train_masks  = [x[1] for x in train_pairs]

val_images = [x[0] for x in val_pairs]
val_masks  = [x[1] for x in val_pairs]

test_images = [x[0] for x in test_pairs]
test_masks  = [x[1] for x in test_pairs]
# Out:
# Single sample shapes:
# Image: (128, 128, 3)
# Mask : (128, 128, 1)

# %%
# =========================
# Augmentation
# =========================
def augment(image, mask):
    # Horizontal flip
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    # Vertical flip
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    # Random 90-degree rotation
    k = tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    # Image-only augmentations
    image = tf.image.random_brightness(image, 0.1)
    image = tf.image.random_contrast(image, 0.9, 1.1)
    return image, mask

# %%
def create_dataset(image_paths, mask_paths, training=False):
    dataset = tf.data.Dataset.from_tensor_slices(
        (image_paths, mask_paths)
    )
    dataset = dataset.map(
        load_data,
        num_parallel_calls=tf.data.AUTOTUNE
    )
    # Cache after loading/resizing
    dataset = dataset.cache()

    if training:
        dataset = dataset.shuffle(len(image_paths))
        dataset = dataset.map(
            augment,
            num_parallel_calls=tf.data.AUTOTUNE
        )

    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_ds = create_dataset(train_images, train_masks, training=True)
val_ds   = create_dataset(val_images, val_masks, training=False)
test_ds  = create_dataset(test_images, test_masks, training=False)

# =========================
# Verify dataset pipeline
# =========================
for image, mask in train_ds.take(1):
    print("\nBatched shapes:")
    print("Images:", image.shape)
    print("Masks :", mask.shape)

    plt.figure(figsize=(12, 12))
    for i in range(min(4, image.shape[0])):
        plt.subplot(4, 2, 2 * i + 1)
        plt.imshow(image[i])
        plt.axis("off")
        plt.title("Image")

        plt.subplot(4, 2, 2 * i + 2)
        plt.imshow(tf.squeeze(mask[i]), cmap="gray")
        plt.axis("off")
        plt.title("Mask")

    plt.tight_layout()
    plt.show()

# =========================
# Optional: final dataset stats
# =========================
print("\nFinal dataset sizes:")
print("Train:", len(train_images))
print("Val  :", len(val_images))
print("Test :", len(test_images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.06759313..0.7483228].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.04652974..0.8086026].
# Batched shapes:
# Images: (32, 128, 128, 3)
# Masks : (32, 128, 128, 1)
# Final dataset sizes:
# Train: 2594
# Val  : 100
# Test : 1000

# %% [markdown]
# ## Metrics and Loss Function

# %%
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)

    intersection = tf.reduce_sum(y_true_f * y_pred_f)

    return (2. * intersection + smooth) / (
        tf.reduce_sum(y_true_f) +
        tf.reduce_sum(y_pred_f) +
        smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)

    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = (
        tf.reduce_sum(y_true_f)
        + tf.reduce_sum(y_pred_f)
        - intersection
    )

    return (intersection + smooth) / (union + smooth)

# %% [markdown]
# ## Building UNET Blocks

# %%
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p

def up_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x

# %% [markdown]
# ## Build UNET

# %%
def build_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(shape=input_shape)

    s1, p1 = down_block(inputs, 32)
    s2, p2 = down_block(p1, 64)
    s3, p3 = down_block(p2, 128)
    s4, p4 = down_block(p3, 256)

    bottleneck = conv_block(p4, 512)

    u1 = up_block(bottleneck, s4, 256)
    u2 = up_block(u1, s3, 128)
    u3 = up_block(u2, s2, 64)
    u4 = up_block(u3, s1, 32)

    outputs = layers.Conv2D(1,1,activation="sigmoid",dtype="float32")(u4)

    model = Model(inputs, outputs, name="UNet_Binary")
    return model

strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    model = build_unet()

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-4),
        loss=dice_loss,
        metrics=["accuracy", dice_coef, iou_coef]
    )

model.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Model: "UNet_Binary"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 128, 128,  │        896 │ input_layer_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_76[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_72 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 128, 128,  │      9,248 │ re_lu_72[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_77[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_73 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 64, 64,    │          0 │ re_lu_73[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 64, 64,    │          0 │ max_pooling2d_16… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 64, 64,    │     18,496 │ dropout_32[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_78[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_74 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_79 (Conv2D)  │ (None, 64, 64,    │     36,928 │ re_lu_74[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_79[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_75 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_17    │ (None, 32, 32,    │          0 │ re_lu_75[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 32, 32,    │          0 │ max_pooling2d_17… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 32, 32,    │     73,856 │ dropout_33[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_80[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_76 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 32, 32,    │    147,584 │ re_lu_76[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_81[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_77 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_18    │ (None, 16, 16,    │          0 │ re_lu_77[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 16, 16,    │          0 │ max_pooling2d_18… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 16, 16,    │    295,168 │ dropout_34[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_82[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_78 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 16, 16,    │    590,080 │ re_lu_78[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_83[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_79 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_19    │ (None, 8, 8, 256) │          0 │ re_lu_79[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 8, 8, 256) │          0 │ max_pooling2d_19… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 8, 8, 512) │  1,180,160 │ dropout_35[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_84[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_80 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 8, 8, 512) │  2,359,808 │ re_lu_80[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_81 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_16 │ (None, 16, 16,    │    524,544 │ re_lu_81[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ re_lu_79[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_36          │ (None, 16, 16,    │          0 │ concatenate_16[0… │
# │ (Dropout)           │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 16, 16,    │  1,179,904 │ dropout_36[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_86[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_82 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 16, 16,    │    590,080 │ re_lu_82[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_83 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_17 │ (None, 32, 32,    │    131,200 │ re_lu_83[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ re_lu_77[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_37          │ (None, 32, 32,    │          0 │ concatenate_17[0… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 32, 32,    │    295,040 │ dropout_37[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_84 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 32, 32,    │    147,584 │ re_lu_84[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_89[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_85 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_18 │ (None, 64, 64,    │     32,832 │ re_lu_85[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ re_lu_75[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_38          │ (None, 64, 64,    │          0 │ concatenate_18[0… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 64, 64,    │     73,792 │ dropout_38[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_86 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 64, 64,    │     36,928 │ re_lu_86[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_87 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_19 │ (None, 128, 128,  │      8,224 │ re_lu_87[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ re_lu_73[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 128, 128,  │          0 │ concatenate_19[0… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 128, 128,  │     18,464 │ dropout_39[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_88 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 128, 128,  │      9,248 │ re_lu_88[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_89 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 128, 128,  │         33 │ re_lu_89[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,771,873 (29.65 MB)
#  Trainable params: 7,765,985 (29.62 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %% [markdown]
# ## Callbacks and Training

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/50
# INFO:tensorflow:Collective all_reduce tensors: 82 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.6248 - dice_coef: 0.4121 - iou_coef: 0.2644 - loss: 1.1758
# Epoch 1: val_dice_coef improved from None to 0.41163, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 63s 372ms/step - accuracy: 0.7382 - dice_coef: 0.4876 - iou_coef: 0.3291 - loss: 1.0287 - val_accuracy: 0.8137 - val_dice_coef: 0.4116 - val_iou_coef: 0.2660 - val_loss: 1.1609 - learning_rate: 1.0000e-04
# Epoch 2/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8688 - dice_coef: 0.6231 - iou_coef: 0.4564 - loss: 0.7536
# Epoch 2: val_dice_coef improved from 0.41163 to 0.59528, saving model to best_unet.keras
#
# Epoch 2: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.8759 - dice_coef: 0.6274 - iou_coef: 0.4631 - loss: 0.7329 - val_accuracy: 0.8497 - val_dice_coef: 0.5953 - val_iou_coef: 0.4304 - val_loss: 0.7993 - learning_rate: 1.0000e-04
# Epoch 3/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8962 - dice_coef: 0.6686 - iou_coef: 0.5069 - loss: 0.6628
# Epoch 3: val_dice_coef improved from 0.59528 to 0.65141, saving model to best_unet.keras
#
# Epoch 3: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9010 - dice_coef: 0.6755 - iou_coef: 0.5152 - loss: 0.6464 - val_accuracy: 0.8590 - val_dice_coef: 0.6514 - val_iou_coef: 0.4919 - val_loss: 0.6886 - learning_rate: 1.0000e-04
# Epoch 4/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9184 - dice_coef: 0.7111 - iou_coef: 0.5550 - loss: 0.5777
# Epoch 4: val_dice_coef improved from 0.65141 to 0.68446, saving model to best_unet.keras
#
# Epoch 4: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - accuracy: 0.9153 - dice_coef: 0.7059 - iou_coef: 0.5508 - loss: 0.5847 - val_accuracy: 0.8549 - val_dice_coef: 0.6845 - val_iou_coef: 0.5275 - val_loss: 0.6088 - learning_rate: 1.0000e-04
# Epoch 5/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9166 - dice_coef: 0.7259 - iou_coef: 0.5736 - loss: 0.5481
# Epoch 5: val_dice_coef improved from 0.68446 to 0.72542, saving model to best_unet.keras
#
# Epoch 5: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - accuracy: 0.9235 - dice_coef: 0.7270 - iou_coef: 0.5754 - loss: 0.5400 - val_accuracy: 0.8881 - val_dice_coef: 0.7254 - val_iou_coef: 0.5757 - val_loss: 0.5366 - learning_rate: 1.0000e-04
# Epoch 6/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9306 - dice_coef: 0.7376 - iou_coef: 0.5887 - loss: 0.5248
# Epoch 6: val_dice_coef improved from 0.72542 to 0.73494, saving model to best_unet.keras
#
# Epoch 6: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 12s 141ms/step - accuracy: 0.9277 - dice_coef: 0.7454 - iou_coef: 0.5985 - loss: 0.5107 - val_accuracy: 0.8840 - val_dice_coef: 0.7349 - val_iou_coef: 0.5843 - val_loss: 0.5224 - learning_rate: 1.0000e-04
# Epoch 7/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9284 - dice_coef: 0.7403 - iou_coef: 0.5920 - loss: 0.5193
# Epoch 7: val_dice_coef improved from 0.73494 to 0.75705, saving model to best_unet.keras
#
# Epoch 7: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9311 - dice_coef: 0.7606 - iou_coef: 0.6175 - loss: 0.4809 - val_accuracy: 0.9009 - val_dice_coef: 0.7570 - val_iou_coef: 0.6148 - val_loss: 0.4900 - learning_rate: 1.0000e-04
# Epoch 8/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9326 - dice_coef: 0.7684 - iou_coef: 0.6272 - loss: 0.4632
# Epoch 8: val_dice_coef improved from 0.75705 to 0.76462, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9332 - dice_coef: 0.7726 - iou_coef: 0.6335 - loss: 0.4510 - val_accuracy: 0.9049 - val_dice_coef: 0.7646 - val_iou_coef: 0.6261 - val_loss: 0.4713 - learning_rate: 1.0000e-04
# Epoch 9/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9364 - dice_coef: 0.7825 - iou_coef: 0.6460 - loss: 0.4351
# Epoch 9: val_dice_coef improved from 0.76462 to 0.78160, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9372 - dice_coef: 0.7816 - iou_coef: 0.6477 - loss: 0.4250 - val_accuracy: 0.9102 - val_dice_coef: 0.7816 - val_iou_coef: 0.6466 - val_loss: 0.4361 - learning_rate: 1.0000e-04
# Epoch 10/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9365 - dice_coef: 0.7909 - iou_coef: 0.6572 - loss: 0.4181
# Epoch 10: val_dice_coef improved from 0.78160 to 0.78901, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9374 - dice_coef: 0.7927 - iou_coef: 0.6602 - loss: 0.4126 - val_accuracy: 0.9150 - val_dice_coef: 0.7890 - val_iou_coef: 0.6575 - val_loss: 0.4232 - learning_rate: 1.0000e-04
# Epoch 11/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9420 - dice_coef: 0.8061 - iou_coef: 0.6780 - loss: 0.3876
# Epoch 11: val_dice_coef did not improve from 0.78901
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9397 - dice_coef: 0.8002 - iou_coef: 0.6718 - loss: 0.3940 - val_accuracy: 0.8912 - val_dice_coef: 0.7512 - val_iou_coef: 0.6060 - val_loss: 0.4999 - learning_rate: 1.0000e-04
# Epoch 12/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9405 - dice_coef: 0.8109 - iou_coef: 0.6844 - loss: 0.3782
# Epoch 12: val_dice_coef improved from 0.78901 to 0.79196, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 134ms/step - accuracy: 0.9406 - dice_coef: 0.8033 - iou_coef: 0.6780 - loss: 0.3805 - val_accuracy: 0.9128 - val_dice_coef: 0.7920 - val_iou_coef: 0.6605 - val_loss: 0.4001 - learning_rate: 1.0000e-04
# Epoch 13/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9413 - dice_coef: 0.8114 - iou_coef: 0.6855 - loss: 0.3773
# Epoch 13: val_dice_coef improved from 0.79196 to 0.81210, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9413 - dice_coef: 0.8102 - iou_coef: 0.6849 - loss: 0.3750 - val_accuracy: 0.9210 - val_dice_coef: 0.8121 - val_iou_coef: 0.6889 - val_loss: 0.3730 - learning_rate: 1.0000e-04
# Epoch 14/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9433 - dice_coef: 0.8198 - iou_coef: 0.6985 - loss: 0.3603
# Epoch 14: val_dice_coef improved from 0.81210 to 0.81536, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9432 - dice_coef: 0.8229 - iou_coef: 0.7027 - loss: 0.3553 - val_accuracy: 0.9170 - val_dice_coef: 0.8154 - val_iou_coef: 0.6916 - val_loss: 0.3635 - learning_rate: 1.0000e-04
# Epoch 15/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9463 - dice_coef: 0.8294 - iou_coef: 0.7109 - loss: 0.3413
# Epoch 15: val_dice_coef did not improve from 0.81536
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9457 - dice_coef: 0.8326 - iou_coef: 0.7156 - loss: 0.3331 - val_accuracy: 0.9169 - val_dice_coef: 0.8109 - val_iou_coef: 0.6891 - val_loss: 0.4012 - learning_rate: 1.0000e-04
# Epoch 16/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9454 - dice_coef: 0.8356 - iou_coef: 0.7204 - loss: 0.3288
# Epoch 16: val_dice_coef improved from 0.81536 to 0.82165, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9450 - dice_coef: 0.8289 - iou_coef: 0.7131 - loss: 0.3337 - val_accuracy: 0.9203 - val_dice_coef: 0.8217 - val_iou_coef: 0.7023 - val_loss: 0.3705 - learning_rate: 1.0000e-04
# Epoch 17/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9478 - dice_coef: 0.8432 - iou_coef: 0.7312 - loss: 0.3135
# Epoch 17: val_dice_coef did not improve from 0.82165
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9469 - dice_coef: 0.8359 - iou_coef: 0.7229 - loss: 0.3168 - val_accuracy: 0.9178 - val_dice_coef: 0.8194 - val_iou_coef: 0.6996 - val_loss: 0.3793 - learning_rate: 1.0000e-04
# Epoch 18/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9487 - dice_coef: 0.8474 - iou_coef: 0.7379 - loss: 0.3051
# Epoch 18: val_dice_coef improved from 0.82165 to 0.82460, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9475 - dice_coef: 0.8401 - iou_coef: 0.7299 - loss: 0.3121 - val_accuracy: 0.9189 - val_dice_coef: 0.8246 - val_iou_coef: 0.7057 - val_loss: 0.3607 - learning_rate: 1.0000e-04
# Epoch 19/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9477 - dice_coef: 0.8523 - iou_coef: 0.7448 - loss: 0.2952
# Epoch 19: val_dice_coef improved from 0.82460 to 0.84865, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9481 - dice_coef: 0.8413 - iou_coef: 0.7325 - loss: 0.3046 - val_accuracy: 0.9321 - val_dice_coef: 0.8487 - val_iou_coef: 0.7403 - val_loss: 0.3018 - learning_rate: 1.0000e-04
# Epoch 20/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9437 - dice_coef: 0.8380 - iou_coef: 0.7243 - loss: 0.3240
# Epoch 20: val_dice_coef did not improve from 0.84865
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9470 - dice_coef: 0.8431 - iou_coef: 0.7326 - loss: 0.3074 - val_accuracy: 0.9101 - val_dice_coef: 0.8125 - val_iou_coef: 0.6878 - val_loss: 0.3882 - learning_rate: 1.0000e-04
# Epoch 21/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9468 - dice_coef: 0.8510 - iou_coef: 0.7434 - loss: 0.2980
# Epoch 21: val_dice_coef did not improve from 0.84865
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9478 - dice_coef: 0.8474 - iou_coef: 0.7404 - loss: 0.2987 - val_accuracy: 0.9274 - val_dice_coef: 0.8448 - val_iou_coef: 0.7376 - val_loss: 0.3357 - learning_rate: 1.0000e-04
# Epoch 22/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9505 - dice_coef: 0.8570 - iou_coef: 0.7525 - loss: 0.2860
# Epoch 22: val_dice_coef did not improve from 0.84865
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9495 - dice_coef: 0.8561 - iou_coef: 0.7512 - loss: 0.2875 - val_accuracy: 0.9266 - val_dice_coef: 0.8446 - val_iou_coef: 0.7376 - val_loss: 0.3335 - learning_rate: 1.0000e-04
# Epoch 23/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9515 - dice_coef: 0.8597 - iou_coef: 0.7560 - loss: 0.2805
# Epoch 23: val_dice_coef improved from 0.84865 to 0.85771, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9511 - dice_coef: 0.8630 - iou_coef: 0.7610 - loss: 0.2743 - val_accuracy: 0.9330 - val_dice_coef: 0.8577 - val_iou_coef: 0.7525 - val_loss: 0.2870 - learning_rate: 1.0000e-04
# Epoch 24/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9537 - dice_coef: 0.8649 - iou_coef: 0.7644 - loss: 0.2702
# Epoch 24: val_dice_coef did not improve from 0.85771
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9506 - dice_coef: 0.8587 - iou_coef: 0.7568 - loss: 0.2772 - val_accuracy: 0.9187 - val_dice_coef: 0.8346 - val_iou_coef: 0.7171 - val_loss: 0.3230 - learning_rate: 1.0000e-04
# Epoch 25/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9499 - dice_coef: 0.8640 - iou_coef: 0.7623 - loss: 0.2720
# Epoch 25: val_dice_coef improved from 0.85771 to 0.85988, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9512 - dice_coef: 0.8671 - iou_coef: 0.7674 - loss: 0.2671 - val_accuracy: 0.9339 - val_dice_coef: 0.8599 - val_iou_coef: 0.7580 - val_loss: 0.2892 - learning_rate: 1.0000e-04
# Epoch 26/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9524 - dice_coef: 0.8681 - iou_coef: 0.7689 - loss: 0.2638
# Epoch 26: val_dice_coef did not improve from 0.85988
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9527 - dice_coef: 0.8703 - iou_coef: 0.7728 - loss: 0.2561 - val_accuracy: 0.9215 - val_dice_coef: 0.8381 - val_iou_coef: 0.7256 - val_loss: 0.3346 - learning_rate: 1.0000e-04
# Epoch 27/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9512 - dice_coef: 0.8682 - iou_coef: 0.7693 - loss: 0.2636
# Epoch 27: val_dice_coef did not improve from 0.85988
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9512 - dice_coef: 0.8650 - iou_coef: 0.7653 - loss: 0.2656 - val_accuracy: 0.9257 - val_dice_coef: 0.8485 - val_iou_coef: 0.7402 - val_loss: 0.3110 - learning_rate: 1.0000e-04
# Epoch 28/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9513 - dice_coef: 0.8695 - iou_coef: 0.7719 - loss: 0.2609
# Epoch 28: val_dice_coef did not improve from 0.85988
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9525 - dice_coef: 0.8691 - iou_coef: 0.7722 - loss: 0.2560 - val_accuracy: 0.9222 - val_dice_coef: 0.8396 - val_iou_coef: 0.7253 - val_loss: 0.3123 - learning_rate: 1.0000e-04
# Epoch 29/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9524 - dice_coef: 0.8670 - iou_coef: 0.7684 - loss: 0.2659
# Epoch 29: val_dice_coef did not improve from 0.85988
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9527 - dice_coef: 0.8709 - iou_coef: 0.7745 - loss: 0.2540 - val_accuracy: 0.9255 - val_dice_coef: 0.8497 - val_iou_coef: 0.7403 - val_loss: 0.3139 - learning_rate: 1.0000e-04
# Epoch 30/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9545 - dice_coef: 0.8787 - iou_coef: 0.7861 - loss: 0.2426
# Epoch 30: val_dice_coef improved from 0.85988 to 0.86322, saving model to best_unet.keras
#
# Epoch 30: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 134ms/step - accuracy: 0.9540 - dice_coef: 0.8750 - iou_coef: 0.7811 - loss: 0.2463 - val_accuracy: 0.9316 - val_dice_coef: 0.8632 - val_iou_coef: 0.7616 - val_loss: 0.2885 - learning_rate: 5.0000e-05
# Epoch 31/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9549 - dice_coef: 0.8775 - iou_coef: 0.7841 - loss: 0.2450
# Epoch 31: val_dice_coef did not improve from 0.86322
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9550 - dice_coef: 0.8746 - iou_coef: 0.7817 - loss: 0.2415 - val_accuracy: 0.9306 - val_dice_coef: 0.8631 - val_iou_coef: 0.7610 - val_loss: 0.2796 - learning_rate: 5.0000e-05
# Epoch 32/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9561 - dice_coef: 0.8775 - iou_coef: 0.7836 - loss: 0.2450
# Epoch 32: val_dice_coef improved from 0.86322 to 0.86361, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9552 - dice_coef: 0.8795 - iou_coef: 0.7870 - loss: 0.2399 - val_accuracy: 0.9314 - val_dice_coef: 0.8636 - val_iou_coef: 0.7625 - val_loss: 0.2889 - learning_rate: 5.0000e-05
# Epoch 33/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9547 - dice_coef: 0.8779 - iou_coef: 0.7851 - loss: 0.2442
# Epoch 33: val_dice_coef did not improve from 0.86361
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9552 - dice_coef: 0.8802 - iou_coef: 0.7885 - loss: 0.2366 - val_accuracy: 0.9303 - val_dice_coef: 0.8612 - val_iou_coef: 0.7602 - val_loss: 0.2914 - learning_rate: 5.0000e-05
# Epoch 34/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9556 - dice_coef: 0.8796 - iou_coef: 0.7872 - loss: 0.2409
# Epoch 34: val_dice_coef improved from 0.86361 to 0.86876, saving model to best_unet.keras
#
# Epoch 34: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9552 - dice_coef: 0.8817 - iou_coef: 0.7905 - loss: 0.2371 - val_accuracy: 0.9329 - val_dice_coef: 0.8688 - val_iou_coef: 0.7697 - val_loss: 0.2732 - learning_rate: 5.0000e-05
# Epoch 35/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9542 - dice_coef: 0.8833 - iou_coef: 0.7926 - loss: 0.2334
# Epoch 35: val_dice_coef did not improve from 0.86876
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9555 - dice_coef: 0.8817 - iou_coef: 0.7906 - loss: 0.2336 - val_accuracy: 0.9347 - val_dice_coef: 0.8674 - val_iou_coef: 0.7672 - val_loss: 0.2606 - learning_rate: 5.0000e-05
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9549 - dice_coef: 0.8808 - iou_coef: 0.7887 - loss: 0.2384
# Epoch 36: val_dice_coef did not improve from 0.86876
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9559 - dice_coef: 0.8819 - iou_coef: 0.7909 - loss: 0.2341 - val_accuracy: 0.9261 - val_dice_coef: 0.8559 - val_iou_coef: 0.7505 - val_loss: 0.3045 - learning_rate: 5.0000e-05
# Epoch 37/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9577 - dice_coef: 0.8879 - iou_coef: 0.7998 - loss: 0.2243
# Epoch 37: val_dice_coef did not improve from 0.86876
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9565 - dice_coef: 0.8852 - iou_coef: 0.7962 - loss: 0.2267 - val_accuracy: 0.9285 - val_dice_coef: 0.8565 - val_iou_coef: 0.7505 - val_loss: 0.2838 - learning_rate: 5.0000e-05
# Epoch 38/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9586 - dice_coef: 0.8868 - iou_coef: 0.7989 - loss: 0.2264
# Epoch 38: val_dice_coef did not improve from 0.86876
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9567 - dice_coef: 0.8846 - iou_coef: 0.7955 - loss: 0.2278 - val_accuracy: 0.9331 - val_dice_coef: 0.8666 - val_iou_coef: 0.7660 - val_loss: 0.2707 - learning_rate: 5.0000e-05
# Epoch 39/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9578 - dice_coef: 0.8863 - iou_coef: 0.7979 - loss: 0.2275
# Epoch 39: val_dice_coef did not improve from 0.86876
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9569 - dice_coef: 0.8868 - iou_coef: 0.7986 - loss: 0.2268 - val_accuracy: 0.9321 - val_dice_coef: 0.8655 - val_iou_coef: 0.7657 - val_loss: 0.2803 - learning_rate: 2.5000e-05
# Epoch 40/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9589 - dice_coef: 0.8934 - iou_coef: 0.8089 - loss: 0.2131
# Epoch 40: val_dice_coef did not improve from 0.86876
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 117ms/step - accuracy: 0.9578 - dice_coef: 0.8842 - iou_coef: 0.7972 - loss: 0.2208 - val_accuracy: 0.9322 - val_dice_coef: 0.8655 - val_iou_coef: 0.7648 - val_loss: 0.2757 - learning_rate: 2.5000e-05
# Epoch 41/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9581 - dice_coef: 0.8897 - iou_coef: 0.8029 - loss: 0.2206
# Epoch 41: val_dice_coef did not improve from 0.86876
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9582 - dice_coef: 0.8879 - iou_coef: 0.8010 - loss: 0.2199 - val_accuracy: 0.9298 - val_dice_coef: 0.8610 - val_iou_coef: 0.7574 - val_loss: 0.2831 - learning_rate: 2.5000e-05
# Epoch 42/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9589 - dice_coef: 0.8932 - iou_coef: 0.8084 - loss: 0.2135
# Epoch 42: val_dice_coef did not improve from 0.86876
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 119ms/step - accuracy: 0.9580 - dice_coef: 0.8903 - iou_coef: 0.8041 - loss: 0.2174 - val_accuracy: 0.9295 - val_dice_coef: 0.8626 - val_iou_coef: 0.7598 - val_loss: 0.2787 - learning_rate: 2.5000e-05
# Epoch 43/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9586 - dice_coef: 0.8888 - iou_coef: 0.8028 - loss: 0.2223
# Epoch 43: val_dice_coef improved from 0.86876 to 0.86918, saving model to best_unet.keras
#
# Epoch 43: finished saving model to best_unet.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - accuracy: 0.9586 - dice_coef: 0.8899 - iou_coef: 0.8039 - loss: 0.2172 - val_accuracy: 0.9330 - val_dice_coef: 0.8692 - val_iou_coef: 0.7706 - val_loss: 0.2707 - learning_rate: 1.2500e-05
# Epoch 44/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9579 - dice_coef: 0.8858 - iou_coef: 0.7975 - loss: 0.2283
# Epoch 44: val_dice_coef did not improve from 0.86918
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9584 - dice_coef: 0.8909 - iou_coef: 0.8053 - loss: 0.2176 - val_accuracy: 0.9329 - val_dice_coef: 0.8677 - val_iou_coef: 0.7679 - val_loss: 0.2717 - learning_rate: 1.2500e-05
# Epoch 45/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9588 - dice_coef: 0.8943 - iou_coef: 0.8104 - loss: 0.2115
# Epoch 45: val_dice_coef did not improve from 0.86918
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9583 - dice_coef: 0.8865 - iou_coef: 0.8013 - loss: 0.2174 - val_accuracy: 0.9279 - val_dice_coef: 0.8595 - val_iou_coef: 0.7562 - val_loss: 0.2907 - learning_rate: 1.2500e-05
# Epoch 46/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9597 - dice_coef: 0.8970 - iou_coef: 0.8147 - loss: 0.2060
# Epoch 46: val_dice_coef did not improve from 0.86918
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9594 - dice_coef: 0.8910 - iou_coef: 0.8061 - loss: 0.2136 - val_accuracy: 0.9279 - val_dice_coef: 0.8589 - val_iou_coef: 0.7552 - val_loss: 0.2923 - learning_rate: 1.2500e-05
# Epoch 47/50
# 81/82 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9599 - dice_coef: 0.8928 - iou_coef: 0.8077 - loss: 0.2145
# Epoch 47: val_dice_coef did not improve from 0.86918
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9592 - dice_coef: 0.8940 - iou_coef: 0.8099 - loss: 0.2112 - val_accuracy: 0.9291 - val_dice_coef: 0.8621 - val_iou_coef: 0.7606 - val_loss: 0.2882 - learning_rate: 1.2500e-05
# Epoch 48/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9580 - dice_coef: 0.8894 - iou_coef: 0.8027 - loss: 0.2211
# Epoch 48: val_dice_coef did not improve from 0.86918
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9581 - dice_coef: 0.8872 - iou_coef: 0.8006 - loss: 0.2186 - val_accuracy: 0.9316 - val_dice_coef: 0.8655 - val_iou_coef: 0.7654 - val_loss: 0.2786 - learning_rate: 6.2500e-06
# Epoch 49/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9601 - dice_coef: 0.8907 - iou_coef: 0.8059 - loss: 0.2186
# Epoch 49: val_dice_coef did not improve from 0.86918
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9592 - dice_coef: 0.8912 - iou_coef: 0.8064 - loss: 0.2147 - val_accuracy: 0.9322 - val_dice_coef: 0.8672 - val_iou_coef: 0.7679 - val_loss: 0.2763 - learning_rate: 6.2500e-06
# Epoch 50/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9606 - dice_coef: 0.9003 - iou_coef: 0.8198 - loss: 0.1994
# Epoch 50: val_dice_coef did not improve from 0.86918
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9588 - dice_coef: 0.8912 - iou_coef: 0.8058 - loss: 0.2140 - val_accuracy: 0.9326 - val_dice_coef: 0.8668 - val_iou_coef: 0.7668 - val_loss: 0.2734 - learning_rate: 6.2500e-06
# Restoring model weights from the end of the best epoch: 43.

# %%
test_results = model.evaluate(test_ds, verbose=1)

print(f"Test Loss     : {test_results[0]:.4f}")
print(f"Test Accuracy : {test_results[1]:.4f}")
print(f"Test Dice     : {test_results[2]:.4f}")
print(f"Test IoU      : {test_results[3]:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9183 - dice_coef: 0.8409 - iou_coef: 0.7339 - loss: 0.3202
# Test Loss     : 0.3202
# Test Accuracy : 0.9183
# Test Dice     : 0.8409
# Test IoU      : 0.7339

# %%
plt.figure(figsize=(12, 12))

for images, masks in test_ds.take(1):

    preds = model.predict(images, verbose=0)
    preds = (preds > 0.5).astype(np.float32)

    for i in range(4):

        plt.subplot(4, 3, 3*i + 1)
        plt.imshow(images[i])
        plt.title("Image")
        plt.axis("off")

        plt.subplot(4, 3, 3*i + 2)
        plt.imshow(tf.squeeze(masks[i]), cmap="gray")
        plt.title("Ground Truth")
        plt.axis("off")

        plt.subplot(4, 3, 3*i + 3)
        plt.imshow(preds[i].squeeze(), cmap="gray")
        plt.title("Prediction")
        plt.axis("off")

plt.tight_layout()
plt.show()
