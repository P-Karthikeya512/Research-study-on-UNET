# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Research-study-on-UNET/blob/main/Modified_UNET_1(BUSI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
EPOCHS = 50
SEED = 42

ZIP_PATH = "/content/Dataset_BUSI_with_GT.zip"
EXTRACT_DIR = "/content/BUSI_DATASET"

import zipfile
from pathlib import Path

with zipfile.ZipFile(ZIP_PATH, "r") as z:
    z.extractall(EXTRACT_DIR)

def find_dataset_root(base_dir):
    for root, dirs, files in os.walk(base_dir):
        d = {x.lower() for x in dirs}
        if {"benign", "malignant", "normal"}.issubset(d):
            return root
    raise FileNotFoundError("Could not find benign/malignant/normal folders.")

DATASET_DIR = find_dataset_root(EXTRACT_DIR)

print("Dataset:", DATASET_DIR)

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Dataset: /content/BUSI_DATASET/Dataset_BUSI_with_GT

# %%
def get_pairs(dataset_dir):
    pairs = []

    for cls in ["benign", "malignant", "normal"]:
        folder = os.path.join(dataset_dir, cls)
        for f in sorted(os.listdir(folder)):
            path = os.path.join(folder, f)
            if not os.path.isfile(path):
                continue
            ext = Path(f).suffix.lower()
            if ext not in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]:
                continue
            stem = Path(f).stem
            if "_mask" in stem.lower():
                continue
            mask = os.path.join(folder, stem + "_mask.png")
            if os.path.exists(mask):
                pairs.append((path, mask))
            else:
                print("No mask:", path)

    return pairs


# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    if isinstance(img_path, bytes):
        img_path = img_path.decode()

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode()

    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")

    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(DATASET_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
# Out:
# Total paired samples: 780
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100)_mask.png

# %%
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

labels = [Path(img).parent.name for img, mask in pairs]
train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED, stratify=labels)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))

# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

import tensorflow as tf
from tensorflow.keras import layers, Model

# =========================
# BASIC BLOCKS
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p


def resize_to_ref(tensor, ref, name=None):
    return layers.Lambda(
        lambda t: tf.image.resize(t[0], tf.shape(t[1])[1:3], method="bilinear"),
        name=name
    )([tensor, ref])


def project_and_resize(skip, ref, filters):
    # reduce channels first
    skip = layers.Conv2D(filters, 1, padding="same", kernel_initializer="he_normal")(skip)
    skip = layers.BatchNormalization()(skip)
    skip = layers.ReLU()(skip)

    # then match spatial size
    skip = resize_to_ref(skip, ref)
    return skip


def up_block(x, skips, filters):
    # upsample decoder feature
    x = layers.UpSampling2D((2, 2), interpolation="bilinear")(x)
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    fused = [x]

    # add multiple skip tensors after aligning shape
    for s in skips:
        if s is not None:
            s = project_and_resize(s, x, filters)
            fused.append(s)

    if len(fused) > 1:
        x = layers.Concatenate()(fused)

    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x


# =========================
# BUILD MODIFIED U-NET
# =========================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1, p1 = down_block(inputs, 32)   # 256 -> 128
    c2, p2 = down_block(p1, 64)       # 128 -> 64
    c3, p3 = down_block(p2, 128)      # 64 -> 32
    c4, p4 = down_block(p3, 256)      # 32 -> 16

    # Bottleneck
    bottleneck = conv_block(p4, 512)

    # Decoder with multi-skip fusion
    # up1 = 16 -> 32
    u1 = up_block(bottleneck, [c4], 256)

    # up2 = 32 -> 64, fuse c3 + c4
    u2 = up_block(u1, [c3, c4], 128)

    # up3 = 64 -> 128, fuse c2 + c3
    u3 = up_block(u2, [c2, c3], 64)

    # up4 = 128 -> 256, fuse c1 + c2
    u4 = up_block(u3, [c1, c2], 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_MultiSkip_Resized")
    return model


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    # Accuracy
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Train samples: 624
# Val samples: 156
# Model: "UNet_MultiSkip_Resized"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ re_lu_8[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ re_lu_9[0][0]     │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ up_sampling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │     65,792 │ re_lu_7[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 32, 32,    │          0 │ re_lu_11[0][0],   │
# │                     │ 256)              │            │ re_lu_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ re_lu_10[0][0],   │
# │ (Concatenate)       │ 512)              │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_12[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ re_lu_13[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    295,040 │ up_sampling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │     16,512 │ re_lu_5[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 32, 32,    │     32,896 │ re_lu_7[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 64, 64,    │          0 │ re_lu_15[0][0],   │
# │                     │ 128)              │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 64, 64,    │          0 │ re_lu_16[0][0],   │
# │                     │ 128)              │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ re_lu_14[0][0],   │
# │ (Concatenate)       │ 384)              │            │ lambda_1[0][0],   │
# │                     │                   │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_1[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 64, 64,    │    442,496 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_17[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ re_lu_18[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │     73,792 │ up_sampling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 128, 128,  │      4,160 │ re_lu_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64,    │      8,256 │ re_lu_5[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 128, 128,  │          0 │ re_lu_20[0][0],   │
# │                     │ 64)               │            │ re_lu_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 128, 128,  │          0 │ re_lu_21[0][0],   │
# │                     │ 64)               │            │ re_lu_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ re_lu_19[0][0],   │
# │ (Concatenate)       │ 192)              │            │ lambda_3[0][0],   │
# │                     │                   │            │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_2[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │    110,656 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_22[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ re_lu_23[0][0]    │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │     18,464 │ up_sampling2d_3[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │      1,056 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │      2,080 │ re_lu_3[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 256, 256,  │          0 │ re_lu_25[0][0],   │
# │                     │ 32)               │            │ re_lu_24[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 256, 256,  │          0 │ re_lu_26[0][0],   │
# │                     │ 32)               │            │ re_lu_24[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ re_lu_24[0][0],   │
# │ (Concatenate)       │ 96)               │            │ lambda_5[0][0],   │
# │                     │                   │            │ lambda_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ concatenate_3[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 256, 256,  │     27,680 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_27[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 256, 256,  │         33 │ re_lu_28[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,971,297 (34.22 MB)
#  Trainable params: 8,963,041 (34.19 MB)
#  Non-trainable params: 8,256 (32.25 KB)
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5621 - dice_coef: 0.1575 - iou_coef: 0.0867 - loss: 0.8425
# Epoch 1: val_dice_coef improved from None to 0.15196, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 108s 523ms/step - accuracy: 0.6444 - dice_coef: 0.1922 - iou_coef: 0.1087 - loss: 0.8078 - val_accuracy: 0.9111 - val_dice_coef: 0.1520 - val_iou_coef: 0.0829 - val_loss: 0.8478 - learning_rate: 1.0000e-04
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.7459 - dice_coef: 0.2376 - iou_coef: 0.1369 - loss: 0.7624
# Epoch 2: val_dice_coef improved from 0.15196 to 0.23284, saving model to best_unet.keras
#
# Epoch 2: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 374ms/step - accuracy: 0.7744 - dice_coef: 0.2456 - iou_coef: 0.1426 - loss: 0.7544 - val_accuracy: 0.8413 - val_dice_coef: 0.2328 - val_iou_coef: 0.1344 - val_loss: 0.7673 - learning_rate: 1.0000e-04
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.8368 - dice_coef: 0.2760 - iou_coef: 0.1638 - loss: 0.7240
# Epoch 3: val_dice_coef improved from 0.23284 to 0.27607, saving model to best_unet.keras
#
# Epoch 3: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 31s 393ms/step - accuracy: 0.8430 - dice_coef: 0.2881 - iou_coef: 0.1725 - loss: 0.7119 - val_accuracy: 0.8504 - val_dice_coef: 0.2761 - val_iou_coef: 0.1635 - val_loss: 0.7240 - learning_rate: 1.0000e-04
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8529 - dice_coef: 0.3087 - iou_coef: 0.1865 - loss: 0.6913
# Epoch 4: val_dice_coef improved from 0.27607 to 0.29723, saving model to best_unet.keras
#
# Epoch 4: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 389ms/step - accuracy: 0.8552 - dice_coef: 0.2993 - iou_coef: 0.1800 - loss: 0.7007 - val_accuracy: 0.8434 - val_dice_coef: 0.2972 - val_iou_coef: 0.1788 - val_loss: 0.7024 - learning_rate: 1.0000e-04
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.8849 - dice_coef: 0.3220 - iou_coef: 0.1944 - loss: 0.6780
# Epoch 5: val_dice_coef improved from 0.29723 to 0.33281, saving model to best_unet.keras
#
# Epoch 5: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 387ms/step - accuracy: 0.8763 - dice_coef: 0.3268 - iou_coef: 0.1990 - loss: 0.6732 - val_accuracy: 0.8993 - val_dice_coef: 0.3328 - val_iou_coef: 0.2036 - val_loss: 0.6689 - learning_rate: 1.0000e-04
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8852 - dice_coef: 0.3330 - iou_coef: 0.2051 - loss: 0.6670
# Epoch 6: val_dice_coef improved from 0.33281 to 0.36415, saving model to best_unet.keras
#
# Epoch 6: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 393ms/step - accuracy: 0.8893 - dice_coef: 0.3424 - iou_coef: 0.2128 - loss: 0.6576 - val_accuracy: 0.8867 - val_dice_coef: 0.3641 - val_iou_coef: 0.2280 - val_loss: 0.6368 - learning_rate: 1.0000e-04
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8895 - dice_coef: 0.3518 - iou_coef: 0.2220 - loss: 0.6482
# Epoch 7: val_dice_coef improved from 0.36415 to 0.40828, saving model to best_unet.keras
#
# Epoch 7: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 385ms/step - accuracy: 0.8942 - dice_coef: 0.3577 - iou_coef: 0.2238 - loss: 0.6423 - val_accuracy: 0.9124 - val_dice_coef: 0.4083 - val_iou_coef: 0.2625 - val_loss: 0.5945 - learning_rate: 1.0000e-04
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9051 - dice_coef: 0.3769 - iou_coef: 0.2376 - loss: 0.6231
# Epoch 8: val_dice_coef improved from 0.40828 to 0.41621, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 380ms/step - accuracy: 0.9018 - dice_coef: 0.3773 - iou_coef: 0.2385 - loss: 0.6227 - val_accuracy: 0.9037 - val_dice_coef: 0.4162 - val_iou_coef: 0.2712 - val_loss: 0.5863 - learning_rate: 1.0000e-04
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8980 - dice_coef: 0.4032 - iou_coef: 0.2582 - loss: 0.5968
# Epoch 9: val_dice_coef did not improve from 0.41621
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 373ms/step - accuracy: 0.9068 - dice_coef: 0.3937 - iou_coef: 0.2513 - loss: 0.6063 - val_accuracy: 0.9291 - val_dice_coef: 0.3779 - val_iou_coef: 0.2405 - val_loss: 0.6269 - learning_rate: 1.0000e-04
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9200 - dice_coef: 0.4292 - iou_coef: 0.2792 - loss: 0.5708
# Epoch 10: val_dice_coef did not improve from 0.41621
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 377ms/step - accuracy: 0.9190 - dice_coef: 0.4120 - iou_coef: 0.2667 - loss: 0.5880 - val_accuracy: 0.9339 - val_dice_coef: 0.4124 - val_iou_coef: 0.2677 - val_loss: 0.5920 - learning_rate: 1.0000e-04
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9203 - dice_coef: 0.4290 - iou_coef: 0.2808 - loss: 0.5710
# Epoch 11: val_dice_coef improved from 0.41621 to 0.42701, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 386ms/step - accuracy: 0.9196 - dice_coef: 0.4223 - iou_coef: 0.2748 - loss: 0.5777 - val_accuracy: 0.9194 - val_dice_coef: 0.4270 - val_iou_coef: 0.2811 - val_loss: 0.5791 - learning_rate: 1.0000e-04
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9275 - dice_coef: 0.4446 - iou_coef: 0.2945 - loss: 0.5554
# Epoch 12: val_dice_coef improved from 0.42701 to 0.47085, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 383ms/step - accuracy: 0.9275 - dice_coef: 0.4513 - iou_coef: 0.3001 - loss: 0.5487 - val_accuracy: 0.8990 - val_dice_coef: 0.4709 - val_iou_coef: 0.3182 - val_loss: 0.5325 - learning_rate: 1.0000e-04
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9192 - dice_coef: 0.4673 - iou_coef: 0.3141 - loss: 0.5327
# Epoch 13: val_dice_coef improved from 0.47085 to 0.47567, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 386ms/step - accuracy: 0.9288 - dice_coef: 0.4619 - iou_coef: 0.3088 - loss: 0.5381 - val_accuracy: 0.9330 - val_dice_coef: 0.4757 - val_iou_coef: 0.3223 - val_loss: 0.5286 - learning_rate: 1.0000e-04
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9303 - dice_coef: 0.4696 - iou_coef: 0.3146 - loss: 0.5304
# Epoch 14: val_dice_coef improved from 0.47567 to 0.49791, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 388ms/step - accuracy: 0.9302 - dice_coef: 0.4698 - iou_coef: 0.3148 - loss: 0.5302 - val_accuracy: 0.9288 - val_dice_coef: 0.4979 - val_iou_coef: 0.3443 - val_loss: 0.5058 - learning_rate: 1.0000e-04
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9392 - dice_coef: 0.5041 - iou_coef: 0.3442 - loss: 0.4959
# Epoch 15: val_dice_coef did not improve from 0.49791
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 376ms/step - accuracy: 0.9374 - dice_coef: 0.5073 - iou_coef: 0.3472 - loss: 0.4927 - val_accuracy: 0.9142 - val_dice_coef: 0.4678 - val_iou_coef: 0.3182 - val_loss: 0.5375 - learning_rate: 1.0000e-04
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9337 - dice_coef: 0.4836 - iou_coef: 0.3283 - loss: 0.5164
# Epoch 16: val_dice_coef did not improve from 0.49791
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 370ms/step - accuracy: 0.9327 - dice_coef: 0.4879 - iou_coef: 0.3317 - loss: 0.5121 - val_accuracy: 0.9222 - val_dice_coef: 0.4966 - val_iou_coef: 0.3414 - val_loss: 0.5068 - learning_rate: 1.0000e-04
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9433 - dice_coef: 0.5130 - iou_coef: 0.3542 - loss: 0.4870
# Epoch 17: val_dice_coef improved from 0.49791 to 0.54263, saving model to best_unet.keras
#
# Epoch 17: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 31s 390ms/step - accuracy: 0.9422 - dice_coef: 0.5261 - iou_coef: 0.3661 - loss: 0.4739 - val_accuracy: 0.9325 - val_dice_coef: 0.5426 - val_iou_coef: 0.3859 - val_loss: 0.4614 - learning_rate: 1.0000e-04
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9415 - dice_coef: 0.5383 - iou_coef: 0.3733 - loss: 0.4617
# Epoch 18: val_dice_coef did not improve from 0.54263
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 374ms/step - accuracy: 0.9420 - dice_coef: 0.5369 - iou_coef: 0.3735 - loss: 0.4631 - val_accuracy: 0.9321 - val_dice_coef: 0.5017 - val_iou_coef: 0.3475 - val_loss: 0.5050 - learning_rate: 1.0000e-04
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9391 - dice_coef: 0.4912 - iou_coef: 0.3380 - loss: 0.5088
# Epoch 19: val_dice_coef improved from 0.54263 to 0.56310, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 384ms/step - accuracy: 0.9393 - dice_coef: 0.5165 - iou_coef: 0.3593 - loss: 0.4835 - val_accuracy: 0.9356 - val_dice_coef: 0.5631 - val_iou_coef: 0.4049 - val_loss: 0.4413 - learning_rate: 1.0000e-04
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9520 - dice_coef: 0.5879 - iou_coef: 0.4208 - loss: 0.4121
# Epoch 20: val_dice_coef did not improve from 0.56310
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 370ms/step - accuracy: 0.9490 - dice_coef: 0.5768 - iou_coef: 0.4110 - loss: 0.4232 - val_accuracy: 0.9414 - val_dice_coef: 0.5512 - val_iou_coef: 0.3956 - val_loss: 0.4563 - learning_rate: 1.0000e-04
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9447 - dice_coef: 0.5508 - iou_coef: 0.3914 - loss: 0.4492
# Epoch 21: val_dice_coef improved from 0.56310 to 0.58138, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 382ms/step - accuracy: 0.9423 - dice_coef: 0.5466 - iou_coef: 0.3865 - loss: 0.4534 - val_accuracy: 0.9329 - val_dice_coef: 0.5814 - val_iou_coef: 0.4247 - val_loss: 0.4237 - learning_rate: 1.0000e-04
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9368 - dice_coef: 0.5562 - iou_coef: 0.3970 - loss: 0.4438
# Epoch 22: val_dice_coef did not improve from 0.58138
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 372ms/step - accuracy: 0.9456 - dice_coef: 0.5788 - iou_coef: 0.4206 - loss: 0.4212 - val_accuracy: 0.9151 - val_dice_coef: 0.5260 - val_iou_coef: 0.3723 - val_loss: 0.4792 - learning_rate: 1.0000e-04
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9487 - dice_coef: 0.5723 - iou_coef: 0.4139 - loss: 0.4277
# Epoch 23: val_dice_coef improved from 0.58138 to 0.58608, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 384ms/step - accuracy: 0.9499 - dice_coef: 0.5955 - iou_coef: 0.4352 - loss: 0.4045 - val_accuracy: 0.9430 - val_dice_coef: 0.5861 - val_iou_coef: 0.4345 - val_loss: 0.4210 - learning_rate: 1.0000e-04
# Epoch 24/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9551 - dice_coef: 0.6182 - iou_coef: 0.4566 - loss: 0.3818
# Epoch 24: val_dice_coef improved from 0.58608 to 0.61356, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 383ms/step - accuracy: 0.9486 - dice_coef: 0.5875 - iou_coef: 0.4286 - loss: 0.4125 - val_accuracy: 0.9418 - val_dice_coef: 0.6136 - val_iou_coef: 0.4578 - val_loss: 0.3900 - learning_rate: 1.0000e-04
# Epoch 25/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9555 - dice_coef: 0.6267 - iou_coef: 0.4635 - loss: 0.3733
# Epoch 25: val_dice_coef improved from 0.61356 to 0.62667, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 383ms/step - accuracy: 0.9523 - dice_coef: 0.6099 - iou_coef: 0.4478 - loss: 0.3901 - val_accuracy: 0.9456 - val_dice_coef: 0.6267 - val_iou_coef: 0.4758 - val_loss: 0.3783 - learning_rate: 1.0000e-04
# Epoch 26/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9426 - dice_coef: 0.5916 - iou_coef: 0.4361 - loss: 0.4084
# Epoch 26: val_dice_coef did not improve from 0.62667
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 372ms/step - accuracy: 0.9465 - dice_coef: 0.5840 - iou_coef: 0.4268 - loss: 0.4160 - val_accuracy: 0.9411 - val_dice_coef: 0.6051 - val_iou_coef: 0.4546 - val_loss: 0.4010 - learning_rate: 1.0000e-04
# Epoch 27/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9482 - dice_coef: 0.5983 - iou_coef: 0.4403 - loss: 0.4017
# Epoch 27: val_dice_coef did not improve from 0.62667
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 374ms/step - accuracy: 0.9501 - dice_coef: 0.6065 - iou_coef: 0.4480 - loss: 0.3935 - val_accuracy: 0.9441 - val_dice_coef: 0.6158 - val_iou_coef: 0.4636 - val_loss: 0.3902 - learning_rate: 1.0000e-04
# Epoch 28/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9497 - dice_coef: 0.5754 - iou_coef: 0.4192 - loss: 0.4246
# Epoch 28: val_dice_coef improved from 0.62667 to 0.63301, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 31s 392ms/step - accuracy: 0.9498 - dice_coef: 0.6013 - iou_coef: 0.4426 - loss: 0.3987 - val_accuracy: 0.9396 - val_dice_coef: 0.6330 - val_iou_coef: 0.4832 - val_loss: 0.3712 - learning_rate: 1.0000e-04
# Epoch 29/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9546 - dice_coef: 0.6219 - iou_coef: 0.4681 - loss: 0.3781
# Epoch 29: val_dice_coef did not improve from 0.63301
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 377ms/step - accuracy: 0.9542 - dice_coef: 0.6259 - iou_coef: 0.4713 - loss: 0.3741 - val_accuracy: 0.9345 - val_dice_coef: 0.6189 - val_iou_coef: 0.4682 - val_loss: 0.3848 - learning_rate: 1.0000e-04
# Epoch 30/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9506 - dice_coef: 0.6130 - iou_coef: 0.4601 - loss: 0.3870
# Epoch 30: val_dice_coef did not improve from 0.63301
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 379ms/step - accuracy: 0.9484 - dice_coef: 0.6042 - iou_coef: 0.4532 - loss: 0.3958 - val_accuracy: 0.9442 - val_dice_coef: 0.5988 - val_iou_coef: 0.4499 - val_loss: 0.4069 - learning_rate: 1.0000e-04
# Epoch 31/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9558 - dice_coef: 0.6198 - iou_coef: 0.4601 - loss: 0.3802
# Epoch 31: val_dice_coef improved from 0.63301 to 0.65444, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 386ms/step - accuracy: 0.9516 - dice_coef: 0.6130 - iou_coef: 0.4572 - loss: 0.3870 - val_accuracy: 0.9464 - val_dice_coef: 0.6544 - val_iou_coef: 0.5040 - val_loss: 0.3493 - learning_rate: 1.0000e-04
# Epoch 32/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9493 - dice_coef: 0.6253 - iou_coef: 0.4710 - loss: 0.3747
# Epoch 32: val_dice_coef did not improve from 0.65444
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 373ms/step - accuracy: 0.9504 - dice_coef: 0.6223 - iou_coef: 0.4689 - loss: 0.3777 - val_accuracy: 0.9474 - val_dice_coef: 0.6358 - val_iou_coef: 0.4864 - val_loss: 0.3692 - learning_rate: 1.0000e-04
# Epoch 33/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9566 - dice_coef: 0.6568 - iou_coef: 0.5015 - loss: 0.3432
# Epoch 33: val_dice_coef did not improve from 0.65444
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 373ms/step - accuracy: 0.9544 - dice_coef: 0.6404 - iou_coef: 0.4844 - loss: 0.3596 - val_accuracy: 0.9444 - val_dice_coef: 0.6475 - val_iou_coef: 0.4961 - val_loss: 0.3565 - learning_rate: 1.0000e-04
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9556 - dice_coef: 0.6366 - iou_coef: 0.4771 - loss: 0.3634
# Epoch 34: val_dice_coef improved from 0.65444 to 0.66039, saving model to best_unet.keras
#
# Epoch 34: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 383ms/step - accuracy: 0.9561 - dice_coef: 0.6588 - iou_coef: 0.5012 - loss: 0.3412 - val_accuracy: 0.9481 - val_dice_coef: 0.6604 - val_iou_coef: 0.5115 - val_loss: 0.3446 - learning_rate: 1.0000e-04
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9580 - dice_coef: 0.6461 - iou_coef: 0.4919 - loss: 0.3539
# Epoch 35: val_dice_coef did not improve from 0.66039
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 373ms/step - accuracy: 0.9534 - dice_coef: 0.6326 - iou_coef: 0.4782 - loss: 0.3674 - val_accuracy: 0.9455 - val_dice_coef: 0.6266 - val_iou_coef: 0.4837 - val_loss: 0.3804 - learning_rate: 1.0000e-04
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9573 - dice_coef: 0.6798 - iou_coef: 0.5258 - loss: 0.3202
# Epoch 36: val_dice_coef did not improve from 0.66039
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 374ms/step - accuracy: 0.9566 - dice_coef: 0.6669 - iou_coef: 0.5137 - loss: 0.3331 - val_accuracy: 0.9432 - val_dice_coef: 0.5611 - val_iou_coef: 0.4180 - val_loss: 0.4472 - learning_rate: 1.0000e-04
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9584 - dice_coef: 0.6592 - iou_coef: 0.5027 - loss: 0.3408
# Epoch 37: val_dice_coef did not improve from 0.66039
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 377ms/step - accuracy: 0.9582 - dice_coef: 0.6678 - iou_coef: 0.5131 - loss: 0.3322 - val_accuracy: 0.9453 - val_dice_coef: 0.6343 - val_iou_coef: 0.4864 - val_loss: 0.3711 - learning_rate: 1.0000e-04
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9587 - dice_coef: 0.6569 - iou_coef: 0.5018 - loss: 0.3431
# Epoch 38: val_dice_coef did not improve from 0.66039
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 378ms/step - accuracy: 0.9578 - dice_coef: 0.6617 - iou_coef: 0.5077 - loss: 0.3383 - val_accuracy: 0.9436 - val_dice_coef: 0.6371 - val_iou_coef: 0.4918 - val_loss: 0.3681 - learning_rate: 1.0000e-04
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9626 - dice_coef: 0.6735 - iou_coef: 0.5226 - loss: 0.3265
# Epoch 39: val_dice_coef improved from 0.66039 to 0.66385, saving model to best_unet.keras
#
# Epoch 39: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 382ms/step - accuracy: 0.9579 - dice_coef: 0.6656 - iou_coef: 0.5140 - loss: 0.3344 - val_accuracy: 0.9500 - val_dice_coef: 0.6638 - val_iou_coef: 0.5189 - val_loss: 0.3414 - learning_rate: 5.0000e-05
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9568 - dice_coef: 0.6778 - iou_coef: 0.5310 - loss: 0.3222
# Epoch 40: val_dice_coef did not improve from 0.66385
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 372ms/step - accuracy: 0.9577 - dice_coef: 0.6719 - iou_coef: 0.5227 - loss: 0.3281 - val_accuracy: 0.9478 - val_dice_coef: 0.6379 - val_iou_coef: 0.4933 - val_loss: 0.3690 - learning_rate: 5.0000e-05
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9598 - dice_coef: 0.6842 - iou_coef: 0.5341 - loss: 0.3158
# Epoch 41: val_dice_coef did not improve from 0.66385
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 375ms/step - accuracy: 0.9602 - dice_coef: 0.6875 - iou_coef: 0.5372 - loss: 0.3125 - val_accuracy: 0.9490 - val_dice_coef: 0.6562 - val_iou_coef: 0.5114 - val_loss: 0.3492 - learning_rate: 5.0000e-05
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9649 - dice_coef: 0.7175 - iou_coef: 0.5710 - loss: 0.2825
# Epoch 42: val_dice_coef improved from 0.66385 to 0.66511, saving model to best_unet.keras
#
# Epoch 42: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 389ms/step - accuracy: 0.9600 - dice_coef: 0.6912 - iou_coef: 0.5418 - loss: 0.3088 - val_accuracy: 0.9495 - val_dice_coef: 0.6651 - val_iou_coef: 0.5181 - val_loss: 0.3393 - learning_rate: 5.0000e-05
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.9597 - dice_coef: 0.7104 - iou_coef: 0.5648 - loss: 0.2896
# Epoch 43: val_dice_coef improved from 0.66511 to 0.67740, saving model to best_unet.keras
#
# Epoch 43: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 388ms/step - accuracy: 0.9620 - dice_coef: 0.7014 - iou_coef: 0.5548 - loss: 0.2986 - val_accuracy: 0.9490 - val_dice_coef: 0.6774 - val_iou_coef: 0.5322 - val_loss: 0.3271 - learning_rate: 5.0000e-05
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9628 - dice_coef: 0.7305 - iou_coef: 0.5843 - loss: 0.2695
# Epoch 44: val_dice_coef did not improve from 0.67740
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 374ms/step - accuracy: 0.9610 - dice_coef: 0.6917 - iou_coef: 0.5405 - loss: 0.3083 - val_accuracy: 0.9495 - val_dice_coef: 0.6723 - val_iou_coef: 0.5281 - val_loss: 0.3330 - learning_rate: 5.0000e-05
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9586 - dice_coef: 0.6791 - iou_coef: 0.5261 - loss: 0.3209
# Epoch 45: val_dice_coef improved from 0.67740 to 0.68199, saving model to best_unet.keras
#
# Epoch 45: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 384ms/step - accuracy: 0.9598 - dice_coef: 0.6881 - iou_coef: 0.5365 - loss: 0.3119 - val_accuracy: 0.9482 - val_dice_coef: 0.6820 - val_iou_coef: 0.5382 - val_loss: 0.3229 - learning_rate: 5.0000e-05
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9629 - dice_coef: 0.7048 - iou_coef: 0.5565 - loss: 0.2952
# Epoch 46: val_dice_coef improved from 0.68199 to 0.69782, saving model to best_unet.keras
#
# Epoch 46: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 389ms/step - accuracy: 0.9618 - dice_coef: 0.6890 - iou_coef: 0.5371 - loss: 0.3110 - val_accuracy: 0.9502 - val_dice_coef: 0.6978 - val_iou_coef: 0.5579 - val_loss: 0.3067 - learning_rate: 5.0000e-05
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9636 - dice_coef: 0.6938 - iou_coef: 0.5486 - loss: 0.3062
# Epoch 47: val_dice_coef improved from 0.69782 to 0.69917, saving model to best_unet.keras
#
# Epoch 47: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 385ms/step - accuracy: 0.9609 - dice_coef: 0.6929 - iou_coef: 0.5467 - loss: 0.3071 - val_accuracy: 0.9503 - val_dice_coef: 0.6992 - val_iou_coef: 0.5592 - val_loss: 0.3056 - learning_rate: 5.0000e-05
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9596 - dice_coef: 0.6905 - iou_coef: 0.5456 - loss: 0.3095
# Epoch 48: val_dice_coef did not improve from 0.69917
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 374ms/step - accuracy: 0.9610 - dice_coef: 0.6953 - iou_coef: 0.5502 - loss: 0.3047 - val_accuracy: 0.9490 - val_dice_coef: 0.6907 - val_iou_coef: 0.5449 - val_loss: 0.3131 - learning_rate: 5.0000e-05
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9610 - dice_coef: 0.6801 - iou_coef: 0.5305 - loss: 0.3199
# Epoch 49: val_dice_coef did not improve from 0.69917
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 373ms/step - accuracy: 0.9601 - dice_coef: 0.6903 - iou_coef: 0.5424 - loss: 0.3097 - val_accuracy: 0.9482 - val_dice_coef: 0.6623 - val_iou_coef: 0.5143 - val_loss: 0.3416 - learning_rate: 5.0000e-05
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9594 - dice_coef: 0.6984 - iou_coef: 0.5504 - loss: 0.3016
# Epoch 50: val_dice_coef did not improve from 0.69917
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 374ms/step - accuracy: 0.9614 - dice_coef: 0.6969 - iou_coef: 0.5508 - loss: 0.3031 - val_accuracy: 0.9508 - val_dice_coef: 0.6839 - val_iou_coef: 0.5446 - val_loss: 0.3217 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 47.

# %%
show_prediction(model, val_pairs[8])
show_prediction(model, val_pairs[9])
show_prediction(model, val_pairs[79])
show_prediction(model, val_pairs[80])
