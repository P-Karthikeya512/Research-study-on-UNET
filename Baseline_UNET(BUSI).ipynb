# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Research-study-on-UNET/blob/main/Baseline_UNET(BUSI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
EPOCHS = 50
SEED = 42

ZIP_PATH = "/content/Dataset_BUSI_with_GT.zip"
EXTRACT_DIR = "/content/BUSI_DATASET"

import zipfile
from pathlib import Path

with zipfile.ZipFile(ZIP_PATH, "r") as z:
    z.extractall(EXTRACT_DIR)

def find_dataset_root(base_dir):
    for root, dirs, files in os.walk(base_dir):
        d = {x.lower() for x in dirs}
        if {"benign", "malignant", "normal"}.issubset(d):
            return root
    raise FileNotFoundError("Could not find benign/malignant/normal folders.")

DATASET_DIR = find_dataset_root(EXTRACT_DIR)

print("Dataset:", DATASET_DIR)

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Dataset: /content/BUSI_DATASET/Dataset_BUSI_with_GT

# %%
def get_pairs(dataset_dir):
    pairs = []

    for cls in ["benign", "malignant", "normal"]:
        folder = os.path.join(dataset_dir, cls)
        for f in sorted(os.listdir(folder)):
            path = os.path.join(folder, f)
            if not os.path.isfile(path):
                continue
            ext = Path(f).suffix.lower()
            if ext not in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]:
                continue
            stem = Path(f).stem
            if "_mask" in stem.lower():
                continue
            mask = os.path.join(folder, stem + "_mask.png")
            if os.path.exists(mask):
                pairs.append((path, mask))
            else:
                print("No mask:", path)

    return pairs


# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    if isinstance(img_path, bytes):
        img_path = img_path.decode()

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode()

    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")

    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(DATASET_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
# Out:
# Total paired samples: 780
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100)_mask.png

# %%
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

labels = [Path(img).parent.name for img, mask in pairs]
train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED, stratify=labels)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))

# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# =========================
# U-NET BUILDING BLOCKS
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p

def up_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x

# =========================
# BUILD U-NET
# =========================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    s1, p1 = down_block(inputs, 32)
    s2, p2 = down_block(p1, 64)
    s3, p3 = down_block(p2, 128)
    s4, p4 = down_block(p3, 256)

    bottleneck = conv_block(p4, 512)

    u1 = up_block(bottleneck, s4, 256)
    u2 = up_block(u1, s3, 128)
    u3 = up_block(u2, s2, 64)
    u4 = up_block(u3, s1, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary")
    return model

model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    # Accuracy
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[9])
show_prediction(model, val_pairs[10])
# Out:
# Train samples: 624
# Val samples: 156
# Model: "UNet_Binary"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 256, 256,  │        896 │ input_layer_5[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_90 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_90[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_96[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_91 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 128, 128,  │          0 │ re_lu_91[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 128, 128,  │          0 │ max_pooling2d_20… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 128, 128,  │     18,496 │ dropout_40[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_97[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_92 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_92[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_98[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_93 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 64, 64,    │          0 │ re_lu_93[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_41          │ (None, 64, 64,    │          0 │ max_pooling2d_21… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 64, 64,    │     73,856 │ dropout_41[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_99[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_94 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 64, 64,    │    147,584 │ re_lu_94[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_100[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_95 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 32, 32,    │          0 │ re_lu_95[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 32, 32,    │          0 │ max_pooling2d_22… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 32, 32,    │    295,168 │ dropout_42[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_101[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_96 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 32, 32,    │    590,080 │ re_lu_96[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_102[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_97 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 16, 16,    │          0 │ re_lu_97[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_43          │ (None, 16, 16,    │          0 │ max_pooling2d_23… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 16, 16,    │  1,180,160 │ dropout_43[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_103[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_98 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 16, 16,    │  2,359,808 │ re_lu_98[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_104[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_99 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_20 │ (None, 32, 32,    │    524,544 │ re_lu_99[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ re_lu_97[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_44          │ (None, 32, 32,    │          0 │ concatenate_20[0… │
# │ (Dropout)           │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_105 (Conv2D) │ (None, 32, 32,    │  1,179,904 │ dropout_44[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_105[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_100 (ReLU)    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_106 (Conv2D) │ (None, 32, 32,    │    590,080 │ re_lu_100[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_106[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_101 (ReLU)    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_21 │ (None, 64, 64,    │    131,200 │ re_lu_101[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_21      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ re_lu_95[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_45          │ (None, 64, 64,    │          0 │ concatenate_21[0… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_107 (Conv2D) │ (None, 64, 64,    │    295,040 │ dropout_45[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_107[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_102 (ReLU)    │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_108 (Conv2D) │ (None, 64, 64,    │    147,584 │ re_lu_102[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_108[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_103 (ReLU)    │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_22 │ (None, 128, 128,  │     32,832 │ re_lu_103[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_22      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ re_lu_93[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_46          │ (None, 128, 128,  │          0 │ concatenate_22[0… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_109 (Conv2D) │ (None, 128, 128,  │     73,792 │ dropout_46[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_109[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_104 (ReLU)    │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_110 (Conv2D) │ (None, 128, 128,  │     36,928 │ re_lu_104[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_110[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_105 (ReLU)    │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_23 │ (None, 256, 256,  │      8,224 │ re_lu_105[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ re_lu_91[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 256, 256,  │          0 │ concatenate_23[0… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_111 (Conv2D) │ (None, 256, 256,  │     18,464 │ dropout_47[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_111[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_106 (ReLU)    │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_112 (Conv2D) │ (None, 256, 256,  │      9,248 │ re_lu_106[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_112[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_107 (ReLU)    │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_113 (Conv2D) │ (None, 256, 256,  │         33 │ re_lu_107[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,771,873 (29.65 MB)
#  Trainable params: 7,765,985 (29.62 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.2724 - dice_coef: 0.1309 - iou_coef: 0.0705 - loss: 1.8687
# Epoch 1: val_dice_coef improved from None to 0.16462, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 51s 242ms/step - accuracy: 0.4479 - dice_coef: 0.1336 - iou_coef: 0.0722 - loss: 1.6886 - val_accuracy: 0.5229 - val_dice_coef: 0.1646 - val_iou_coef: 0.0910 - val_loss: 1.6299 - learning_rate: 1.0000e-04
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8916 - dice_coef: 0.1352 - iou_coef: 0.0732 - loss: 1.3880
# Epoch 2: val_dice_coef did not improve from 0.16462
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 209ms/step - accuracy: 0.9081 - dice_coef: 0.1335 - iou_coef: 0.0723 - loss: 1.3587 - val_accuracy: 0.9061 - val_dice_coef: 0.1503 - val_iou_coef: 0.0821 - val_loss: 1.3567 - learning_rate: 1.0000e-04
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9291 - dice_coef: 0.1312 - iou_coef: 0.0708 - loss: 1.2929
# Epoch 3: val_dice_coef did not improve from 0.16462
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 15s 195ms/step - accuracy: 0.9252 - dice_coef: 0.1368 - iou_coef: 0.0742 - loss: 1.2828 - val_accuracy: 0.9095 - val_dice_coef: 0.1477 - val_iou_coef: 0.0805 - val_loss: 1.2896 - learning_rate: 1.0000e-04
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9110 - dice_coef: 0.1526 - iou_coef: 0.0835 - loss: 1.2563
# Epoch 4: val_dice_coef did not improve from 0.16462
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 204ms/step - accuracy: 0.9121 - dice_coef: 0.1511 - iou_coef: 0.0826 - loss: 1.2506 - val_accuracy: 0.9103 - val_dice_coef: 0.1452 - val_iou_coef: 0.0789 - val_loss: 1.2353 - learning_rate: 1.0000e-04
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9173 - dice_coef: 0.1745 - iou_coef: 0.0965 - loss: 1.1818
# Epoch 5: val_dice_coef improved from 0.16462 to 0.19464, saving model to best_unet.keras
#
# Epoch 5: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 18s 225ms/step - accuracy: 0.9082 - dice_coef: 0.1952 - iou_coef: 0.1095 - loss: 1.1607 - val_accuracy: 0.8742 - val_dice_coef: 0.1946 - val_iou_coef: 0.1089 - val_loss: 1.2252 - learning_rate: 1.0000e-04
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9144 - dice_coef: 0.2170 - iou_coef: 0.1232 - loss: 1.1173
# Epoch 6: val_dice_coef did not improve from 0.19464
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 19s 199ms/step - accuracy: 0.9151 - dice_coef: 0.2290 - iou_coef: 0.1312 - loss: 1.0980 - val_accuracy: 0.9161 - val_dice_coef: 0.1848 - val_iou_coef: 0.1025 - val_loss: 1.1570 - learning_rate: 1.0000e-04
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9185 - dice_coef: 0.2465 - iou_coef: 0.1431 - loss: 1.0626
# Epoch 7: val_dice_coef improved from 0.19464 to 0.23226, saving model to best_unet.keras
#
# Epoch 7: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9169 - dice_coef: 0.2526 - iou_coef: 0.1466 - loss: 1.0538 - val_accuracy: 0.9248 - val_dice_coef: 0.2323 - val_iou_coef: 0.1330 - val_loss: 1.0756 - learning_rate: 1.0000e-04
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9216 - dice_coef: 0.2711 - iou_coef: 0.1588 - loss: 1.0191
# Epoch 8: val_dice_coef improved from 0.23226 to 0.23541, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 18s 227ms/step - accuracy: 0.9226 - dice_coef: 0.2756 - iou_coef: 0.1622 - loss: 1.0092 - val_accuracy: 0.9264 - val_dice_coef: 0.2354 - val_iou_coef: 0.1361 - val_loss: 1.0474 - learning_rate: 1.0000e-04
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9172 - dice_coef: 0.3009 - iou_coef: 0.1797 - loss: 0.9884
# Epoch 9: val_dice_coef improved from 0.23541 to 0.25475, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 18s 226ms/step - accuracy: 0.9226 - dice_coef: 0.2874 - iou_coef: 0.1702 - loss: 0.9889 - val_accuracy: 0.9259 - val_dice_coef: 0.2547 - val_iou_coef: 0.1482 - val_loss: 1.0138 - learning_rate: 1.0000e-04
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9302 - dice_coef: 0.3232 - iou_coef: 0.1958 - loss: 0.9294
# Epoch 10: val_dice_coef did not improve from 0.25475
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 201ms/step - accuracy: 0.9289 - dice_coef: 0.3079 - iou_coef: 0.1853 - loss: 0.9454 - val_accuracy: 0.9256 - val_dice_coef: 0.2357 - val_iou_coef: 0.1363 - val_loss: 1.0299 - learning_rate: 1.0000e-04
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9304 - dice_coef: 0.3238 - iou_coef: 0.1967 - loss: 0.9223
# Epoch 11: val_dice_coef improved from 0.25475 to 0.27784, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.9319 - dice_coef: 0.3223 - iou_coef: 0.1951 - loss: 0.9194 - val_accuracy: 0.9301 - val_dice_coef: 0.2778 - val_iou_coef: 0.1655 - val_loss: 0.9760 - learning_rate: 1.0000e-04
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9374 - dice_coef: 0.3426 - iou_coef: 0.2107 - loss: 0.8832
# Epoch 12: val_dice_coef improved from 0.27784 to 0.31506, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 210ms/step - accuracy: 0.9370 - dice_coef: 0.3466 - iou_coef: 0.2137 - loss: 0.8784 - val_accuracy: 0.9332 - val_dice_coef: 0.3151 - val_iou_coef: 0.1930 - val_loss: 0.9203 - learning_rate: 1.0000e-04
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9333 - dice_coef: 0.3754 - iou_coef: 0.2354 - loss: 0.8508
# Epoch 13: val_dice_coef did not improve from 0.31506
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 202ms/step - accuracy: 0.9384 - dice_coef: 0.3654 - iou_coef: 0.2274 - loss: 0.8519 - val_accuracy: 0.9284 - val_dice_coef: 0.2849 - val_iou_coef: 0.1711 - val_loss: 0.9618 - learning_rate: 1.0000e-04
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9393 - dice_coef: 0.3727 - iou_coef: 0.2328 - loss: 0.8369
# Epoch 14: val_dice_coef improved from 0.31506 to 0.37491, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 226ms/step - accuracy: 0.9387 - dice_coef: 0.3738 - iou_coef: 0.2338 - loss: 0.8364 - val_accuracy: 0.9361 - val_dice_coef: 0.3749 - val_iou_coef: 0.2387 - val_loss: 0.8484 - learning_rate: 1.0000e-04
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9467 - dice_coef: 0.4051 - iou_coef: 0.2577 - loss: 0.7847
# Epoch 15: val_dice_coef did not improve from 0.37491
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9439 - dice_coef: 0.4069 - iou_coef: 0.2590 - loss: 0.7875 - val_accuracy: 0.9346 - val_dice_coef: 0.3503 - val_iou_coef: 0.2226 - val_loss: 0.8798 - learning_rate: 1.0000e-04
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9451 - dice_coef: 0.4031 - iou_coef: 0.2581 - loss: 0.7853
# Epoch 16: val_dice_coef improved from 0.37491 to 0.42127, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 211ms/step - accuracy: 0.9404 - dice_coef: 0.4028 - iou_coef: 0.2575 - loss: 0.7934 - val_accuracy: 0.9383 - val_dice_coef: 0.4213 - val_iou_coef: 0.2758 - val_loss: 0.7899 - learning_rate: 1.0000e-04
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9440 - dice_coef: 0.4054 - iou_coef: 0.2593 - loss: 0.7818
# Epoch 17: val_dice_coef did not improve from 0.42127
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - accuracy: 0.9448 - dice_coef: 0.4242 - iou_coef: 0.2741 - loss: 0.7587 - val_accuracy: 0.9364 - val_dice_coef: 0.4002 - val_iou_coef: 0.2601 - val_loss: 0.8267 - learning_rate: 1.0000e-04
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9458 - dice_coef: 0.4534 - iou_coef: 0.2967 - loss: 0.7273
# Epoch 18: val_dice_coef improved from 0.42127 to 0.42527, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 226ms/step - accuracy: 0.9488 - dice_coef: 0.4548 - iou_coef: 0.2983 - loss: 0.7187 - val_accuracy: 0.9374 - val_dice_coef: 0.4253 - val_iou_coef: 0.2801 - val_loss: 0.7976 - learning_rate: 1.0000e-04
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9442 - dice_coef: 0.4264 - iou_coef: 0.2767 - loss: 0.7585
# Epoch 19: val_dice_coef improved from 0.42527 to 0.46484, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 20s 217ms/step - accuracy: 0.9440 - dice_coef: 0.4452 - iou_coef: 0.2917 - loss: 0.7360 - val_accuracy: 0.9410 - val_dice_coef: 0.4648 - val_iou_coef: 0.3158 - val_loss: 0.7461 - learning_rate: 1.0000e-04
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9517 - dice_coef: 0.4847 - iou_coef: 0.3230 - loss: 0.6753
# Epoch 20: val_dice_coef improved from 0.46484 to 0.50198, saving model to best_unet.keras
#
# Epoch 20: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 213ms/step - accuracy: 0.9488 - dice_coef: 0.4784 - iou_coef: 0.3189 - loss: 0.6909 - val_accuracy: 0.9405 - val_dice_coef: 0.5020 - val_iou_coef: 0.3450 - val_loss: 0.7041 - learning_rate: 1.0000e-04
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9494 - dice_coef: 0.4745 - iou_coef: 0.3171 - loss: 0.6907
# Epoch 21: val_dice_coef did not improve from 0.50198
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - accuracy: 0.9483 - dice_coef: 0.4755 - iou_coef: 0.3178 - loss: 0.6928 - val_accuracy: 0.9352 - val_dice_coef: 0.4253 - val_iou_coef: 0.2840 - val_loss: 0.7978 - learning_rate: 1.0000e-04
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9414 - dice_coef: 0.4789 - iou_coef: 0.3202 - loss: 0.7069
# Epoch 22: val_dice_coef improved from 0.50198 to 0.50481, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 222ms/step - accuracy: 0.9479 - dice_coef: 0.4913 - iou_coef: 0.3325 - loss: 0.6774 - val_accuracy: 0.9451 - val_dice_coef: 0.5048 - val_iou_coef: 0.3490 - val_loss: 0.6867 - learning_rate: 1.0000e-04
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9513 - dice_coef: 0.4925 - iou_coef: 0.3339 - loss: 0.6708
# Epoch 23: val_dice_coef did not improve from 0.50481
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.9513 - dice_coef: 0.5083 - iou_coef: 0.3473 - loss: 0.6508 - val_accuracy: 0.9394 - val_dice_coef: 0.4508 - val_iou_coef: 0.3062 - val_loss: 0.7681 - learning_rate: 1.0000e-04
# Epoch 24/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9578 - dice_coef: 0.5462 - iou_coef: 0.3817 - loss: 0.5992
# Epoch 24: val_dice_coef did not improve from 0.50481
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 222ms/step - accuracy: 0.9522 - dice_coef: 0.5205 - iou_coef: 0.3598 - loss: 0.6396 - val_accuracy: 0.9431 - val_dice_coef: 0.4808 - val_iou_coef: 0.3324 - val_loss: 0.7215 - learning_rate: 1.0000e-04
# Epoch 25/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9567 - dice_coef: 0.5410 - iou_coef: 0.3757 - loss: 0.6016
# Epoch 25: val_dice_coef improved from 0.50481 to 0.51395, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - accuracy: 0.9529 - dice_coef: 0.5288 - iou_coef: 0.3657 - loss: 0.6267 - val_accuracy: 0.9446 - val_dice_coef: 0.5139 - val_iou_coef: 0.3594 - val_loss: 0.6754 - learning_rate: 1.0000e-04
# Epoch 26/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9487 - dice_coef: 0.5406 - iou_coef: 0.3801 - loss: 0.6208
# Epoch 26: val_dice_coef did not improve from 0.51395
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 204ms/step - accuracy: 0.9513 - dice_coef: 0.5289 - iou_coef: 0.3675 - loss: 0.6282 - val_accuracy: 0.9355 - val_dice_coef: 0.4304 - val_iou_coef: 0.2919 - val_loss: 0.8036 - learning_rate: 1.0000e-04
# Epoch 27/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9480 - dice_coef: 0.5143 - iou_coef: 0.3551 - loss: 0.6506
# Epoch 27: val_dice_coef improved from 0.51395 to 0.53551, saving model to best_unet.keras
#
# Epoch 27: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - accuracy: 0.9507 - dice_coef: 0.5281 - iou_coef: 0.3664 - loss: 0.6303 - val_accuracy: 0.9446 - val_dice_coef: 0.5355 - val_iou_coef: 0.3832 - val_loss: 0.6701 - learning_rate: 1.0000e-04
# Epoch 28/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9504 - dice_coef: 0.5049 - iou_coef: 0.3496 - loss: 0.6542
# Epoch 28: val_dice_coef improved from 0.53551 to 0.59408, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 213ms/step - accuracy: 0.9506 - dice_coef: 0.5322 - iou_coef: 0.3720 - loss: 0.6258 - val_accuracy: 0.9469 - val_dice_coef: 0.5941 - val_iou_coef: 0.4357 - val_loss: 0.5928 - learning_rate: 1.0000e-04
# Epoch 29/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9549 - dice_coef: 0.5560 - iou_coef: 0.3955 - loss: 0.5943
# Epoch 29: val_dice_coef did not improve from 0.59408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 204ms/step - accuracy: 0.9539 - dice_coef: 0.5586 - iou_coef: 0.3974 - loss: 0.5962 - val_accuracy: 0.9482 - val_dice_coef: 0.5670 - val_iou_coef: 0.4138 - val_loss: 0.6222 - learning_rate: 1.0000e-04
# Epoch 30/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9514 - dice_coef: 0.5437 - iou_coef: 0.3832 - loss: 0.6104
# Epoch 30: val_dice_coef did not improve from 0.59408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 220ms/step - accuracy: 0.9507 - dice_coef: 0.5422 - iou_coef: 0.3840 - loss: 0.6166 - val_accuracy: 0.9275 - val_dice_coef: 0.5222 - val_iou_coef: 0.3644 - val_loss: 0.7035 - learning_rate: 1.0000e-04
# Epoch 31/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9545 - dice_coef: 0.5418 - iou_coef: 0.3792 - loss: 0.6091
# Epoch 31: val_dice_coef did not improve from 0.59408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - accuracy: 0.9515 - dice_coef: 0.5541 - iou_coef: 0.3932 - loss: 0.6019 - val_accuracy: 0.9414 - val_dice_coef: 0.5264 - val_iou_coef: 0.3738 - val_loss: 0.6895 - learning_rate: 1.0000e-04
# Epoch 32/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9530 - dice_coef: 0.5639 - iou_coef: 0.4027 - loss: 0.5873
# Epoch 32: val_dice_coef did not improve from 0.59408
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9534 - dice_coef: 0.5640 - iou_coef: 0.4043 - loss: 0.5860 - val_accuracy: 0.9451 - val_dice_coef: 0.5640 - val_iou_coef: 0.4095 - val_loss: 0.6348 - learning_rate: 1.0000e-04
# Epoch 33/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9584 - dice_coef: 0.5995 - iou_coef: 0.4381 - loss: 0.5358
# Epoch 33: val_dice_coef did not improve from 0.59408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9565 - dice_coef: 0.5898 - iou_coef: 0.4281 - loss: 0.5528 - val_accuracy: 0.9465 - val_dice_coef: 0.5763 - val_iou_coef: 0.4220 - val_loss: 0.6224 - learning_rate: 5.0000e-05
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9593 - dice_coef: 0.5969 - iou_coef: 0.4328 - loss: 0.5394
# Epoch 34: val_dice_coef did not improve from 0.59408
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9589 - dice_coef: 0.6114 - iou_coef: 0.4470 - loss: 0.5266 - val_accuracy: 0.9468 - val_dice_coef: 0.5735 - val_iou_coef: 0.4216 - val_loss: 0.6268 - learning_rate: 5.0000e-05
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9623 - dice_coef: 0.6160 - iou_coef: 0.4543 - loss: 0.5143
# Epoch 35: val_dice_coef improved from 0.59408 to 0.59611, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 18s 224ms/step - accuracy: 0.9587 - dice_coef: 0.6036 - iou_coef: 0.4422 - loss: 0.5389 - val_accuracy: 0.9471 - val_dice_coef: 0.5961 - val_iou_coef: 0.4431 - val_loss: 0.5994 - learning_rate: 5.0000e-05
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9586 - dice_coef: 0.6244 - iou_coef: 0.4610 - loss: 0.5162
# Epoch 36: val_dice_coef did not improve from 0.59611
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9577 - dice_coef: 0.6072 - iou_coef: 0.4453 - loss: 0.5361 - val_accuracy: 0.9432 - val_dice_coef: 0.5440 - val_iou_coef: 0.3949 - val_loss: 0.6707 - learning_rate: 5.0000e-05
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9581 - dice_coef: 0.6020 - iou_coef: 0.4401 - loss: 0.5399
# Epoch 37: val_dice_coef did not improve from 0.59611
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9586 - dice_coef: 0.6123 - iou_coef: 0.4502 - loss: 0.5270 - val_accuracy: 0.9462 - val_dice_coef: 0.5710 - val_iou_coef: 0.4194 - val_loss: 0.6290 - learning_rate: 5.0000e-05
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9595 - dice_coef: 0.6005 - iou_coef: 0.4398 - loss: 0.5395
# Epoch 38: val_dice_coef did not improve from 0.59611
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 204ms/step - accuracy: 0.9591 - dice_coef: 0.6087 - iou_coef: 0.4469 - loss: 0.5311 - val_accuracy: 0.9455 - val_dice_coef: 0.5823 - val_iou_coef: 0.4299 - val_loss: 0.6195 - learning_rate: 5.0000e-05
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9634 - dice_coef: 0.6121 - iou_coef: 0.4502 - loss: 0.5158
# Epoch 39: val_dice_coef did not improve from 0.59611
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - accuracy: 0.9579 - dice_coef: 0.6070 - iou_coef: 0.4449 - loss: 0.5350 - val_accuracy: 0.9456 - val_dice_coef: 0.5716 - val_iou_coef: 0.4210 - val_loss: 0.6359 - learning_rate: 5.0000e-05
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9584 - dice_coef: 0.6150 - iou_coef: 0.4554 - loss: 0.5253
# Epoch 40: val_dice_coef did not improve from 0.59611
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - accuracy: 0.9593 - dice_coef: 0.6148 - iou_coef: 0.4555 - loss: 0.5239 - val_accuracy: 0.9460 - val_dice_coef: 0.5856 - val_iou_coef: 0.4346 - val_loss: 0.6142 - learning_rate: 2.5000e-05
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9610 - dice_coef: 0.6367 - iou_coef: 0.4763 - loss: 0.4964
# Epoch 41: val_dice_coef did not improve from 0.59611
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 204ms/step - accuracy: 0.9606 - dice_coef: 0.6374 - iou_coef: 0.4773 - loss: 0.4952 - val_accuracy: 0.9474 - val_dice_coef: 0.5961 - val_iou_coef: 0.4440 - val_loss: 0.5994 - learning_rate: 2.5000e-05
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9640 - dice_coef: 0.6533 - iou_coef: 0.4938 - loss: 0.4671
# Epoch 42: val_dice_coef improved from 0.59611 to 0.61103, saving model to best_unet.keras
#
# Epoch 42: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - accuracy: 0.9598 - dice_coef: 0.6304 - iou_coef: 0.4706 - loss: 0.5073 - val_accuracy: 0.9478 - val_dice_coef: 0.6110 - val_iou_coef: 0.4573 - val_loss: 0.5808 - learning_rate: 2.5000e-05
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9603 - dice_coef: 0.6569 - iou_coef: 0.4991 - loss: 0.4762
# Epoch 43: val_dice_coef did not improve from 0.61103
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - accuracy: 0.9612 - dice_coef: 0.6378 - iou_coef: 0.4785 - loss: 0.4941 - val_accuracy: 0.9473 - val_dice_coef: 0.5980 - val_iou_coef: 0.4465 - val_loss: 0.6032 - learning_rate: 2.5000e-05
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9619 - dice_coef: 0.6667 - iou_coef: 0.5060 - loss: 0.4616
# Epoch 44: val_dice_coef did not improve from 0.61103
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 219ms/step - accuracy: 0.9606 - dice_coef: 0.6360 - iou_coef: 0.4740 - loss: 0.4976 - val_accuracy: 0.9481 - val_dice_coef: 0.6007 - val_iou_coef: 0.4489 - val_loss: 0.5975 - learning_rate: 2.5000e-05
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9597 - dice_coef: 0.6305 - iou_coef: 0.4701 - loss: 0.5111
# Epoch 45: val_dice_coef did not improve from 0.61103
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 212ms/step - accuracy: 0.9604 - dice_coef: 0.6363 - iou_coef: 0.4762 - loss: 0.4987 - val_accuracy: 0.9467 - val_dice_coef: 0.5956 - val_iou_coef: 0.4436 - val_loss: 0.6058 - learning_rate: 2.5000e-05
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9605 - dice_coef: 0.6360 - iou_coef: 0.4754 - loss: 0.4999
# Epoch 46: val_dice_coef improved from 0.61103 to 0.61655, saving model to best_unet.keras
#
# Epoch 46: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 213ms/step - accuracy: 0.9602 - dice_coef: 0.6234 - iou_coef: 0.4617 - loss: 0.5130 - val_accuracy: 0.9479 - val_dice_coef: 0.6166 - val_iou_coef: 0.4645 - val_loss: 0.5806 - learning_rate: 2.5000e-05
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9655 - dice_coef: 0.6447 - iou_coef: 0.4890 - loss: 0.4752
# Epoch 47: val_dice_coef did not improve from 0.61655
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9622 - dice_coef: 0.6397 - iou_coef: 0.4825 - loss: 0.4914 - val_accuracy: 0.9479 - val_dice_coef: 0.6152 - val_iou_coef: 0.4628 - val_loss: 0.5815 - learning_rate: 2.5000e-05
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9586 - dice_coef: 0.6284 - iou_coef: 0.4711 - loss: 0.5115
# Epoch 48: val_dice_coef did not improve from 0.61655
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 16s 203ms/step - accuracy: 0.9602 - dice_coef: 0.6357 - iou_coef: 0.4782 - loss: 0.4985 - val_accuracy: 0.9472 - val_dice_coef: 0.6126 - val_iou_coef: 0.4584 - val_loss: 0.5891 - learning_rate: 2.5000e-05
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9640 - dice_coef: 0.6386 - iou_coef: 0.4813 - loss: 0.4827
# Epoch 49: val_dice_coef did not improve from 0.61655
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 17s 210ms/step - accuracy: 0.9622 - dice_coef: 0.6416 - iou_coef: 0.4839 - loss: 0.4861 - val_accuracy: 0.9464 - val_dice_coef: 0.5984 - val_iou_coef: 0.4457 - val_loss: 0.6038 - learning_rate: 2.5000e-05
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9606 - dice_coef: 0.6460 - iou_coef: 0.4860 - loss: 0.4891
# Epoch 50: val_dice_coef improved from 0.61655 to 0.61679, saving model to best_unet.keras
#
# Epoch 50: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 226ms/step - accuracy: 0.9623 - dice_coef: 0.6443 - iou_coef: 0.4856 - loss: 0.4850 - val_accuracy: 0.9478 - val_dice_coef: 0.6168 - val_iou_coef: 0.4642 - val_loss: 0.5805 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 50.

# %%
show_prediction(model, val_pairs[80])
show_prediction(model, val_pairs[79])

# %%
empty = 0

for img_path, mask_path in pairs:
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if mask is None:
        continue

    if np.count_nonzero(mask) == 0:
        empty += 1

print("Total:", len(pairs))
print("Empty masks:", empty)
print("Non-empty masks:", len(pairs) - empty)
# Out:
# Total: 780
# Empty masks: 133
# Non-empty masks: 647

# %%
areas = []

for img_path, mask_path in pairs:
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if mask is not None:
        areas.append(np.count_nonzero(mask > 127))

areas = np.array(areas)

print("Minimum:", areas.min())
print("Median:", np.median(areas))
print("Maximum:", areas.max())
print("Empty:", np.sum(areas == 0))
# Out:
# Minimum: 0
# Median: 11539.5
# Maximum: 209121
# Empty: 133

# %%
def show_prediction_with_probability(model, pair):

    img_path, mask_path = pair

    # Load the actual image and mask
    img, mask = load_image_mask(
        img_path.encode(),
        mask_path.encode()
    )

    print("Image shape:", img.shape)
    print("Image dtype:", img.dtype)
    print("Mask shape:", mask.shape)
    print("Mask dtype:", mask.dtype)

    # Make sure model input is float32
    input_img = np.expand_dims(img, axis=0).astype(np.float32)

    print("Model input shape:", input_img.shape)
    print("Model input dtype:", input_img.dtype)

    pred = model.predict(
        input_img,
        verbose=0
    )[0]

    plt.figure(figsize=(18, 5))

    plt.subplot(1, 4, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 4, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 4, 3)
    plt.imshow(pred.squeeze(), cmap="gray", vmin=0, vmax=1)
    plt.colorbar()
    plt.title("Prediction Probability")
    plt.axis("off")

    plt.subplot(1, 4, 4)
    plt.imshow((pred > 0.5).squeeze(), cmap="gray")
    plt.title("Prediction > 0.5")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

show_prediction_with_probability(model, val_pairs[9])
# Out:
# Image shape: (256, 256, 3)
# Image dtype: float32
# Mask shape: (256, 256, 1)
# Mask dtype: float32
# Model input shape: (1, 256, 256, 3)
# Model input dtype: float32
