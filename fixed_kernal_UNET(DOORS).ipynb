# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Research-study-on-UNET/blob/main/fixed_kernal_UNET(DOORS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

prabhalakarthikeya_doors_data_path = kagglehub.dataset_download('prabhalakarthikeya/doors-data')

print('Data source import complete.')

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (128, 128)
BATCH_SIZE = 64
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/img"
MASK_DIR  = "/kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/mask"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))

print(os.listdir(IMAGE_DIR)[:5])
print(os.listdir(MASK_DIR)[:5])
# Out:
# Images : 35183
# Masks  : 35183
# ['TR_011977.png', 'TR_014931.png', 'TR_017397.png', 'TR_012869.png', 'Te2_002212.png']
# ['TR_011977.png', 'TR_014931.png', 'TR_017397.png', 'TR_012869.png', 'Te2_002212.png']

# %%
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs


pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))


# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    # Image
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    # Mask
    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    # Binary mask: 0/1
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask


def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask


# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask


# =========================
# CREATE DATASET
# =========================
pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()


def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds


train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))
# Out:
# Total paired samples: 35183
# Total paired samples: 35183
# /kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/img/TR_000001.png
# /kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/mask/TR_000001.png
#
# /kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/img/TR_000002.png
# /kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/mask/TR_000002.png
#
# /kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/img/TR_000003.png
# /kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/mask/TR_000003.png
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786941070.748721      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1786941070.752048      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Train samples: 28146
# Val samples: 7037

# %%
# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )


def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)


def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# %%
@tf.keras.utils.register_keras_serializable()
class FixedKernelLayer(layers.Layer):
    """
    Fixed non-trainable kernel bank:
    - Sobel X
    - Sobel Y
    - Laplacian

    Input:  [B, H, W, C]
    Output: [B, H, W, 3C]
    """
    def __init__(self, **kwargs):
        super().__init__(trainable=False, **kwargs)

    def build(self, input_shape):
        c = int(input_shape[-1])

        sobel_x = np.array([
            [-1, 0, 1],
            [-2, 0, 2],
            [-1, 0, 1]
        ], dtype=np.float32)

        sobel_y = np.array([
            [-1, -2, -1],
            [ 0,  0,  0],
            [ 1,  2,  1]
        ], dtype=np.float32)

        laplacian = np.array([
            [ 0,  1,  0],
            [ 1, -4,  1],
            [ 0,  1,  0]
        ], dtype=np.float32)

        def make_depthwise_kernel(base_kernel):
            k = np.zeros((3, 3, c, 1), dtype=np.float32)
            for ch in range(c):
                k[:, :, ch, 0] = base_kernel
            return tf.constant(k)

        self.k_sobel_x = make_depthwise_kernel(sobel_x)
        self.k_sobel_y = make_depthwise_kernel(sobel_y)
        self.k_lap = make_depthwise_kernel(laplacian)

        super().build(input_shape)

    def call(self, x):
        sx = tf.nn.depthwise_conv2d(
            x, self.k_sobel_x, strides=[1, 1, 1, 1], padding="SAME"
        )
        sy = tf.nn.depthwise_conv2d(
            x, self.k_sobel_y, strides=[1, 1, 1, 1], padding="SAME"
        )
        lp = tf.nn.depthwise_conv2d(
            x, self.k_lap, strides=[1, 1, 1, 1], padding="SAME"
        )
        return tf.concat([sx, sy, lp], axis=-1)

    def get_config(self):
        config = super().get_config()
        return config


# =========================================================
# FIXED KERNEL BRANCH
# =========================================================
def fixed_kernel_block(x):
    x = FixedKernelLayer()(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def merge_with_fixed_kernels(feat, filters, prefix):
    """
    For a single skip tensor:
      original feature
      + fixed-kernel response of that feature
    Then concatenate and compress with 1x1 conv.
    """
    fk = FixedKernelLayer(name=f"{prefix}_fixed")(feat)
    x = layers.Concatenate(name=f"{prefix}_concat")([feat, fk])

    x = layers.Conv2D(
        filters,
        1,
        padding="same",
        kernel_initializer="he_normal",
        name=f"{prefix}_compress"
    )(x)
    x = layers.ReLU(name=f"{prefix}_compress_relu")(x)
    return x


# =========================================================
# U-NET BLOCKS
# =========================================================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p


def up_block(x, skip, skip_fixed, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip, skip_fixed])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x


# =========================================================
# BUILD MODEL
# =========================================================
def build_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1, p1 = down_block(inputs, 32)
    c2, p2 = down_block(p1, 64)
    c3, p3 = down_block(p2, 128)
    c4, p4 = down_block(p3, 256)

    # Fixed-kernel transformed skips
    c1_star = merge_with_fixed_kernels(c1, 32, "c1")
    c2_star = merge_with_fixed_kernels(c2, 64, "c2")
    c3_star = merge_with_fixed_kernels(c3, 128, "c3")
    c4_star = merge_with_fixed_kernels(c4, 256, "c4")

    # Bottleneck
    bottleneck = conv_block(p4, 512)

    # Decoder
    u1 = up_block(bottleneck, c4, c4_star, 256)
    u2 = up_block(u1, c3, c3_star, 128)
    u3 = up_block(u2, c2, c2_star, 64)
    u4 = up_block(u3, c1, c1_star, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary_FixedKernel")
    return model


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()
# Out:
# Model: "UNet_Binary_FixedKernel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64, 64,    │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 256) │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 8, 8, 256) │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 512) │  1,180,160 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 512) │  2,359,808 │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_fixed            │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (FixedKernelLayer)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_concat           │ (None, 16, 16,    │          0 │ re_lu_7[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ c4_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress         │ (None, 16, 16,    │    262,400 │ c4_concat[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    524,544 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress_relu    │ (None, 16, 16,    │          0 │ c4_compress[0][0] │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ re_lu_7[0][0],    │
# │                     │                   │            │ c4_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ concatenate[0][0] │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │  1,769,728 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │    590,080 │ re_lu_10[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_fixed            │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_concat           │ (None, 32, 32,    │          0 │ re_lu_5[0][0],    │
# │ (Concatenate)       │ 512)              │            │ c3_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress         │ (None, 32, 32,    │     65,664 │ c3_concat[0][0]   │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │    131,200 │ re_lu_11[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress_relu    │ (None, 32, 32,    │          0 │ c3_compress[0][0] │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 384)              │            │ re_lu_5[0][0],    │
# │                     │                   │            │ c3_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ concatenate_1[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │    442,496 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    147,584 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_fixed            │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_concat           │ (None, 64, 64,    │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 256)              │            │ c2_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress         │ (None, 64, 64,    │     16,448 │ c2_concat[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │     32,832 │ re_lu_13[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress_relu    │ (None, 64, 64,    │          0 │ c2_compress[0][0] │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 192)              │            │ re_lu_3[0][0],    │
# │                     │                   │            │ c2_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_2[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    110,656 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │     36,928 │ re_lu_14[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_fixed            │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_concat           │ (None, 128, 128,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 128)              │            │ c1_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress         │ (None, 128, 128,  │      4,128 │ c1_concat[0][0]   │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      8,224 │ re_lu_15[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress_relu    │ (None, 128, 128,  │          0 │ c1_compress[0][0] │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 96)               │            │ re_lu_1[0][0],    │
# │                     │                   │            │ c1_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_3[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │     27,680 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │      9,248 │ re_lu_16[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         33 │ re_lu_17[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,903,873 (33.97 MB)
#  Trainable params: 8,897,985 (33.94 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Epoch 1/50
# 2026-08-17 04:31:48.216722: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:31:48.522866: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:31:51.434126: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:31:51.806826: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:31:52.870948: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:31:53.038033: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:31:53.992066: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:31:54.202337: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:32:14.971134: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,96,128,128]{3,2,1,0}, f32[64,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-08-17 04:32:15.541602: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.570549774s
# Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,96,128,128]{3,2,1,0}, f32[64,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# I0000 00:00:1786941146.649164     131 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 439/440 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.7299 - dice_coef: 0.5168 - iou_coef: 0.3532 - loss: 0.4832
# 2026-08-17 04:36:32.913058: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:36:33.211029: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:36:36.187896: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:36:36.551243: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:36:37.673846: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:36:37.839808: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:36:38.768441: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:36:38.986124: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-08-17 04:37:00.033742: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[50,96,128,128]{3,2,1,0}, f32[50,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-08-17 04:37:00.580051: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.546417203s
# Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[50,96,128,128]{3,2,1,0}, f32[50,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.7300 - dice_coef: 0.5169 - iou_coef: 0.3533 - loss: 0.4831
# Epoch 1: val_dice_coef improved from None to 0.60471, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 419s 774ms/step - accuracy: 0.7570 - dice_coef: 0.5830 - iou_coef: 0.4144 - loss: 0.4170 - val_accuracy: 0.7425 - val_dice_coef: 0.6047 - val_iou_coef: 0.4334 - val_loss: 0.3953 - learning_rate: 1.0000e-04
# Epoch 2/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8134 - dice_coef: 0.6688 - iou_coef: 0.5027 - loss: 0.3312
# Epoch 2: val_dice_coef improved from 0.60471 to 0.71930, saving model to best_unet.keras
#
# Epoch 2: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.8278 - dice_coef: 0.6869 - iou_coef: 0.5236 - loss: 0.3131 - val_accuracy: 0.8481 - val_dice_coef: 0.7193 - val_iou_coef: 0.5617 - val_loss: 0.2807 - learning_rate: 1.0000e-04
# Epoch 3/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.8561 - dice_coef: 0.7269 - iou_coef: 0.5710 - loss: 0.2731
# Epoch 3: val_dice_coef improved from 0.71930 to 0.75513, saving model to best_unet.keras
#
# Epoch 3: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 551ms/step - accuracy: 0.8607 - dice_coef: 0.7350 - iou_coef: 0.5812 - loss: 0.2650 - val_accuracy: 0.8717 - val_dice_coef: 0.7551 - val_iou_coef: 0.6067 - val_loss: 0.2449 - learning_rate: 1.0000e-04
# Epoch 4/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8724 - dice_coef: 0.7559 - iou_coef: 0.6076 - loss: 0.2441
# Epoch 4: val_dice_coef improved from 0.75513 to 0.77819, saving model to best_unet.keras
#
# Epoch 4: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 550ms/step - accuracy: 0.8754 - dice_coef: 0.7617 - iou_coef: 0.6151 - loss: 0.2383 - val_accuracy: 0.8859 - val_dice_coef: 0.7782 - val_iou_coef: 0.6370 - val_loss: 0.2218 - learning_rate: 1.0000e-04
# Epoch 5/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8828 - dice_coef: 0.7753 - iou_coef: 0.6332 - loss: 0.2247
# Epoch 5: val_dice_coef improved from 0.77819 to 0.79180, saving model to best_unet.keras
#
# Epoch 5: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 550ms/step - accuracy: 0.8840 - dice_coef: 0.7787 - iou_coef: 0.6377 - loss: 0.2213 - val_accuracy: 0.8919 - val_dice_coef: 0.7918 - val_iou_coef: 0.6554 - val_loss: 0.2082 - learning_rate: 1.0000e-04
# Epoch 6/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.8877 - dice_coef: 0.7871 - iou_coef: 0.6491 - loss: 0.2129
# Epoch 6: val_dice_coef improved from 0.79180 to 0.80004, saving model to best_unet.keras
#
# Epoch 6: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 550ms/step - accuracy: 0.8886 - dice_coef: 0.7891 - iou_coef: 0.6517 - loss: 0.2109 - val_accuracy: 0.8950 - val_dice_coef: 0.8000 - val_iou_coef: 0.6668 - val_loss: 0.2000 - learning_rate: 1.0000e-04
# Epoch 7/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8908 - dice_coef: 0.7945 - iou_coef: 0.6591 - loss: 0.2055
# Epoch 7: val_dice_coef improved from 0.80004 to 0.80428, saving model to best_unet.keras
#
# Epoch 7: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.8915 - dice_coef: 0.7962 - iou_coef: 0.6614 - loss: 0.2038 - val_accuracy: 0.8957 - val_dice_coef: 0.8043 - val_iou_coef: 0.6727 - val_loss: 0.1957 - learning_rate: 1.0000e-04
# Epoch 8/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8932 - dice_coef: 0.8002 - iou_coef: 0.6670 - loss: 0.1998
# Epoch 8: val_dice_coef improved from 0.80428 to 0.80861, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 550ms/step - accuracy: 0.8936 - dice_coef: 0.8013 - iou_coef: 0.6685 - loss: 0.1987 - val_accuracy: 0.8984 - val_dice_coef: 0.8086 - val_iou_coef: 0.6788 - val_loss: 0.1914 - learning_rate: 1.0000e-04
# Epoch 9/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8947 - dice_coef: 0.8040 - iou_coef: 0.6723 - loss: 0.1960
# Epoch 9: val_dice_coef improved from 0.80861 to 0.81214, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 550ms/step - accuracy: 0.8951 - dice_coef: 0.8050 - iou_coef: 0.6737 - loss: 0.1950 - val_accuracy: 0.9006 - val_dice_coef: 0.8121 - val_iou_coef: 0.6838 - val_loss: 0.1879 - learning_rate: 1.0000e-04
# Epoch 10/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8960 - dice_coef: 0.8077 - iou_coef: 0.6775 - loss: 0.1923
# Epoch 10: val_dice_coef improved from 0.81214 to 0.81418, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.8966 - dice_coef: 0.8085 - iou_coef: 0.6786 - loss: 0.1915 - val_accuracy: 0.9020 - val_dice_coef: 0.8142 - val_iou_coef: 0.6867 - val_loss: 0.1858 - learning_rate: 1.0000e-04
# Epoch 11/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8975 - dice_coef: 0.8107 - iou_coef: 0.6817 - loss: 0.1893
# Epoch 11: val_dice_coef improved from 0.81418 to 0.81760, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.8977 - dice_coef: 0.8110 - iou_coef: 0.6821 - loss: 0.1890 - val_accuracy: 0.9015 - val_dice_coef: 0.8176 - val_iou_coef: 0.6915 - val_loss: 0.1824 - learning_rate: 1.0000e-04
# Epoch 12/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8987 - dice_coef: 0.8134 - iou_coef: 0.6855 - loss: 0.1866
# Epoch 12: val_dice_coef improved from 0.81760 to 0.81952, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.8987 - dice_coef: 0.8133 - iou_coef: 0.6854 - loss: 0.1867 - val_accuracy: 0.9033 - val_dice_coef: 0.8195 - val_iou_coef: 0.6943 - val_loss: 0.1805 - learning_rate: 1.0000e-04
# Epoch 13/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8989 - dice_coef: 0.8140 - iou_coef: 0.6864 - loss: 0.1860
# Epoch 13: val_dice_coef improved from 0.81952 to 0.82044, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.8994 - dice_coef: 0.8150 - iou_coef: 0.6878 - loss: 0.1850 - val_accuracy: 0.9035 - val_dice_coef: 0.8204 - val_iou_coef: 0.6956 - val_loss: 0.1796 - learning_rate: 1.0000e-04
# Epoch 14/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8998 - dice_coef: 0.8163 - iou_coef: 0.6897 - loss: 0.1837
# Epoch 14: val_dice_coef improved from 0.82044 to 0.82218, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9002 - dice_coef: 0.8168 - iou_coef: 0.6904 - loss: 0.1832 - val_accuracy: 0.9041 - val_dice_coef: 0.8222 - val_iou_coef: 0.6981 - val_loss: 0.1778 - learning_rate: 1.0000e-04
# Epoch 15/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.9004 - dice_coef: 0.8172 - iou_coef: 0.6910 - loss: 0.1828
# Epoch 15: val_dice_coef improved from 0.82218 to 0.82296, saving model to best_unet.keras
#
# Epoch 15: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 245s 556ms/step - accuracy: 0.9008 - dice_coef: 0.8182 - iou_coef: 0.6924 - loss: 0.1818 - val_accuracy: 0.9046 - val_dice_coef: 0.8230 - val_iou_coef: 0.6992 - val_loss: 0.1770 - learning_rate: 1.0000e-04
# Epoch 16/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9012 - dice_coef: 0.8192 - iou_coef: 0.6938 - loss: 0.1808
# Epoch 16: val_dice_coef improved from 0.82296 to 0.82414, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9014 - dice_coef: 0.8197 - iou_coef: 0.6945 - loss: 0.1803 - val_accuracy: 0.9053 - val_dice_coef: 0.8241 - val_iou_coef: 0.7009 - val_loss: 0.1759 - learning_rate: 1.0000e-04
# Epoch 17/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9020 - dice_coef: 0.8207 - iou_coef: 0.6959 - loss: 0.1793
# Epoch 17: val_dice_coef improved from 0.82414 to 0.82581, saving model to best_unet.keras
#
# Epoch 17: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9019 - dice_coef: 0.8207 - iou_coef: 0.6960 - loss: 0.1793 - val_accuracy: 0.9062 - val_dice_coef: 0.8258 - val_iou_coef: 0.7034 - val_loss: 0.1742 - learning_rate: 1.0000e-04
# Epoch 18/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9026 - dice_coef: 0.8219 - iou_coef: 0.6977 - loss: 0.1781
# Epoch 18: val_dice_coef improved from 0.82581 to 0.82680, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9025 - dice_coef: 0.8219 - iou_coef: 0.6977 - loss: 0.1781 - val_accuracy: 0.9059 - val_dice_coef: 0.8268 - val_iou_coef: 0.7048 - val_loss: 0.1732 - learning_rate: 1.0000e-04
# Epoch 19/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9028 - dice_coef: 0.8220 - iou_coef: 0.6979 - loss: 0.1780
# Epoch 19: val_dice_coef improved from 0.82680 to 0.82743, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 548ms/step - accuracy: 0.9029 - dice_coef: 0.8229 - iou_coef: 0.6992 - loss: 0.1771 - val_accuracy: 0.9062 - val_dice_coef: 0.8274 - val_iou_coef: 0.7057 - val_loss: 0.1726 - learning_rate: 1.0000e-04
# Epoch 20/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9030 - dice_coef: 0.8236 - iou_coef: 0.7001 - loss: 0.1764
# Epoch 20: val_dice_coef improved from 0.82743 to 0.82795, saving model to best_unet.keras
#
# Epoch 20: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9033 - dice_coef: 0.8237 - iou_coef: 0.7004 - loss: 0.1763 - val_accuracy: 0.9071 - val_dice_coef: 0.8280 - val_iou_coef: 0.7065 - val_loss: 0.1720 - learning_rate: 1.0000e-04
# Epoch 21/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9035 - dice_coef: 0.8243 - iou_coef: 0.7011 - loss: 0.1757
# Epoch 21: val_dice_coef improved from 0.82795 to 0.82862, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9037 - dice_coef: 0.8245 - iou_coef: 0.7014 - loss: 0.1755 - val_accuracy: 0.9074 - val_dice_coef: 0.8286 - val_iou_coef: 0.7074 - val_loss: 0.1714 - learning_rate: 1.0000e-04
# Epoch 22/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9040 - dice_coef: 0.8252 - iou_coef: 0.7025 - loss: 0.1748
# Epoch 22: val_dice_coef improved from 0.82862 to 0.82879, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9040 - dice_coef: 0.8252 - iou_coef: 0.7025 - loss: 0.1748 - val_accuracy: 0.9072 - val_dice_coef: 0.8288 - val_iou_coef: 0.7077 - val_loss: 0.1712 - learning_rate: 1.0000e-04
# Epoch 23/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9040 - dice_coef: 0.8253 - iou_coef: 0.7027 - loss: 0.1747
# Epoch 23: val_dice_coef improved from 0.82879 to 0.82942, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9043 - dice_coef: 0.8259 - iou_coef: 0.7034 - loss: 0.1741 - val_accuracy: 0.9074 - val_dice_coef: 0.8294 - val_iou_coef: 0.7086 - val_loss: 0.1706 - learning_rate: 1.0000e-04
# Epoch 24/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9043 - dice_coef: 0.8259 - iou_coef: 0.7036 - loss: 0.1741
# Epoch 24: val_dice_coef improved from 0.82942 to 0.83039, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9046 - dice_coef: 0.8265 - iou_coef: 0.7043 - loss: 0.1735 - val_accuracy: 0.9082 - val_dice_coef: 0.8304 - val_iou_coef: 0.7100 - val_loss: 0.1696 - learning_rate: 1.0000e-04
# Epoch 25/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9046 - dice_coef: 0.8265 - iou_coef: 0.7044 - loss: 0.1735
# Epoch 25: val_dice_coef improved from 0.83039 to 0.83099, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9049 - dice_coef: 0.8270 - iou_coef: 0.7051 - loss: 0.1730 - val_accuracy: 0.9082 - val_dice_coef: 0.8310 - val_iou_coef: 0.7109 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 26/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9051 - dice_coef: 0.8274 - iou_coef: 0.7057 - loss: 0.1726
# Epoch 26: val_dice_coef improved from 0.83099 to 0.83133, saving model to best_unet.keras
#
# Epoch 26: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9051 - dice_coef: 0.8275 - iou_coef: 0.7058 - loss: 0.1725 - val_accuracy: 0.9082 - val_dice_coef: 0.8313 - val_iou_coef: 0.7114 - val_loss: 0.1687 - learning_rate: 1.0000e-04
# Epoch 27/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9054 - dice_coef: 0.8278 - iou_coef: 0.7063 - loss: 0.1722
# Epoch 27: val_dice_coef improved from 0.83133 to 0.83134, saving model to best_unet.keras
#
# Epoch 27: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9054 - dice_coef: 0.8280 - iou_coef: 0.7066 - loss: 0.1720 - val_accuracy: 0.9085 - val_dice_coef: 0.8313 - val_iou_coef: 0.7114 - val_loss: 0.1687 - learning_rate: 1.0000e-04
# Epoch 28/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9056 - dice_coef: 0.8287 - iou_coef: 0.7076 - loss: 0.1713
# Epoch 28: val_dice_coef improved from 0.83134 to 0.83271, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 548ms/step - accuracy: 0.9056 - dice_coef: 0.8285 - iou_coef: 0.7073 - loss: 0.1715 - val_accuracy: 0.9092 - val_dice_coef: 0.8327 - val_iou_coef: 0.7134 - val_loss: 0.1673 - learning_rate: 1.0000e-04
# Epoch 29/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9060 - dice_coef: 0.8289 - iou_coef: 0.7078 - loss: 0.1711
# Epoch 29: val_dice_coef did not improve from 0.83271
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9058 - dice_coef: 0.8289 - iou_coef: 0.7078 - loss: 0.1711 - val_accuracy: 0.9091 - val_dice_coef: 0.8323 - val_iou_coef: 0.7129 - val_loss: 0.1677 - learning_rate: 1.0000e-04
# Epoch 30/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9059 - dice_coef: 0.8292 - iou_coef: 0.7083 - loss: 0.1708
# Epoch 30: val_dice_coef did not improve from 0.83271
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9060 - dice_coef: 0.8293 - iou_coef: 0.7084 - loss: 0.1707 - val_accuracy: 0.9085 - val_dice_coef: 0.8327 - val_iou_coef: 0.7133 - val_loss: 0.1673 - learning_rate: 1.0000e-04
# Epoch 31/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.9060 - dice_coef: 0.8293 - iou_coef: 0.7084 - loss: 0.1707
# Epoch 31: val_dice_coef improved from 0.83271 to 0.83287, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 288s 655ms/step - accuracy: 0.9062 - dice_coef: 0.8297 - iou_coef: 0.7091 - loss: 0.1703 - val_accuracy: 0.9093 - val_dice_coef: 0.8329 - val_iou_coef: 0.7137 - val_loss: 0.1671 - learning_rate: 1.0000e-04
# Epoch 32/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9064 - dice_coef: 0.8303 - iou_coef: 0.7100 - loss: 0.1697
# Epoch 32: val_dice_coef improved from 0.83287 to 0.83383, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9064 - dice_coef: 0.8301 - iou_coef: 0.7096 - loss: 0.1699 - val_accuracy: 0.9096 - val_dice_coef: 0.8338 - val_iou_coef: 0.7151 - val_loss: 0.1662 - learning_rate: 1.0000e-04
# Epoch 33/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9064 - dice_coef: 0.8302 - iou_coef: 0.7098 - loss: 0.1698
# Epoch 33: val_dice_coef improved from 0.83383 to 0.83457, saving model to best_unet.keras
#
# Epoch 33: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9065 - dice_coef: 0.8304 - iou_coef: 0.7100 - loss: 0.1696 - val_accuracy: 0.9100 - val_dice_coef: 0.8346 - val_iou_coef: 0.7162 - val_loss: 0.1654 - learning_rate: 1.0000e-04
# Epoch 34/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.9066 - dice_coef: 0.8305 - iou_coef: 0.7102 - loss: 0.1695
# Epoch 34: val_dice_coef did not improve from 0.83457
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 240s 546ms/step - accuracy: 0.9068 - dice_coef: 0.8308 - iou_coef: 0.7107 - loss: 0.1692 - val_accuracy: 0.9100 - val_dice_coef: 0.8339 - val_iou_coef: 0.7152 - val_loss: 0.1661 - learning_rate: 1.0000e-04
# Epoch 35/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9071 - dice_coef: 0.8315 - iou_coef: 0.7117 - loss: 0.1685
# Epoch 35: val_dice_coef improved from 0.83457 to 0.83476, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9069 - dice_coef: 0.8311 - iou_coef: 0.7110 - loss: 0.1689 - val_accuracy: 0.9098 - val_dice_coef: 0.8348 - val_iou_coef: 0.7164 - val_loss: 0.1652 - learning_rate: 1.0000e-04
# Epoch 36/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9068 - dice_coef: 0.8311 - iou_coef: 0.7111 - loss: 0.1689
# Epoch 36: val_dice_coef did not improve from 0.83476
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9070 - dice_coef: 0.8312 - iou_coef: 0.7113 - loss: 0.1688 - val_accuracy: 0.9105 - val_dice_coef: 0.8342 - val_iou_coef: 0.7157 - val_loss: 0.1658 - learning_rate: 1.0000e-04
# Epoch 37/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9071 - dice_coef: 0.8316 - iou_coef: 0.7118 - loss: 0.1684
# Epoch 37: val_dice_coef improved from 0.83476 to 0.83507, saving model to best_unet.keras
#
# Epoch 37: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9072 - dice_coef: 0.8316 - iou_coef: 0.7118 - loss: 0.1684 - val_accuracy: 0.9106 - val_dice_coef: 0.8351 - val_iou_coef: 0.7169 - val_loss: 0.1649 - learning_rate: 1.0000e-04
# Epoch 38/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9072 - dice_coef: 0.8317 - iou_coef: 0.7120 - loss: 0.1683
# Epoch 38: val_dice_coef improved from 0.83507 to 0.83530, saving model to best_unet.keras
#
# Epoch 38: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9073 - dice_coef: 0.8318 - iou_coef: 0.7121 - loss: 0.1682 - val_accuracy: 0.9104 - val_dice_coef: 0.8353 - val_iou_coef: 0.7172 - val_loss: 0.1647 - learning_rate: 1.0000e-04
# Epoch 39/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9077 - dice_coef: 0.8325 - iou_coef: 0.7131 - loss: 0.1675
# Epoch 39: val_dice_coef improved from 0.83530 to 0.83550, saving model to best_unet.keras
#
# Epoch 39: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9074 - dice_coef: 0.8321 - iou_coef: 0.7126 - loss: 0.1679 - val_accuracy: 0.9097 - val_dice_coef: 0.8355 - val_iou_coef: 0.7175 - val_loss: 0.1645 - learning_rate: 1.0000e-04
# Epoch 40/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9076 - dice_coef: 0.8320 - iou_coef: 0.7124 - loss: 0.1680
# Epoch 40: val_dice_coef did not improve from 0.83550
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9076 - dice_coef: 0.8324 - iou_coef: 0.7130 - loss: 0.1676 - val_accuracy: 0.9104 - val_dice_coef: 0.8354 - val_iou_coef: 0.7174 - val_loss: 0.1646 - learning_rate: 1.0000e-04
# Epoch 41/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9076 - dice_coef: 0.8323 - iou_coef: 0.7129 - loss: 0.1677
# Epoch 41: val_dice_coef improved from 0.83550 to 0.83626, saving model to best_unet.keras
#
# Epoch 41: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9077 - dice_coef: 0.8326 - iou_coef: 0.7132 - loss: 0.1674 - val_accuracy: 0.9101 - val_dice_coef: 0.8363 - val_iou_coef: 0.7187 - val_loss: 0.1637 - learning_rate: 1.0000e-04
# Epoch 42/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.9076 - dice_coef: 0.8324 - iou_coef: 0.7130 - loss: 0.1676
# Epoch 42: val_dice_coef did not improve from 0.83626
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 548ms/step - accuracy: 0.9078 - dice_coef: 0.8327 - iou_coef: 0.7135 - loss: 0.1673 - val_accuracy: 0.9104 - val_dice_coef: 0.8352 - val_iou_coef: 0.7171 - val_loss: 0.1648 - learning_rate: 1.0000e-04
# Epoch 43/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9077 - dice_coef: 0.8328 - iou_coef: 0.7136 - loss: 0.1672
# Epoch 43: val_dice_coef did not improve from 0.83626
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9079 - dice_coef: 0.8329 - iou_coef: 0.7137 - loss: 0.1671 - val_accuracy: 0.9112 - val_dice_coef: 0.8362 - val_iou_coef: 0.7186 - val_loss: 0.1638 - learning_rate: 1.0000e-04
# Epoch 44/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9077 - dice_coef: 0.8327 - iou_coef: 0.7134 - loss: 0.1673
# Epoch 44: val_dice_coef improved from 0.83626 to 0.83632, saving model to best_unet.keras
#
# Epoch 44: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9080 - dice_coef: 0.8332 - iou_coef: 0.7141 - loss: 0.1668 - val_accuracy: 0.9111 - val_dice_coef: 0.8363 - val_iou_coef: 0.7188 - val_loss: 0.1637 - learning_rate: 1.0000e-04
# Epoch 45/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9083 - dice_coef: 0.8336 - iou_coef: 0.7148 - loss: 0.1664
# Epoch 45: val_dice_coef improved from 0.83632 to 0.83673, saving model to best_unet.keras
#
# Epoch 45: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9081 - dice_coef: 0.8334 - iou_coef: 0.7145 - loss: 0.1666 - val_accuracy: 0.9110 - val_dice_coef: 0.8367 - val_iou_coef: 0.7193 - val_loss: 0.1633 - learning_rate: 1.0000e-04
# Epoch 46/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9079 - dice_coef: 0.8333 - iou_coef: 0.7142 - loss: 0.1667
# Epoch 46: val_dice_coef did not improve from 0.83673
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9082 - dice_coef: 0.8337 - iou_coef: 0.7148 - loss: 0.1663 - val_accuracy: 0.9105 - val_dice_coef: 0.8365 - val_iou_coef: 0.7190 - val_loss: 0.1635 - learning_rate: 1.0000e-04
# Epoch 47/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9086 - dice_coef: 0.8344 - iou_coef: 0.7159 - loss: 0.1656
# Epoch 47: val_dice_coef did not improve from 0.83673
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9083 - dice_coef: 0.8338 - iou_coef: 0.7150 - loss: 0.1662 - val_accuracy: 0.9111 - val_dice_coef: 0.8367 - val_iou_coef: 0.7193 - val_loss: 0.1633 - learning_rate: 1.0000e-04
# Epoch 48/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9083 - dice_coef: 0.8338 - iou_coef: 0.7150 - loss: 0.1662
# Epoch 48: val_dice_coef improved from 0.83673 to 0.83733, saving model to best_unet.keras
#
# Epoch 48: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 242s 549ms/step - accuracy: 0.9084 - dice_coef: 0.8340 - iou_coef: 0.7153 - loss: 0.1660 - val_accuracy: 0.9110 - val_dice_coef: 0.8373 - val_iou_coef: 0.7202 - val_loss: 0.1627 - learning_rate: 1.0000e-04
# Epoch 49/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.9084 - dice_coef: 0.8340 - iou_coef: 0.7153 - loss: 0.1660
# Epoch 49: val_dice_coef did not improve from 0.83733
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9085 - dice_coef: 0.8341 - iou_coef: 0.7155 - loss: 0.1659 - val_accuracy: 0.9118 - val_dice_coef: 0.8371 - val_iou_coef: 0.7199 - val_loss: 0.1629 - learning_rate: 1.0000e-04
# Epoch 50/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.9087 - dice_coef: 0.8343 - iou_coef: 0.7158 - loss: 0.1657
# Epoch 50: val_dice_coef improved from 0.83733 to 0.83751, saving model to best_unet.keras
#
# Epoch 50: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 241s 547ms/step - accuracy: 0.9086 - dice_coef: 0.8343 - iou_coef: 0.7157 - loss: 0.1657 - val_accuracy: 0.9107 - val_dice_coef: 0.8375 - val_iou_coef: 0.7205 - val_loss: 0.1625 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 50.
