# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Research-study-on-UNET/blob/main/multi_skip_UNET(DOORS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

prabhalakarthikeya_doors_data_path = kagglehub.dataset_download('prabhalakarthikeya/doors-data')

print('Data source import complete.')

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (128, 128)
BATCH_SIZE = 64
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/img"
MASK_DIR  = "/kaggle/input/datasets/prabhalakarthikeya/doors-data/DOORS_data/mask"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

AUTOTUNE = tf.data.AUTOTUNE

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))

def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))
# Out:
# Images : 35183
# Masks  : 35183
# Total paired samples: 35183

# %%
# =========================
# LOAD IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask
train_pairs, val_pairs = train_test_split(
    pairs,
    test_size=0.2,
    random_state=SEED
)


def make_dataset(pairs, training=True, duplicate=False):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=AUTOTUNE)

    if duplicate:
        ds = ds.map(duplicate_mask, num_parallel_calls=AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds_single = make_dataset(train_pairs, training=True, duplicate=False)
val_ds_single   = make_dataset(val_pairs, training=False, duplicate=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))
# Out:
# Train samples: 28146
# Val samples: 7037

# %%
# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

import tensorflow as tf
from tensorflow.keras import layers, Model

# =========================
# BASIC BLOCKS
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p


def resize_to_ref(tensor, ref, name=None):
    return layers.Lambda(
        lambda t: tf.image.resize(t[0], tf.shape(t[1])[1:3], method="bilinear"),
        name=name
    )([tensor, ref])


def project_and_resize(skip, ref, filters):
    # reduce channels first
    skip = layers.Conv2D(filters, 1, padding="same", kernel_initializer="he_normal")(skip)
    skip = layers.BatchNormalization()(skip)
    skip = layers.ReLU()(skip)

    # then match spatial size
    skip = resize_to_ref(skip, ref)
    return skip


def up_block(x, skips, filters):
    # upsample decoder feature
    x = layers.UpSampling2D((2, 2), interpolation="bilinear")(x)
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    fused = [x]

    # add multiple skip tensors after aligning shape
    for s in skips:
        if s is not None:
            s = project_and_resize(s, x, filters)
            fused.append(s)

    if len(fused) > 1:
        x = layers.Concatenate()(fused)

    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x


# =========================
# BUILD MODIFIED U-NET
# =========================
def build_unet(input_shape=(128, 128, 3)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1, p1 = down_block(inputs, 32)   # 256 -> 128
    c2, p2 = down_block(p1, 64)       # 128 -> 64
    c3, p3 = down_block(p2, 128)      # 64 -> 32
    c4, p4 = down_block(p3, 256)      # 32 -> 16

    # Bottleneck
    bottleneck = conv_block(p4, 512)

    # Decoder with multi-skip fusion
    # up1 = 16 -> 32
    u1 = up_block(bottleneck, [c4], 256)

    # up2 = 32 -> 64, fuse c3 + c4
    u2 = up_block(u1, [c3, c4], 128)

    # up3 = 64 -> 128, fuse c2 + c3
    u3 = up_block(u2, [c2, c3], 64)

    # up4 = 128 -> 256, fuse c1 + c2
    u4 = up_block(u3, [c1, c2], 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_MultiSkip_Resized")
    return model


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds_single,
    validation_data=val_ds_single,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    # Accuracy
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Model: "UNet_MultiSkip_Resized"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_29 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │      9,248 │ re_lu_29[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ re_lu_30[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 64, 64,    │     18,496 │ dropout_8[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 64, 64,    │     36,928 │ re_lu_31[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ re_lu_32[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 32, 32,    │     73,856 │ dropout_9[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 32, 32,    │    147,584 │ re_lu_33[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 16, 16,    │          0 │ re_lu_34[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 16, 16,    │          0 │ max_pooling2d_6[… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 16, 16,    │    295,168 │ dropout_10[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 16, 16,    │    590,080 │ re_lu_35[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 8, 8, 256) │          0 │ re_lu_36[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 8, 8, 256) │          0 │ max_pooling2d_7[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 8, 8, 512) │  1,180,160 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 8, 8, 512) │  2,359,808 │ re_lu_37[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 16, 16,    │          0 │ re_lu_38[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 16, 16,    │  1,179,904 │ up_sampling2d_4[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 16, 16,    │     65,792 │ re_lu_36[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_40 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 16, 16,    │          0 │ re_lu_40[0][0],   │
# │                     │ 256)              │            │ re_lu_39[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 16, 16,    │          0 │ re_lu_39[0][0],   │
# │ (Concatenate)       │ 512)              │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 16, 16,    │          0 │ concatenate_4[0]… │
# │ (Dropout)           │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 16, 16,    │  1,179,904 │ dropout_12[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_41 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 16, 16,    │    590,080 │ re_lu_41[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_42 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 32, 32,    │          0 │ re_lu_42[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 32, 32,    │    295,040 │ up_sampling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 32, 32,    │     16,512 │ re_lu_34[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 16, 16,    │     32,896 │ re_lu_36[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_43 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_45 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_8 (Lambda)   │ (None, 32, 32,    │          0 │ re_lu_44[0][0],   │
# │                     │ 128)              │            │ re_lu_43[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 32, 32,    │          0 │ re_lu_45[0][0],   │
# │                     │ 128)              │            │ re_lu_43[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 32, 32,    │          0 │ re_lu_43[0][0],   │
# │ (Concatenate)       │ 384)              │            │ lambda_8[0][0],   │
# │                     │                   │            │ lambda_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 32, 32,    │          0 │ concatenate_5[0]… │
# │ (Dropout)           │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 32,    │    442,496 │ dropout_13[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_46 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 32, 32,    │    147,584 │ re_lu_46[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_47 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 64, 64,    │          0 │ re_lu_47[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 64, 64,    │     73,792 │ up_sampling2d_6[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 64, 64,    │      4,160 │ re_lu_32[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 32, 32,    │      8,256 │ re_lu_34[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_10 (Lambda)  │ (None, 64, 64,    │          0 │ re_lu_49[0][0],   │
# │                     │ 64)               │            │ re_lu_48[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_11 (Lambda)  │ (None, 64, 64,    │          0 │ re_lu_50[0][0],   │
# │                     │ 64)               │            │ re_lu_48[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 64, 64,    │          0 │ re_lu_48[0][0],   │
# │ (Concatenate)       │ 192)              │            │ lambda_10[0][0],  │
# │                     │                   │            │ lambda_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 64, 64,    │          0 │ concatenate_6[0]… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │    110,656 │ dropout_14[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │     36,928 │ re_lu_51[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 128, 128,  │          0 │ re_lu_52[0][0]    │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 128, 128,  │     18,464 │ up_sampling2d_7[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 128, 128,  │      1,056 │ re_lu_30[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 64, 64,    │      2,080 │ re_lu_32[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_12 (Lambda)  │ (None, 128, 128,  │          0 │ re_lu_54[0][0],   │
# │                     │ 32)               │            │ re_lu_53[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_13 (Lambda)  │ (None, 128, 128,  │          0 │ re_lu_55[0][0],   │
# │                     │ 32)               │            │ re_lu_53[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ re_lu_53[0][0],   │
# │ (Concatenate)       │ 96)               │            │ lambda_12[0][0],  │
# │                     │                   │            │ lambda_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 128, 128,  │          0 │ concatenate_7[0]… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 128, 128,  │     27,680 │ dropout_15[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 128, 128,  │      9,248 │ re_lu_56[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_58[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 128, 128,  │         33 │ re_lu_57[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,971,297 (34.22 MB)
#  Trainable params: 8,963,041 (34.19 MB)
#  Non-trainable params: 8,256 (32.25 KB)
# Epoch 1/50
# 2026-09-06 16:41:55.281990: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:41:55.585477: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:41:58.506941: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:41:58.877406: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:00.635222: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:00.977207: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:01.903978: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:02.068318: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:02.999898: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:03.210285: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:04.789956: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:04.977039: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:42:24.502619: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (f32[32,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,128,128]{3,2,1,0}, f32[64,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-09-06 16:42:24.551740: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.049216091s
# Trying algorithm eng0{} for conv (f32[32,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,64,128,128]{3,2,1,0}, f32[64,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-09-06 16:42:27.539703: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,96,128,128]{3,2,1,0}, f32[64,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-09-06 16:42:28.159681: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.620085976s
# Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[64,96,128,128]{3,2,1,0}, f32[64,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# I0000 00:00:1788712962.844563     129 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 439/440 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.6845 - dice_coef: 0.5281 - iou_coef: 0.3616 - loss: 0.4719
# 2026-09-06 16:48:16.895297: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:17.195306: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:19.805272: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:20.167117: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:21.808897: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:22.149265: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:22.979022: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:23.145031: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:24.086746: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:24.298280: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:25.791332: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:25.983047: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-06 16:48:46.855649: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[50,96,128,128]{3,2,1,0}, f32[50,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-09-06 16:48:47.273275: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.417731831s
# Trying algorithm eng0{} for conv (f32[32,96,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[50,96,128,128]{3,2,1,0}, f32[50,32,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.6846 - dice_coef: 0.5282 - iou_coef: 0.3617 - loss: 0.4718
# Epoch 1: val_dice_coef improved from None to 0.58353, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 525s 1s/step - accuracy: 0.7280 - dice_coef: 0.5812 - iou_coef: 0.4116 - loss: 0.4188 - val_accuracy: 0.6823 - val_dice_coef: 0.5835 - val_iou_coef: 0.4120 - val_loss: 0.4165 - learning_rate: 1.0000e-04
# Epoch 2/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.8081 - dice_coef: 0.6638 - iou_coef: 0.4970 - loss: 0.3362
# Epoch 2: val_dice_coef improved from 0.58353 to 0.71022, saving model to best_unet.keras
#
# Epoch 2: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 785ms/step - accuracy: 0.8224 - dice_coef: 0.6803 - iou_coef: 0.5158 - loss: 0.3197 - val_accuracy: 0.8409 - val_dice_coef: 0.7102 - val_iou_coef: 0.5507 - val_loss: 0.2898 - learning_rate: 1.0000e-04
# Epoch 3/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8517 - dice_coef: 0.7192 - iou_coef: 0.5616 - loss: 0.2808
# Epoch 3: val_dice_coef improved from 0.71022 to 0.74969, saving model to best_unet.keras
#
# Epoch 3: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.8564 - dice_coef: 0.7274 - iou_coef: 0.5717 - loss: 0.2726 - val_accuracy: 0.8675 - val_dice_coef: 0.7497 - val_iou_coef: 0.5997 - val_loss: 0.2503 - learning_rate: 1.0000e-04
# Epoch 4/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8679 - dice_coef: 0.7483 - iou_coef: 0.5978 - loss: 0.2517
# Epoch 4: val_dice_coef improved from 0.74969 to 0.77044, saving model to best_unet.keras
#
# Epoch 4: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.8707 - dice_coef: 0.7539 - iou_coef: 0.6051 - loss: 0.2461 - val_accuracy: 0.8791 - val_dice_coef: 0.7704 - val_iou_coef: 0.6267 - val_loss: 0.2296 - learning_rate: 1.0000e-04
# Epoch 5/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8782 - dice_coef: 0.7678 - iou_coef: 0.6231 - loss: 0.2322
# Epoch 5: val_dice_coef improved from 0.77044 to 0.78551, saving model to best_unet.keras
#
# Epoch 5: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.8798 - dice_coef: 0.7717 - iou_coef: 0.6283 - loss: 0.2283 - val_accuracy: 0.8870 - val_dice_coef: 0.7855 - val_iou_coef: 0.6468 - val_loss: 0.2145 - learning_rate: 1.0000e-04
# Epoch 6/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8843 - dice_coef: 0.7813 - iou_coef: 0.6411 - loss: 0.2187
# Epoch 6: val_dice_coef improved from 0.78551 to 0.79512, saving model to best_unet.keras
#
# Epoch 6: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 788ms/step - accuracy: 0.8853 - dice_coef: 0.7835 - iou_coef: 0.6441 - loss: 0.2165 - val_accuracy: 0.8907 - val_dice_coef: 0.7951 - val_iou_coef: 0.6600 - val_loss: 0.2049 - learning_rate: 1.0000e-04
# Epoch 7/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.8881 - dice_coef: 0.7898 - iou_coef: 0.6527 - loss: 0.2102
# Epoch 7: val_dice_coef improved from 0.79512 to 0.80141, saving model to best_unet.keras
#
# Epoch 7: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 788ms/step - accuracy: 0.8889 - dice_coef: 0.7917 - iou_coef: 0.6553 - loss: 0.2083 - val_accuracy: 0.8929 - val_dice_coef: 0.8014 - val_iou_coef: 0.6687 - val_loss: 0.1986 - learning_rate: 1.0000e-04
# Epoch 8/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8911 - dice_coef: 0.7965 - iou_coef: 0.6619 - loss: 0.2035
# Epoch 8: val_dice_coef improved from 0.80141 to 0.80747, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.8915 - dice_coef: 0.7978 - iou_coef: 0.6636 - loss: 0.2022 - val_accuracy: 0.8969 - val_dice_coef: 0.8075 - val_iou_coef: 0.6772 - val_loss: 0.1925 - learning_rate: 1.0000e-04
# Epoch 9/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.8929 - dice_coef: 0.8009 - iou_coef: 0.6680 - loss: 0.1991
# Epoch 9: val_dice_coef improved from 0.80747 to 0.81101, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 789ms/step - accuracy: 0.8934 - dice_coef: 0.8021 - iou_coef: 0.6697 - loss: 0.1979 - val_accuracy: 0.8987 - val_dice_coef: 0.8110 - val_iou_coef: 0.6822 - val_loss: 0.1890 - learning_rate: 1.0000e-04
# Epoch 10/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.8943 - dice_coef: 0.8049 - iou_coef: 0.6736 - loss: 0.1951
# Epoch 10: val_dice_coef improved from 0.81101 to 0.81355, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 789ms/step - accuracy: 0.8949 - dice_coef: 0.8057 - iou_coef: 0.6747 - loss: 0.1943 - val_accuracy: 0.8999 - val_dice_coef: 0.8135 - val_iou_coef: 0.6858 - val_loss: 0.1865 - learning_rate: 1.0000e-04
# Epoch 11/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8960 - dice_coef: 0.8083 - iou_coef: 0.6783 - loss: 0.1917
# Epoch 11: val_dice_coef improved from 0.81355 to 0.81696, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 788ms/step - accuracy: 0.8962 - dice_coef: 0.8086 - iou_coef: 0.6788 - loss: 0.1914 - val_accuracy: 0.9013 - val_dice_coef: 0.8170 - val_iou_coef: 0.6906 - val_loss: 0.1830 - learning_rate: 1.0000e-04
# Epoch 12/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.8973 - dice_coef: 0.8112 - iou_coef: 0.6824 - loss: 0.1888
# Epoch 12: val_dice_coef improved from 0.81696 to 0.81814, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 353s 802ms/step - accuracy: 0.8973 - dice_coef: 0.8111 - iou_coef: 0.6823 - loss: 0.1889 - val_accuracy: 0.9017 - val_dice_coef: 0.8181 - val_iou_coef: 0.6923 - val_loss: 0.1819 - learning_rate: 1.0000e-04
# Epoch 13/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8976 - dice_coef: 0.8119 - iou_coef: 0.6834 - loss: 0.1881
# Epoch 13: val_dice_coef improved from 0.81814 to 0.82028, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 788ms/step - accuracy: 0.8981 - dice_coef: 0.8130 - iou_coef: 0.6850 - loss: 0.1870 - val_accuracy: 0.9026 - val_dice_coef: 0.8203 - val_iou_coef: 0.6954 - val_loss: 0.1797 - learning_rate: 1.0000e-04
# Epoch 14/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.8985 - dice_coef: 0.8144 - iou_coef: 0.6869 - loss: 0.1856
# Epoch 14: val_dice_coef improved from 0.82028 to 0.82179, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 350s 795ms/step - accuracy: 0.8989 - dice_coef: 0.8148 - iou_coef: 0.6875 - loss: 0.1852 - val_accuracy: 0.9028 - val_dice_coef: 0.8218 - val_iou_coef: 0.6975 - val_loss: 0.1782 - learning_rate: 1.0000e-04
# Epoch 15/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8992 - dice_coef: 0.8154 - iou_coef: 0.6883 - loss: 0.1846
# Epoch 15: val_dice_coef improved from 0.82179 to 0.82303, saving model to best_unet.keras
#
# Epoch 15: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.8996 - dice_coef: 0.8163 - iou_coef: 0.6897 - loss: 0.1837 - val_accuracy: 0.9035 - val_dice_coef: 0.8230 - val_iou_coef: 0.6993 - val_loss: 0.1770 - learning_rate: 1.0000e-04
# Epoch 16/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9001 - dice_coef: 0.8174 - iou_coef: 0.6913 - loss: 0.1826
# Epoch 16: val_dice_coef improved from 0.82303 to 0.82426, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 788ms/step - accuracy: 0.9003 - dice_coef: 0.8178 - iou_coef: 0.6918 - loss: 0.1822 - val_accuracy: 0.9040 - val_dice_coef: 0.8243 - val_iou_coef: 0.7011 - val_loss: 0.1757 - learning_rate: 1.0000e-04
# Epoch 17/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9010 - dice_coef: 0.8192 - iou_coef: 0.6938 - loss: 0.1808
# Epoch 17: val_dice_coef improved from 0.82426 to 0.82513, saving model to best_unet.keras
#
# Epoch 17: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9009 - dice_coef: 0.8191 - iou_coef: 0.6937 - loss: 0.1809 - val_accuracy: 0.9049 - val_dice_coef: 0.8251 - val_iou_coef: 0.7024 - val_loss: 0.1749 - learning_rate: 1.0000e-04
# Epoch 18/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9015 - dice_coef: 0.8201 - iou_coef: 0.6952 - loss: 0.1799
# Epoch 18: val_dice_coef improved from 0.82513 to 0.82594, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9014 - dice_coef: 0.8202 - iou_coef: 0.6952 - loss: 0.1798 - val_accuracy: 0.9057 - val_dice_coef: 0.8259 - val_iou_coef: 0.7036 - val_loss: 0.1741 - learning_rate: 1.0000e-04
# Epoch 19/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9017 - dice_coef: 0.8203 - iou_coef: 0.6955 - loss: 0.1797
# Epoch 19: val_dice_coef improved from 0.82594 to 0.82723, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 785ms/step - accuracy: 0.9019 - dice_coef: 0.8212 - iou_coef: 0.6967 - loss: 0.1788 - val_accuracy: 0.9053 - val_dice_coef: 0.8272 - val_iou_coef: 0.7054 - val_loss: 0.1728 - learning_rate: 1.0000e-04
# Epoch 20/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9020 - dice_coef: 0.8220 - iou_coef: 0.6978 - loss: 0.1780
# Epoch 20: val_dice_coef improved from 0.82723 to 0.82762, saving model to best_unet.keras
#
# Epoch 20: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9023 - dice_coef: 0.8221 - iou_coef: 0.6980 - loss: 0.1779 - val_accuracy: 0.9059 - val_dice_coef: 0.8276 - val_iou_coef: 0.7060 - val_loss: 0.1724 - learning_rate: 1.0000e-04
# Epoch 21/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9025 - dice_coef: 0.8227 - iou_coef: 0.6989 - loss: 0.1773
# Epoch 21: val_dice_coef improved from 0.82762 to 0.82806, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 789ms/step - accuracy: 0.9026 - dice_coef: 0.8229 - iou_coef: 0.6991 - loss: 0.1771 - val_accuracy: 0.9067 - val_dice_coef: 0.8281 - val_iou_coef: 0.7066 - val_loss: 0.1719 - learning_rate: 1.0000e-04
# Epoch 22/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9030 - dice_coef: 0.8236 - iou_coef: 0.7002 - loss: 0.1764
# Epoch 22: val_dice_coef improved from 0.82806 to 0.82879, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9030 - dice_coef: 0.8236 - iou_coef: 0.7002 - loss: 0.1764 - val_accuracy: 0.9066 - val_dice_coef: 0.8288 - val_iou_coef: 0.7077 - val_loss: 0.1712 - learning_rate: 1.0000e-04
# Epoch 23/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9031 - dice_coef: 0.8238 - iou_coef: 0.7005 - loss: 0.1762
# Epoch 23: val_dice_coef improved from 0.82879 to 0.82926, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9033 - dice_coef: 0.8244 - iou_coef: 0.7013 - loss: 0.1756 - val_accuracy: 0.9069 - val_dice_coef: 0.8293 - val_iou_coef: 0.7084 - val_loss: 0.1707 - learning_rate: 1.0000e-04
# Epoch 24/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9033 - dice_coef: 0.8245 - iou_coef: 0.7014 - loss: 0.1755
# Epoch 24: val_dice_coef improved from 0.82926 to 0.82975, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9037 - dice_coef: 0.8250 - iou_coef: 0.7022 - loss: 0.1750 - val_accuracy: 0.9073 - val_dice_coef: 0.8298 - val_iou_coef: 0.7091 - val_loss: 0.1702 - learning_rate: 1.0000e-04
# Epoch 25/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9037 - dice_coef: 0.8251 - iou_coef: 0.7023 - loss: 0.1749
# Epoch 25: val_dice_coef improved from 0.82975 to 0.83041, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9039 - dice_coef: 0.8255 - iou_coef: 0.7029 - loss: 0.1745 - val_accuracy: 0.9067 - val_dice_coef: 0.8304 - val_iou_coef: 0.7101 - val_loss: 0.1696 - learning_rate: 1.0000e-04
# Epoch 26/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9042 - dice_coef: 0.8260 - iou_coef: 0.7036 - loss: 0.1740
# Epoch 26: val_dice_coef improved from 0.83041 to 0.83050, saving model to best_unet.keras
#
# Epoch 26: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 347s 787ms/step - accuracy: 0.9042 - dice_coef: 0.8260 - iou_coef: 0.7037 - loss: 0.1740 - val_accuracy: 0.9065 - val_dice_coef: 0.8305 - val_iou_coef: 0.7102 - val_loss: 0.1695 - learning_rate: 1.0000e-04
# Epoch 27/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9045 - dice_coef: 0.8264 - iou_coef: 0.7042 - loss: 0.1736
# Epoch 27: val_dice_coef did not improve from 0.83050
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 785ms/step - accuracy: 0.9045 - dice_coef: 0.8266 - iou_coef: 0.7045 - loss: 0.1734 - val_accuracy: 0.9079 - val_dice_coef: 0.8305 - val_iou_coef: 0.7102 - val_loss: 0.1695 - learning_rate: 1.0000e-04
# Epoch 28/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9047 - dice_coef: 0.8273 - iou_coef: 0.7056 - loss: 0.1727
# Epoch 28: val_dice_coef improved from 0.83050 to 0.83135, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9047 - dice_coef: 0.8272 - iou_coef: 0.7053 - loss: 0.1728 - val_accuracy: 0.9083 - val_dice_coef: 0.8313 - val_iou_coef: 0.7114 - val_loss: 0.1687 - learning_rate: 1.0000e-04
# Epoch 29/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9052 - dice_coef: 0.8276 - iou_coef: 0.7060 - loss: 0.1724
# Epoch 29: val_dice_coef improved from 0.83135 to 0.83203, saving model to best_unet.keras
#
# Epoch 29: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9050 - dice_coef: 0.8276 - iou_coef: 0.7060 - loss: 0.1724 - val_accuracy: 0.9080 - val_dice_coef: 0.8320 - val_iou_coef: 0.7124 - val_loss: 0.1680 - learning_rate: 1.0000e-04
# Epoch 30/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9051 - dice_coef: 0.8279 - iou_coef: 0.7063 - loss: 0.1721
# Epoch 30: val_dice_coef improved from 0.83203 to 0.83207, saving model to best_unet.keras
#
# Epoch 30: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9052 - dice_coef: 0.8280 - iou_coef: 0.7066 - loss: 0.1720 - val_accuracy: 0.9086 - val_dice_coef: 0.8321 - val_iou_coef: 0.7125 - val_loss: 0.1679 - learning_rate: 1.0000e-04
# Epoch 31/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9052 - dice_coef: 0.8280 - iou_coef: 0.7065 - loss: 0.1720
# Epoch 31: val_dice_coef improved from 0.83207 to 0.83237, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9054 - dice_coef: 0.8284 - iou_coef: 0.7072 - loss: 0.1716 - val_accuracy: 0.9085 - val_dice_coef: 0.8324 - val_iou_coef: 0.7129 - val_loss: 0.1676 - learning_rate: 1.0000e-04
# Epoch 32/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9056 - dice_coef: 0.8291 - iou_coef: 0.7082 - loss: 0.1709
# Epoch 32: val_dice_coef improved from 0.83237 to 0.83317, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9056 - dice_coef: 0.8288 - iou_coef: 0.7077 - loss: 0.1712 - val_accuracy: 0.9095 - val_dice_coef: 0.8332 - val_iou_coef: 0.7141 - val_loss: 0.1668 - learning_rate: 1.0000e-04
# Epoch 33/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9057 - dice_coef: 0.8291 - iou_coef: 0.7081 - loss: 0.1709
# Epoch 33: val_dice_coef improved from 0.83317 to 0.83325, saving model to best_unet.keras
#
# Epoch 33: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9058 - dice_coef: 0.8292 - iou_coef: 0.7082 - loss: 0.1708 - val_accuracy: 0.9096 - val_dice_coef: 0.8332 - val_iou_coef: 0.7142 - val_loss: 0.1668 - learning_rate: 1.0000e-04
# Epoch 34/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9058 - dice_coef: 0.8293 - iou_coef: 0.7084 - loss: 0.1707
# Epoch 34: val_dice_coef did not improve from 0.83325
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 785ms/step - accuracy: 0.9060 - dice_coef: 0.8295 - iou_coef: 0.7088 - loss: 0.1705 - val_accuracy: 0.9090 - val_dice_coef: 0.8331 - val_iou_coef: 0.7140 - val_loss: 0.1669 - learning_rate: 1.0000e-04
# Epoch 35/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9064 - dice_coef: 0.8304 - iou_coef: 0.7100 - loss: 0.1696
# Epoch 35: val_dice_coef improved from 0.83325 to 0.83367, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9062 - dice_coef: 0.8299 - iou_coef: 0.7092 - loss: 0.1701 - val_accuracy: 0.9091 - val_dice_coef: 0.8337 - val_iou_coef: 0.7148 - val_loss: 0.1663 - learning_rate: 1.0000e-04
# Epoch 36/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9062 - dice_coef: 0.8300 - iou_coef: 0.7095 - loss: 0.1700
# Epoch 36: val_dice_coef improved from 0.83367 to 0.83377, saving model to best_unet.keras
#
# Epoch 36: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 785ms/step - accuracy: 0.9063 - dice_coef: 0.8302 - iou_coef: 0.7097 - loss: 0.1698 - val_accuracy: 0.9097 - val_dice_coef: 0.8338 - val_iou_coef: 0.7150 - val_loss: 0.1662 - learning_rate: 1.0000e-04
# Epoch 37/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9065 - dice_coef: 0.8305 - iou_coef: 0.7102 - loss: 0.1695
# Epoch 37: val_dice_coef improved from 0.83377 to 0.83459, saving model to best_unet.keras
#
# Epoch 37: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9065 - dice_coef: 0.8305 - iou_coef: 0.7102 - loss: 0.1695 - val_accuracy: 0.9096 - val_dice_coef: 0.8346 - val_iou_coef: 0.7162 - val_loss: 0.1654 - learning_rate: 1.0000e-04
# Epoch 38/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9065 - dice_coef: 0.8306 - iou_coef: 0.7104 - loss: 0.1694
# Epoch 38: val_dice_coef did not improve from 0.83459
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 784ms/step - accuracy: 0.9066 - dice_coef: 0.8307 - iou_coef: 0.7105 - loss: 0.1693 - val_accuracy: 0.9093 - val_dice_coef: 0.8343 - val_iou_coef: 0.7157 - val_loss: 0.1657 - learning_rate: 1.0000e-04
# Epoch 39/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9071 - dice_coef: 0.8315 - iou_coef: 0.7116 - loss: 0.1685
# Epoch 39: val_dice_coef did not improve from 0.83459
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 785ms/step - accuracy: 0.9068 - dice_coef: 0.8311 - iou_coef: 0.7110 - loss: 0.1689 - val_accuracy: 0.9098 - val_dice_coef: 0.8344 - val_iou_coef: 0.7160 - val_loss: 0.1656 - learning_rate: 1.0000e-04
# Epoch 40/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9070 - dice_coef: 0.8310 - iou_coef: 0.7109 - loss: 0.1690
# Epoch 40: val_dice_coef did not improve from 0.83459
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 785ms/step - accuracy: 0.9070 - dice_coef: 0.8314 - iou_coef: 0.7115 - loss: 0.1686 - val_accuracy: 0.9095 - val_dice_coef: 0.8345 - val_iou_coef: 0.7160 - val_loss: 0.1655 - learning_rate: 1.0000e-04
# Epoch 41/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9070 - dice_coef: 0.8312 - iou_coef: 0.7113 - loss: 0.1688
# Epoch 41: val_dice_coef improved from 0.83459 to 0.83527, saving model to best_unet.keras
#
# Epoch 41: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9070 - dice_coef: 0.8315 - iou_coef: 0.7117 - loss: 0.1685 - val_accuracy: 0.9104 - val_dice_coef: 0.8353 - val_iou_coef: 0.7172 - val_loss: 0.1647 - learning_rate: 1.0000e-04
# Epoch 42/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9070 - dice_coef: 0.8315 - iou_coef: 0.7117 - loss: 0.1685
# Epoch 42: val_dice_coef did not improve from 0.83527
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 785ms/step - accuracy: 0.9072 - dice_coef: 0.8318 - iou_coef: 0.7121 - loss: 0.1682 - val_accuracy: 0.9094 - val_dice_coef: 0.8349 - val_iou_coef: 0.7167 - val_loss: 0.1651 - learning_rate: 1.0000e-04
# Epoch 43/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9072 - dice_coef: 0.8320 - iou_coef: 0.7123 - loss: 0.1680
# Epoch 43: val_dice_coef did not improve from 0.83527
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 785ms/step - accuracy: 0.9073 - dice_coef: 0.8321 - iou_coef: 0.7125 - loss: 0.1679 - val_accuracy: 0.9107 - val_dice_coef: 0.8345 - val_iou_coef: 0.7161 - val_loss: 0.1655 - learning_rate: 1.0000e-04
# Epoch 44/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9072 - dice_coef: 0.8319 - iou_coef: 0.7122 - loss: 0.1681
# Epoch 44: val_dice_coef improved from 0.83527 to 0.83590, saving model to best_unet.keras
#
# Epoch 44: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9075 - dice_coef: 0.8323 - iou_coef: 0.7129 - loss: 0.1677 - val_accuracy: 0.9099 - val_dice_coef: 0.8359 - val_iou_coef: 0.7181 - val_loss: 0.1641 - learning_rate: 1.0000e-04
# Epoch 45/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9078 - dice_coef: 0.8327 - iou_coef: 0.7135 - loss: 0.1673
# Epoch 45: val_dice_coef did not improve from 0.83590
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 784ms/step - accuracy: 0.9076 - dice_coef: 0.8325 - iou_coef: 0.7131 - loss: 0.1675 - val_accuracy: 0.9110 - val_dice_coef: 0.8353 - val_iou_coef: 0.7173 - val_loss: 0.1647 - learning_rate: 1.0000e-04
# Epoch 46/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9074 - dice_coef: 0.8324 - iou_coef: 0.7130 - loss: 0.1676
# Epoch 46: val_dice_coef did not improve from 0.83590
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 784ms/step - accuracy: 0.9078 - dice_coef: 0.8328 - iou_coef: 0.7136 - loss: 0.1672 - val_accuracy: 0.9107 - val_dice_coef: 0.8359 - val_iou_coef: 0.7181 - val_loss: 0.1641 - learning_rate: 1.0000e-04
# Epoch 47/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9081 - dice_coef: 0.8335 - iou_coef: 0.7146 - loss: 0.1665
# Epoch 47: val_dice_coef did not improve from 0.83590
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 785ms/step - accuracy: 0.9078 - dice_coef: 0.8329 - iou_coef: 0.7137 - loss: 0.1671 - val_accuracy: 0.9099 - val_dice_coef: 0.8357 - val_iou_coef: 0.7178 - val_loss: 0.1643 - learning_rate: 1.0000e-04
# Epoch 48/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9078 - dice_coef: 0.8330 - iou_coef: 0.7139 - loss: 0.1670
# Epoch 48: val_dice_coef improved from 0.83590 to 0.83687, saving model to best_unet.keras
#
# Epoch 48: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 786ms/step - accuracy: 0.9079 - dice_coef: 0.8332 - iou_coef: 0.7141 - loss: 0.1668 - val_accuracy: 0.9101 - val_dice_coef: 0.8369 - val_iou_coef: 0.7196 - val_loss: 0.1631 - learning_rate: 1.0000e-04
# Epoch 49/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9080 - dice_coef: 0.8334 - iou_coef: 0.7144 - loss: 0.1666
# Epoch 49: val_dice_coef did not improve from 0.83687
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 345s 784ms/step - accuracy: 0.9081 - dice_coef: 0.8334 - iou_coef: 0.7144 - loss: 0.1666 - val_accuracy: 0.9115 - val_dice_coef: 0.8355 - val_iou_coef: 0.7175 - val_loss: 0.1645 - learning_rate: 1.0000e-04
# Epoch 50/50
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9083 - dice_coef: 0.8336 - iou_coef: 0.7148 - loss: 0.1664
# Epoch 50: val_dice_coef improved from 0.83687 to 0.83699, saving model to best_unet.keras
#
# Epoch 50: finished saving model to best_unet.keras
# 440/440 ━━━━━━━━━━━━━━━━━━━━ 346s 787ms/step - accuracy: 0.9082 - dice_coef: 0.8336 - iou_coef: 0.7147 - loss: 0.1664 - val_accuracy: 0.9106 - val_dice_coef: 0.8370 - val_iou_coef: 0.7197 - val_loss: 0.1630 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 50.
