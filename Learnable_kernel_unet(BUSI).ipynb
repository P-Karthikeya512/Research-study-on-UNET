# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Research-study-on-UNET/blob/main/Learnable_kernel_unet(BUSI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -o /content/Dataset_BUSI_with_GT.zip -d /content/Dataset_BUSI_with_GT
# Out:
# Archive:  /content/Dataset_BUSI_with_GT.zip
# warning [/content/Dataset_BUSI_with_GT.zip]:  30403291 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# file #1:  bad zipfile offset (local header sig):  30403291
#   (attempting to re-compensate)
#    creating: /content/Dataset_BUSI_with_GT/Dataset_BUSI_with_GT/
# error: invalid zip file with overlapped components (possible zip bomb)

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
EPOCHS = 50
SEED = 42

ZIP_PATH = "/content/Dataset_BUSI_with_GT.zip"
EXTRACT_DIR = "/content/BUSI_DATASET"

import zipfile
from pathlib import Path

with zipfile.ZipFile(ZIP_PATH, "r") as z:
    z.extractall(EXTRACT_DIR)

def find_dataset_root(base_dir):
    for root, dirs, files in os.walk(base_dir):
        d = {x.lower() for x in dirs}
        if {"benign", "malignant", "normal"}.issubset(d):
            return root
    raise FileNotFoundError("Could not find benign/malignant/normal folders.")

DATASET_DIR = find_dataset_root(EXTRACT_DIR)

print("Dataset:", DATASET_DIR)

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Dataset: /content/BUSI_DATASET/Dataset_BUSI_with_GT

# %%
def get_pairs(dataset_dir):
    pairs = []

    for cls in ["benign", "malignant", "normal"]:
        folder = os.path.join(dataset_dir, cls)
        for f in sorted(os.listdir(folder)):
            path = os.path.join(folder, f)
            if not os.path.isfile(path):
                continue
            ext = Path(f).suffix.lower()
            if ext not in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]:
                continue
            stem = Path(f).stem
            if "_mask" in stem.lower():
                continue
            mask = os.path.join(folder, stem + "_mask.png")
            if os.path.exists(mask):
                pairs.append((path, mask))
            else:
                print("No mask:", path)

    return pairs


# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    if isinstance(img_path, bytes):
        img_path = img_path.decode()

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode()

    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")

    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(DATASET_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

labels = [Path(img).parent.name for img, mask in pairs]
train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED, stratify=labels)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))
# Out:
# Total paired samples: 780
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100)_mask.png
#
# Train samples: 624
# Val samples: 156

# %%
# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np

# =========================================================
# LEARNABLE KERNEL LAYER
# =========================================================
@tf.keras.utils.register_keras_serializable()
class LearnableDepthwiseConv2D(layers.Layer):
    """
    Learnable depthwise kernel bank initialized with:
    - Sobel X
    - Sobel Y
    - Laplacian

    Input:  [B, H, W, C]
    Output: [B, H, W, 3C]
    """
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def build(self, input_shape):
        c = int(input_shape[-1])

        sobel_x = np.array([
            [-1, 0, 1],
            [-2, 0, 2],
            [-1, 0, 1]
        ], dtype=np.float32)

        sobel_y = np.array([
            [-1, -2, -1],
            [ 0,  0,  0],
            [ 1,  2,  1]
        ], dtype=np.float32)

        laplacian = np.array([
            [ 0,  1,  0],
            [ 1, -4,  1],
            [ 0,  1,  0]
        ], dtype=np.float32)

        # depthwise kernel shape: [kh, kw, in_channels, channel_multiplier]
        init_kernel = np.zeros((3, 3, c, 3), dtype=np.float32)

        for ch in range(c):
            init_kernel[:, :, ch, 0] = sobel_x
            init_kernel[:, :, ch, 1] = sobel_y
            init_kernel[:, :, ch, 2] = laplacian

        self.kernel = self.add_weight(
            name="kernel",
            shape=(3, 3, c, 3),
            initializer=tf.keras.initializers.Constant(init_kernel),
            trainable=True
        )

        super().build(input_shape)

    def call(self, x):
        return tf.nn.depthwise_conv2d(
            x,
            self.kernel,
            strides=[1, 1, 1, 1],
            padding="SAME"
        )

    def get_config(self):
        config = super().get_config()
        return config


# =========================================================
# LEARNABLE KERNEL BRANCH
# =========================================================
def learnable_kernel_block(x):
    x = LearnableDepthwiseConv2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def merge_with_learnable_kernels(feat, filters, prefix):
    """
    For a single skip tensor:
      original feature
      + learnable-kernel response of that feature
    Then concatenate and compress with 1x1 conv.
    """
    lk = LearnableDepthwiseConv2D(name=f"{prefix}_learnable")(feat)
    x = layers.Concatenate(name=f"{prefix}_concat")([feat, lk])

    x = layers.Conv2D(
        filters,
        1,
        padding="same",
        kernel_initializer="he_normal",
        name=f"{prefix}_compress"
    )(x)
    x = layers.ReLU(name=f"{prefix}_compress_relu")(x)
    return x


# =========================================================
# U-NET BLOCKS
# =========================================================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p


def up_block(x, skip, skip_learnable, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip, skip_learnable])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x


# =========================================================
# BUILD MODEL
# =========================================================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1, p1 = down_block(inputs, 32)
    c2, p2 = down_block(p1, 64)
    c3, p3 = down_block(p2, 128)
    c4, p4 = down_block(p3, 256)

    # Learnable-kernel transformed skips
    c1_star = merge_with_learnable_kernels(c1, 32, "c1")
    c2_star = merge_with_learnable_kernels(c2, 64, "c2")
    c3_star = merge_with_learnable_kernels(c3, 128, "c3")
    c4_star = merge_with_learnable_kernels(c4, 256, "c4")

    # Bottleneck
    bottleneck = conv_block(p4, 512)

    # Decoder
    u1 = up_block(bottleneck, c4, c4_star, 256)
    u2 = up_block(u1, c3, c3_star, 128)
    u3 = up_block(u2, c2, c2_star, 64)
    u4 = up_block(u3, c1, c1_star, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary_LearnableKernel")
    return model


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Model: "UNet_Binary_LearnableKernel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ re_lu_8[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_learnable        │ (None, 32, 32,    │      6,912 │ re_lu_7[0][0]     │
# │ (LearnableDepthwis… │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_concat           │ (None, 32, 32,    │          0 │ re_lu_7[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ c4_learnable[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress         │ (None, 32, 32,    │    262,400 │ c4_concat[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress_relu    │ (None, 32, 32,    │          0 │ c4_compress[0][0] │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ re_lu_7[0][0],    │
# │                     │                   │            │ c4_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ concatenate[0][0] │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,769,728 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_10[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_learnable        │ (None, 64, 64,    │      3,456 │ re_lu_5[0][0]     │
# │ (LearnableDepthwis… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_concat           │ (None, 64, 64,    │          0 │ re_lu_5[0][0],    │
# │ (Concatenate)       │ 512)              │            │ c3_learnable[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress         │ (None, 64, 64,    │     65,664 │ c3_concat[0][0]   │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ re_lu_11[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress_relu    │ (None, 64, 64,    │          0 │ c3_compress[0][0] │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 384)              │            │ re_lu_5[0][0],    │
# │                     │                   │            │ c3_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_1[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    442,496 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_learnable        │ (None, 128, 128,  │      1,728 │ re_lu_3[0][0]     │
# │ (LearnableDepthwis… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_concat           │ (None, 128, 128,  │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 256)              │            │ c2_learnable[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress         │ (None, 128, 128,  │     16,448 │ c2_concat[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ re_lu_13[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress_relu    │ (None, 128, 128,  │          0 │ c2_compress[0][0] │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 192)              │            │ re_lu_3[0][0],    │
# │                     │                   │            │ c2_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_2[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    110,656 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_14[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_learnable        │ (None, 256, 256,  │        864 │ re_lu_1[0][0]     │
# │ (LearnableDepthwis… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_concat           │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 128)              │            │ c1_learnable[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress         │ (None, 256, 256,  │      4,128 │ c1_concat[0][0]   │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ re_lu_15[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress_relu    │ (None, 256, 256,  │          0 │ c1_compress[0][0] │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 96)               │            │ re_lu_1[0][0],    │
# │                     │                   │            │ c1_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ concatenate_3[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     27,680 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_16[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ re_lu_17[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,916,833 (34.02 MB)
#  Trainable params: 8,910,945 (33.99 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.6619 - dice_coef: 0.1336 - iou_coef: 0.0722 - loss: 0.8664
# Epoch 1: val_dice_coef improved from None to 0.20672, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 103s 450ms/step - accuracy: 0.5929 - dice_coef: 0.1532 - iou_coef: 0.0843 - loss: 0.8468 - val_accuracy: 0.4413 - val_dice_coef: 0.2067 - val_iou_coef: 0.1172 - val_loss: 0.7934 - learning_rate: 1.0000e-04
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.7702 - dice_coef: 0.2446 - iou_coef: 0.1420 - loss: 0.7554
# Epoch 2: val_dice_coef improved from 0.20672 to 0.21760, saving model to best_unet.keras
#
# Epoch 2: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 290ms/step - accuracy: 0.7943 - dice_coef: 0.2626 - iou_coef: 0.1544 - loss: 0.7374 - val_accuracy: 0.9133 - val_dice_coef: 0.2176 - val_iou_coef: 0.1243 - val_loss: 0.7850 - learning_rate: 1.0000e-04
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.8177 - dice_coef: 0.2857 - iou_coef: 0.1704 - loss: 0.7143
# Epoch 3: val_dice_coef improved from 0.21760 to 0.33694, saving model to best_unet.keras
#
# Epoch 3: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 299ms/step - accuracy: 0.8396 - dice_coef: 0.3111 - iou_coef: 0.1889 - loss: 0.6889 - val_accuracy: 0.8431 - val_dice_coef: 0.3369 - val_iou_coef: 0.2060 - val_loss: 0.6638 - learning_rate: 1.0000e-04
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.8711 - dice_coef: 0.3525 - iou_coef: 0.2188 - loss: 0.6475
# Epoch 4: val_dice_coef improved from 0.33694 to 0.42838, saving model to best_unet.keras
#
# Epoch 4: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 317ms/step - accuracy: 0.8811 - dice_coef: 0.3510 - iou_coef: 0.2180 - loss: 0.6490 - val_accuracy: 0.9000 - val_dice_coef: 0.4284 - val_iou_coef: 0.2792 - val_loss: 0.5740 - learning_rate: 1.0000e-04
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9119 - dice_coef: 0.3929 - iou_coef: 0.2480 - loss: 0.6071
# Epoch 5: val_dice_coef did not improve from 0.42838
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 296ms/step - accuracy: 0.9057 - dice_coef: 0.3923 - iou_coef: 0.2486 - loss: 0.6077 - val_accuracy: 0.8623 - val_dice_coef: 0.4190 - val_iou_coef: 0.2714 - val_loss: 0.5823 - learning_rate: 1.0000e-04
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9092 - dice_coef: 0.4032 - iou_coef: 0.2586 - loss: 0.5968
# Epoch 6: val_dice_coef improved from 0.42838 to 0.46886, saving model to best_unet.keras
#
# Epoch 6: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 301ms/step - accuracy: 0.9115 - dice_coef: 0.4063 - iou_coef: 0.2624 - loss: 0.5937 - val_accuracy: 0.9219 - val_dice_coef: 0.4689 - val_iou_coef: 0.3197 - val_loss: 0.5356 - learning_rate: 1.0000e-04
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9144 - dice_coef: 0.4170 - iou_coef: 0.2727 - loss: 0.5830
# Epoch 7: val_dice_coef did not improve from 0.46886
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 301ms/step - accuracy: 0.9172 - dice_coef: 0.4285 - iou_coef: 0.2801 - loss: 0.5715 - val_accuracy: 0.8658 - val_dice_coef: 0.4420 - val_iou_coef: 0.2917 - val_loss: 0.5599 - learning_rate: 1.0000e-04
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9240 - dice_coef: 0.4511 - iou_coef: 0.2983 - loss: 0.5489
# Epoch 8: val_dice_coef improved from 0.46886 to 0.49559, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 0.9241 - dice_coef: 0.4511 - iou_coef: 0.2986 - loss: 0.5489 - val_accuracy: 0.9054 - val_dice_coef: 0.4956 - val_iou_coef: 0.3415 - val_loss: 0.5067 - learning_rate: 1.0000e-04
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9180 - dice_coef: 0.4712 - iou_coef: 0.3158 - loss: 0.5288
# Epoch 9: val_dice_coef improved from 0.49559 to 0.50557, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 305ms/step - accuracy: 0.9246 - dice_coef: 0.4638 - iou_coef: 0.3093 - loss: 0.5362 - val_accuracy: 0.9336 - val_dice_coef: 0.5056 - val_iou_coef: 0.3541 - val_loss: 0.5009 - learning_rate: 1.0000e-04
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9321 - dice_coef: 0.5012 - iou_coef: 0.3419 - loss: 0.4988
# Epoch 10: val_dice_coef improved from 0.50557 to 0.54323, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 301ms/step - accuracy: 0.9294 - dice_coef: 0.4809 - iou_coef: 0.3258 - loss: 0.5191 - val_accuracy: 0.9323 - val_dice_coef: 0.5432 - val_iou_coef: 0.3845 - val_loss: 0.4615 - learning_rate: 1.0000e-04
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9329 - dice_coef: 0.5011 - iou_coef: 0.3437 - loss: 0.4989
# Epoch 11: val_dice_coef improved from 0.54323 to 0.54962, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 301ms/step - accuracy: 0.9347 - dice_coef: 0.4964 - iou_coef: 0.3389 - loss: 0.5036 - val_accuracy: 0.9362 - val_dice_coef: 0.5496 - val_iou_coef: 0.3915 - val_loss: 0.4559 - learning_rate: 1.0000e-04
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9361 - dice_coef: 0.5033 - iou_coef: 0.3469 - loss: 0.4967
# Epoch 12: val_dice_coef did not improve from 0.54962
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9364 - dice_coef: 0.5065 - iou_coef: 0.3489 - loss: 0.4935 - val_accuracy: 0.9377 - val_dice_coef: 0.5409 - val_iou_coef: 0.3880 - val_loss: 0.4654 - learning_rate: 1.0000e-04
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9278 - dice_coef: 0.5142 - iou_coef: 0.3574 - loss: 0.4858
# Epoch 13: val_dice_coef improved from 0.54962 to 0.55847, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - accuracy: 0.9338 - dice_coef: 0.5099 - iou_coef: 0.3512 - loss: 0.4901 - val_accuracy: 0.9359 - val_dice_coef: 0.5585 - val_iou_coef: 0.4024 - val_loss: 0.4466 - learning_rate: 1.0000e-04
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9396 - dice_coef: 0.5247 - iou_coef: 0.3626 - loss: 0.4753
# Epoch 14: val_dice_coef improved from 0.55847 to 0.57157, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 312ms/step - accuracy: 0.9403 - dice_coef: 0.5279 - iou_coef: 0.3676 - loss: 0.4721 - val_accuracy: 0.9374 - val_dice_coef: 0.5716 - val_iou_coef: 0.4160 - val_loss: 0.4330 - learning_rate: 1.0000e-04
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9494 - dice_coef: 0.5826 - iou_coef: 0.4193 - loss: 0.4174
# Epoch 15: val_dice_coef did not improve from 0.57157
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9450 - dice_coef: 0.5679 - iou_coef: 0.4045 - loss: 0.4321 - val_accuracy: 0.9391 - val_dice_coef: 0.5562 - val_iou_coef: 0.4034 - val_loss: 0.4508 - learning_rate: 1.0000e-04
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9413 - dice_coef: 0.5345 - iou_coef: 0.3760 - loss: 0.4655
# Epoch 16: val_dice_coef did not improve from 0.57157
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 305ms/step - accuracy: 0.9404 - dice_coef: 0.5425 - iou_coef: 0.3826 - loss: 0.4575 - val_accuracy: 0.9302 - val_dice_coef: 0.5586 - val_iou_coef: 0.3998 - val_loss: 0.4460 - learning_rate: 1.0000e-04
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9427 - dice_coef: 0.5390 - iou_coef: 0.3788 - loss: 0.4610
# Epoch 17: val_dice_coef did not improve from 0.57157
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 293ms/step - accuracy: 0.9446 - dice_coef: 0.5630 - iou_coef: 0.4017 - loss: 0.4370 - val_accuracy: 0.9085 - val_dice_coef: 0.5479 - val_iou_coef: 0.3907 - val_loss: 0.4548 - learning_rate: 1.0000e-04
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9454 - dice_coef: 0.5874 - iou_coef: 0.4222 - loss: 0.4126
# Epoch 18: val_dice_coef improved from 0.57157 to 0.58159, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 312ms/step - accuracy: 0.9473 - dice_coef: 0.5859 - iou_coef: 0.4211 - loss: 0.4141 - val_accuracy: 0.9424 - val_dice_coef: 0.5816 - val_iou_coef: 0.4295 - val_loss: 0.4251 - learning_rate: 1.0000e-04
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9446 - dice_coef: 0.5467 - iou_coef: 0.3868 - loss: 0.4533
# Epoch 19: val_dice_coef did not improve from 0.58159
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9455 - dice_coef: 0.5707 - iou_coef: 0.4094 - loss: 0.4293 - val_accuracy: 0.8857 - val_dice_coef: 0.5025 - val_iou_coef: 0.3472 - val_loss: 0.5002 - learning_rate: 1.0000e-04
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9502 - dice_coef: 0.6059 - iou_coef: 0.4405 - loss: 0.3941
# Epoch 20: val_dice_coef did not improve from 0.58159
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 304ms/step - accuracy: 0.9487 - dice_coef: 0.5986 - iou_coef: 0.4356 - loss: 0.4014 - val_accuracy: 0.9396 - val_dice_coef: 0.5744 - val_iou_coef: 0.4198 - val_loss: 0.4323 - learning_rate: 1.0000e-04
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9482 - dice_coef: 0.5888 - iou_coef: 0.4291 - loss: 0.4112
# Epoch 21: val_dice_coef improved from 0.58159 to 0.58675, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9469 - dice_coef: 0.5859 - iou_coef: 0.4248 - loss: 0.4141 - val_accuracy: 0.9299 - val_dice_coef: 0.5867 - val_iou_coef: 0.4341 - val_loss: 0.4175 - learning_rate: 1.0000e-04
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9374 - dice_coef: 0.5717 - iou_coef: 0.4114 - loss: 0.4283
# Epoch 22: val_dice_coef improved from 0.58675 to 0.60324, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9460 - dice_coef: 0.5963 - iou_coef: 0.4369 - loss: 0.4037 - val_accuracy: 0.9325 - val_dice_coef: 0.6032 - val_iou_coef: 0.4463 - val_loss: 0.3999 - learning_rate: 1.0000e-04
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9504 - dice_coef: 0.5955 - iou_coef: 0.4372 - loss: 0.4045
# Epoch 23: val_dice_coef improved from 0.60324 to 0.62613, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - accuracy: 0.9505 - dice_coef: 0.6115 - iou_coef: 0.4522 - loss: 0.3885 - val_accuracy: 0.9378 - val_dice_coef: 0.6261 - val_iou_coef: 0.4709 - val_loss: 0.3781 - learning_rate: 1.0000e-04
# Epoch 24/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9561 - dice_coef: 0.6474 - iou_coef: 0.4889 - loss: 0.3526
# Epoch 24: val_dice_coef improved from 0.62613 to 0.63203, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 313ms/step - accuracy: 0.9510 - dice_coef: 0.6150 - iou_coef: 0.4589 - loss: 0.3850 - val_accuracy: 0.9420 - val_dice_coef: 0.6320 - val_iou_coef: 0.4786 - val_loss: 0.3729 - learning_rate: 1.0000e-04
# Epoch 25/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9540 - dice_coef: 0.6424 - iou_coef: 0.4824 - loss: 0.3576
# Epoch 25: val_dice_coef did not improve from 0.63203
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 291ms/step - accuracy: 0.9513 - dice_coef: 0.6222 - iou_coef: 0.4622 - loss: 0.3778 - val_accuracy: 0.9321 - val_dice_coef: 0.6205 - val_iou_coef: 0.4662 - val_loss: 0.3839 - learning_rate: 1.0000e-04
# Epoch 26/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9464 - dice_coef: 0.6094 - iou_coef: 0.4533 - loss: 0.3906
# Epoch 26: val_dice_coef did not improve from 0.63203
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 293ms/step - accuracy: 0.9501 - dice_coef: 0.6072 - iou_coef: 0.4480 - loss: 0.3928 - val_accuracy: 0.9358 - val_dice_coef: 0.6170 - val_iou_coef: 0.4616 - val_loss: 0.3875 - learning_rate: 1.0000e-04
# Epoch 27/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9469 - dice_coef: 0.5972 - iou_coef: 0.4386 - loss: 0.4028
# Epoch 27: val_dice_coef did not improve from 0.63203
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 292ms/step - accuracy: 0.9497 - dice_coef: 0.6123 - iou_coef: 0.4539 - loss: 0.3877 - val_accuracy: 0.9376 - val_dice_coef: 0.6098 - val_iou_coef: 0.4541 - val_loss: 0.3950 - learning_rate: 1.0000e-04
# Epoch 28/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9503 - dice_coef: 0.5893 - iou_coef: 0.4337 - loss: 0.4107
# Epoch 28: val_dice_coef did not improve from 0.63203
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 338ms/step - accuracy: 0.9484 - dice_coef: 0.6073 - iou_coef: 0.4486 - loss: 0.3927 - val_accuracy: 0.9307 - val_dice_coef: 0.6145 - val_iou_coef: 0.4611 - val_loss: 0.3893 - learning_rate: 1.0000e-04
# Epoch 29/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9511 - dice_coef: 0.6241 - iou_coef: 0.4700 - loss: 0.3759
# Epoch 29: val_dice_coef did not improve from 0.63203
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 336ms/step - accuracy: 0.9524 - dice_coef: 0.6332 - iou_coef: 0.4774 - loss: 0.3668 - val_accuracy: 0.9442 - val_dice_coef: 0.6316 - val_iou_coef: 0.4825 - val_loss: 0.3738 - learning_rate: 5.0000e-05
# Epoch 30/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9518 - dice_coef: 0.6191 - iou_coef: 0.4643 - loss: 0.3809
# Epoch 30: val_dice_coef improved from 0.63203 to 0.64729, saving model to best_unet.keras
#
# Epoch 30: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 317ms/step - accuracy: 0.9515 - dice_coef: 0.6230 - iou_coef: 0.4709 - loss: 0.3770 - val_accuracy: 0.9439 - val_dice_coef: 0.6473 - val_iou_coef: 0.4994 - val_loss: 0.3581 - learning_rate: 5.0000e-05
# Epoch 31/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9543 - dice_coef: 0.6264 - iou_coef: 0.4671 - loss: 0.3736
# Epoch 31: val_dice_coef did not improve from 0.64729
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 295ms/step - accuracy: 0.9522 - dice_coef: 0.6258 - iou_coef: 0.4698 - loss: 0.3742 - val_accuracy: 0.9323 - val_dice_coef: 0.6262 - val_iou_coef: 0.4712 - val_loss: 0.3776 - learning_rate: 5.0000e-05
# Epoch 32/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9527 - dice_coef: 0.6408 - iou_coef: 0.4872 - loss: 0.3592
# Epoch 32: val_dice_coef improved from 0.64729 to 0.65276, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9528 - dice_coef: 0.6363 - iou_coef: 0.4833 - loss: 0.3637 - val_accuracy: 0.9476 - val_dice_coef: 0.6528 - val_iou_coef: 0.5050 - val_loss: 0.3523 - learning_rate: 5.0000e-05
# Epoch 33/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9572 - dice_coef: 0.6637 - iou_coef: 0.5087 - loss: 0.3363
# Epoch 33: val_dice_coef did not improve from 0.65276
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 304ms/step - accuracy: 0.9562 - dice_coef: 0.6569 - iou_coef: 0.5014 - loss: 0.3431 - val_accuracy: 0.9471 - val_dice_coef: 0.6451 - val_iou_coef: 0.4964 - val_loss: 0.3597 - learning_rate: 5.0000e-05
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9566 - dice_coef: 0.6544 - iou_coef: 0.4967 - loss: 0.3456
# Epoch 34: val_dice_coef did not improve from 0.65276
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 292ms/step - accuracy: 0.9576 - dice_coef: 0.6754 - iou_coef: 0.5201 - loss: 0.3246 - val_accuracy: 0.9473 - val_dice_coef: 0.6478 - val_iou_coef: 0.4995 - val_loss: 0.3584 - learning_rate: 5.0000e-05
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9600 - dice_coef: 0.6689 - iou_coef: 0.5147 - loss: 0.3311
# Epoch 35: val_dice_coef improved from 0.65276 to 0.65535, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 318ms/step - accuracy: 0.9564 - dice_coef: 0.6518 - iou_coef: 0.4962 - loss: 0.3482 - val_accuracy: 0.9444 - val_dice_coef: 0.6554 - val_iou_coef: 0.5060 - val_loss: 0.3499 - learning_rate: 5.0000e-05
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9560 - dice_coef: 0.6766 - iou_coef: 0.5211 - loss: 0.3234
# Epoch 36: val_dice_coef did not improve from 0.65535
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 304ms/step - accuracy: 0.9550 - dice_coef: 0.6586 - iou_coef: 0.5044 - loss: 0.3414 - val_accuracy: 0.9465 - val_dice_coef: 0.6381 - val_iou_coef: 0.4912 - val_loss: 0.3683 - learning_rate: 5.0000e-05
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9566 - dice_coef: 0.6512 - iou_coef: 0.4949 - loss: 0.3488
# Epoch 37: val_dice_coef did not improve from 0.65535
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 305ms/step - accuracy: 0.9571 - dice_coef: 0.6633 - iou_coef: 0.5072 - loss: 0.3367 - val_accuracy: 0.9465 - val_dice_coef: 0.6487 - val_iou_coef: 0.4987 - val_loss: 0.3561 - learning_rate: 5.0000e-05
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9581 - dice_coef: 0.6592 - iou_coef: 0.5038 - loss: 0.3408
# Epoch 38: val_dice_coef did not improve from 0.65535
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 305ms/step - accuracy: 0.9579 - dice_coef: 0.6649 - iou_coef: 0.5103 - loss: 0.3351 - val_accuracy: 0.9436 - val_dice_coef: 0.6362 - val_iou_coef: 0.4867 - val_loss: 0.3695 - learning_rate: 5.0000e-05
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9617 - dice_coef: 0.6715 - iou_coef: 0.5185 - loss: 0.3285
# Epoch 39: val_dice_coef did not improve from 0.65535
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 293ms/step - accuracy: 0.9570 - dice_coef: 0.6609 - iou_coef: 0.5068 - loss: 0.3391 - val_accuracy: 0.9342 - val_dice_coef: 0.6191 - val_iou_coef: 0.4643 - val_loss: 0.3847 - learning_rate: 5.0000e-05
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9538 - dice_coef: 0.6545 - iou_coef: 0.5052 - loss: 0.3455
# Epoch 40: val_dice_coef improved from 0.65535 to 0.66102, saving model to best_unet.keras
#
# Epoch 40: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 304ms/step - accuracy: 0.9558 - dice_coef: 0.6608 - iou_coef: 0.5104 - loss: 0.3392 - val_accuracy: 0.9449 - val_dice_coef: 0.6610 - val_iou_coef: 0.5121 - val_loss: 0.3435 - learning_rate: 2.5000e-05
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9589 - dice_coef: 0.6816 - iou_coef: 0.5297 - loss: 0.3184
# Epoch 41: val_dice_coef did not improve from 0.66102
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9596 - dice_coef: 0.6855 - iou_coef: 0.5330 - loss: 0.3145 - val_accuracy: 0.9428 - val_dice_coef: 0.6411 - val_iou_coef: 0.4912 - val_loss: 0.3638 - learning_rate: 2.5000e-05
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9624 - dice_coef: 0.7028 - iou_coef: 0.5533 - loss: 0.2972
# Epoch 42: val_dice_coef did not improve from 0.66102
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 304ms/step - accuracy: 0.9582 - dice_coef: 0.6767 - iou_coef: 0.5254 - loss: 0.3233 - val_accuracy: 0.9449 - val_dice_coef: 0.6514 - val_iou_coef: 0.5027 - val_loss: 0.3540 - learning_rate: 2.5000e-05
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9575 - dice_coef: 0.6963 - iou_coef: 0.5475 - loss: 0.3037
# Epoch 43: val_dice_coef improved from 0.66102 to 0.66787, saving model to best_unet.keras
#
# Epoch 43: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 314ms/step - accuracy: 0.9584 - dice_coef: 0.6800 - iou_coef: 0.5297 - loss: 0.3200 - val_accuracy: 0.9463 - val_dice_coef: 0.6679 - val_iou_coef: 0.5176 - val_loss: 0.3358 - learning_rate: 2.5000e-05
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9601 - dice_coef: 0.7129 - iou_coef: 0.5619 - loss: 0.2871
# Epoch 44: val_dice_coef did not improve from 0.66787
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 304ms/step - accuracy: 0.9588 - dice_coef: 0.6831 - iou_coef: 0.5289 - loss: 0.3169 - val_accuracy: 0.9455 - val_dice_coef: 0.6527 - val_iou_coef: 0.5042 - val_loss: 0.3525 - learning_rate: 2.5000e-05
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9577 - dice_coef: 0.6732 - iou_coef: 0.5201 - loss: 0.3268
# Epoch 45: val_dice_coef did not improve from 0.66787
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 295ms/step - accuracy: 0.9593 - dice_coef: 0.6827 - iou_coef: 0.5309 - loss: 0.3173 - val_accuracy: 0.9451 - val_dice_coef: 0.6523 - val_iou_coef: 0.5042 - val_loss: 0.3528 - learning_rate: 2.5000e-05
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9593 - dice_coef: 0.6842 - iou_coef: 0.5308 - loss: 0.3158
# Epoch 46: val_dice_coef improved from 0.66787 to 0.66957, saving model to best_unet.keras
#
# Epoch 46: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 315ms/step - accuracy: 0.9586 - dice_coef: 0.6693 - iou_coef: 0.5139 - loss: 0.3307 - val_accuracy: 0.9461 - val_dice_coef: 0.6696 - val_iou_coef: 0.5212 - val_loss: 0.3347 - learning_rate: 2.5000e-05
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9615 - dice_coef: 0.6722 - iou_coef: 0.5238 - loss: 0.3278
# Epoch 47: val_dice_coef did not improve from 0.66957
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.9600 - dice_coef: 0.6807 - iou_coef: 0.5316 - loss: 0.3193 - val_accuracy: 0.9423 - val_dice_coef: 0.6619 - val_iou_coef: 0.5115 - val_loss: 0.3417 - learning_rate: 2.5000e-05
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9582 - dice_coef: 0.6793 - iou_coef: 0.5326 - loss: 0.3207
# Epoch 48: val_dice_coef did not improve from 0.66957
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 305ms/step - accuracy: 0.9585 - dice_coef: 0.6791 - iou_coef: 0.5316 - loss: 0.3209 - val_accuracy: 0.9489 - val_dice_coef: 0.6660 - val_iou_coef: 0.5186 - val_loss: 0.3392 - learning_rate: 2.5000e-05
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9628 - dice_coef: 0.6817 - iou_coef: 0.5284 - loss: 0.3183
# Epoch 49: val_dice_coef did not improve from 0.66957
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 305ms/step - accuracy: 0.9596 - dice_coef: 0.6751 - iou_coef: 0.5215 - loss: 0.3249 - val_accuracy: 0.9487 - val_dice_coef: 0.6617 - val_iou_coef: 0.5150 - val_loss: 0.3438 - learning_rate: 2.5000e-05
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9581 - dice_coef: 0.6857 - iou_coef: 0.5338 - loss: 0.3143
# Epoch 50: val_dice_coef did not improve from 0.66957
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 293ms/step - accuracy: 0.9591 - dice_coef: 0.6781 - iou_coef: 0.5273 - loss: 0.3219 - val_accuracy: 0.9459 - val_dice_coef: 0.6621 - val_iou_coef: 0.5135 - val_loss: 0.3429 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 46.

# %%
show_prediction(model, val_pairs[8])
show_prediction(model, val_pairs[9])
show_prediction(model, val_pairs[79])
show_prediction(model, val_pairs[80])
