# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Research-study-on-UNET/blob/main/FixedKernel_unet(BUSI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
EPOCHS = 50
SEED = 42

ZIP_PATH = "/content/Dataset_BUSI_with_GT.zip"
EXTRACT_DIR = "/content/BUSI_DATASET"

import zipfile
from pathlib import Path

with zipfile.ZipFile(ZIP_PATH, "r") as z:
    z.extractall(EXTRACT_DIR)

def find_dataset_root(base_dir):
    for root, dirs, files in os.walk(base_dir):
        d = {x.lower() for x in dirs}
        if {"benign", "malignant", "normal"}.issubset(d):
            return root
    raise FileNotFoundError("Could not find benign/malignant/normal folders.")

DATASET_DIR = find_dataset_root(EXTRACT_DIR)

print("Dataset:", DATASET_DIR)

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Dataset: /content/BUSI_DATASET/Dataset_BUSI_with_GT

# %%
def get_pairs(dataset_dir):
    pairs = []

    for cls in ["benign", "malignant", "normal"]:
        folder = os.path.join(dataset_dir, cls)
        for f in sorted(os.listdir(folder)):
            path = os.path.join(folder, f)
            if not os.path.isfile(path):
                continue
            ext = Path(f).suffix.lower()
            if ext not in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]:
                continue
            stem = Path(f).stem
            if "_mask" in stem.lower():
                continue
            mask = os.path.join(folder, stem + "_mask.png")
            if os.path.exists(mask):
                pairs.append((path, mask))
            else:
                print("No mask:", path)

    return pairs


# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    if isinstance(img_path, bytes):
        img_path = img_path.decode()

    if isinstance(mask_path, bytes):
        mask_path = mask_path.decode()

    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")

    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(DATASET_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

labels = [Path(img).parent.name for img, mask in pairs]
train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED, stratify=labels)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))
# Out:
# Total paired samples: 780
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (1)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (10)_mask.png
#
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100).png
# /content/BUSI_DATASET/Dataset_BUSI_with_GT/benign/benign (100)_mask.png
#
# Train samples: 624
# Val samples: 156

# %%
# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np

# =========================================================
# LEARNABLE / FIXED-KERNEL STYLE EDGE LAYER
# =========================================================
@tf.keras.utils.register_keras_serializable()
class FixedKernelLayer(layers.Layer):
    """
    Fixed non-trainable kernel bank:
    - Sobel X
    - Sobel Y
    - Laplacian

    Input:  [B, H, W, C]
    Output: [B, H, W, 3C]
    """
    def __init__(self, **kwargs):
        super().__init__(trainable=False, **kwargs)

    def build(self, input_shape):
        c = int(input_shape[-1])

        sobel_x = np.array([
            [-1, 0, 1],
            [-2, 0, 2],
            [-1, 0, 1]
        ], dtype=np.float32)

        sobel_y = np.array([
            [-1, -2, -1],
            [ 0,  0,  0],
            [ 1,  2,  1]
        ], dtype=np.float32)

        laplacian = np.array([
            [ 0,  1,  0],
            [ 1, -4,  1],
            [ 0,  1,  0]
        ], dtype=np.float32)

        def make_depthwise_kernel(base_kernel):
            k = np.zeros((3, 3, c, 1), dtype=np.float32)
            for ch in range(c):
                k[:, :, ch, 0] = base_kernel
            return tf.constant(k)

        self.k_sobel_x = make_depthwise_kernel(sobel_x)
        self.k_sobel_y = make_depthwise_kernel(sobel_y)
        self.k_lap = make_depthwise_kernel(laplacian)

        super().build(input_shape)

    def call(self, x):
        sx = tf.nn.depthwise_conv2d(
            x, self.k_sobel_x, strides=[1, 1, 1, 1], padding="SAME"
        )
        sy = tf.nn.depthwise_conv2d(
            x, self.k_sobel_y, strides=[1, 1, 1, 1], padding="SAME"
        )
        lp = tf.nn.depthwise_conv2d(
            x, self.k_lap, strides=[1, 1, 1, 1], padding="SAME"
        )
        return tf.concat([sx, sy, lp], axis=-1)

    def get_config(self):
        config = super().get_config()
        return config


# =========================================================
# FIXED KERNEL BRANCH
# =========================================================
def fixed_kernel_block(x):
    x = FixedKernelLayer()(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def merge_with_fixed_kernels(feat, filters, prefix):
    """
    For a single skip tensor:
      original feature
      + fixed-kernel response of that feature
    Then concatenate and compress with 1x1 conv.
    """
    fk = FixedKernelLayer(name=f"{prefix}_fixed")(feat)
    x = layers.Concatenate(name=f"{prefix}_concat")([feat, fk])

    x = layers.Conv2D(
        filters,
        1,
        padding="same",
        kernel_initializer="he_normal",
        name=f"{prefix}_compress"
    )(x)
    x = layers.ReLU(name=f"{prefix}_compress_relu")(x)
    return x


# =========================================================
# U-NET BLOCKS
# =========================================================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p


def up_block(x, skip, skip_fixed, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip, skip_fixed])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x


# =========================================================
# BUILD MODEL
# =========================================================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1, p1 = down_block(inputs, 32)
    c2, p2 = down_block(p1, 64)
    c3, p3 = down_block(p2, 128)
    c4, p4 = down_block(p3, 256)

    # Fixed-kernel transformed skips
    c1_star = merge_with_fixed_kernels(c1, 32, "c1")
    c2_star = merge_with_fixed_kernels(c2, 64, "c2")
    c3_star = merge_with_fixed_kernels(c3, 128, "c3")
    c4_star = merge_with_fixed_kernels(c4, 256, "c4")

    # Bottleneck
    bottleneck = conv_block(p4, 512)

    # Decoder
    u1 = up_block(bottleneck, c4, c4_star, 256)
    u2 = up_block(u1, c3, c3_star, 128)
    u3 = up_block(u2, c2, c2_star, 64)
    u4 = up_block(u3, c1, c1_star, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary_FixedKernel")
    return model


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Model: "UNet_Binary_FixedKernel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ re_lu_8[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_fixed            │ (None, 32, 32,    │          0 │ re_lu_7[0][0]     │
# │ (FixedKernelLayer)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_concat           │ (None, 32, 32,    │          0 │ re_lu_7[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ c4_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress         │ (None, 32, 32,    │    262,400 │ c4_concat[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress_relu    │ (None, 32, 32,    │          0 │ c4_compress[0][0] │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ re_lu_7[0][0],    │
# │                     │                   │            │ c4_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ concatenate[0][0] │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,769,728 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_10[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_fixed            │ (None, 64, 64,    │          0 │ re_lu_5[0][0]     │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_concat           │ (None, 64, 64,    │          0 │ re_lu_5[0][0],    │
# │ (Concatenate)       │ 512)              │            │ c3_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress         │ (None, 64, 64,    │     65,664 │ c3_concat[0][0]   │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ re_lu_11[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress_relu    │ (None, 64, 64,    │          0 │ c3_compress[0][0] │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 384)              │            │ re_lu_5[0][0],    │
# │                     │                   │            │ c3_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_1[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    442,496 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_fixed            │ (None, 128, 128,  │          0 │ re_lu_3[0][0]     │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_concat           │ (None, 128, 128,  │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 256)              │            │ c2_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress         │ (None, 128, 128,  │     16,448 │ c2_concat[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ re_lu_13[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress_relu    │ (None, 128, 128,  │          0 │ c2_compress[0][0] │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 192)              │            │ re_lu_3[0][0],    │
# │                     │                   │            │ c2_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_2[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    110,656 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_14[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_fixed            │ (None, 256, 256,  │          0 │ re_lu_1[0][0]     │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_concat           │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 128)              │            │ c1_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress         │ (None, 256, 256,  │      4,128 │ c1_concat[0][0]   │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ re_lu_15[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress_relu    │ (None, 256, 256,  │          0 │ c1_compress[0][0] │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 96)               │            │ re_lu_1[0][0],    │
# │                     │                   │            │ c1_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ concatenate_3[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     27,680 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_16[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ re_lu_17[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,903,873 (33.97 MB)
#  Trainable params: 8,897,985 (33.94 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.6664 - dice_coef: 0.1328 - iou_coef: 0.0718 - loss: 0.8672
# Epoch 1: val_dice_coef improved from None to 0.20854, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 106s 520ms/step - accuracy: 0.6078 - dice_coef: 0.1541 - iou_coef: 0.0849 - loss: 0.8459 - val_accuracy: 0.5394 - val_dice_coef: 0.2085 - val_iou_coef: 0.1183 - val_loss: 0.7915 - learning_rate: 1.0000e-04
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.7758 - dice_coef: 0.2483 - iou_coef: 0.1446 - loss: 0.7517
# Epoch 2: val_dice_coef improved from 0.20854 to 0.27714, saving model to best_unet.keras
#
# Epoch 2: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - accuracy: 0.8003 - dice_coef: 0.2692 - iou_coef: 0.1590 - loss: 0.7308 - val_accuracy: 0.7953 - val_dice_coef: 0.2771 - val_iou_coef: 0.1648 - val_loss: 0.7220 - learning_rate: 1.0000e-04
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8068 - dice_coef: 0.2763 - iou_coef: 0.1641 - loss: 0.7237
# Epoch 3: val_dice_coef improved from 0.27714 to 0.33686, saving model to best_unet.keras
#
# Epoch 3: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 290ms/step - accuracy: 0.8255 - dice_coef: 0.3031 - iou_coef: 0.1834 - loss: 0.6969 - val_accuracy: 0.8411 - val_dice_coef: 0.3369 - val_iou_coef: 0.2063 - val_loss: 0.6638 - learning_rate: 1.0000e-04
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8637 - dice_coef: 0.3496 - iou_coef: 0.2173 - loss: 0.6504
# Epoch 4: val_dice_coef improved from 0.33686 to 0.39177, saving model to best_unet.keras
#
# Epoch 4: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 284ms/step - accuracy: 0.8735 - dice_coef: 0.3435 - iou_coef: 0.2127 - loss: 0.6565 - val_accuracy: 0.8866 - val_dice_coef: 0.3918 - val_iou_coef: 0.2505 - val_loss: 0.6093 - learning_rate: 1.0000e-04
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9070 - dice_coef: 0.3816 - iou_coef: 0.2393 - loss: 0.6184
# Epoch 5: val_dice_coef improved from 0.39177 to 0.45235, saving model to best_unet.keras
#
# Epoch 5: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 42s 301ms/step - accuracy: 0.9018 - dice_coef: 0.3881 - iou_coef: 0.2456 - loss: 0.6119 - val_accuracy: 0.9016 - val_dice_coef: 0.4523 - val_iou_coef: 0.3012 - val_loss: 0.5504 - learning_rate: 1.0000e-04
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9016 - dice_coef: 0.3879 - iou_coef: 0.2465 - loss: 0.6121
# Epoch 6: val_dice_coef improved from 0.45235 to 0.46319, saving model to best_unet.keras
#
# Epoch 6: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 40s 294ms/step - accuracy: 0.9065 - dice_coef: 0.3934 - iou_coef: 0.2523 - loss: 0.6066 - val_accuracy: 0.9081 - val_dice_coef: 0.4632 - val_iou_coef: 0.3118 - val_loss: 0.5395 - learning_rate: 1.0000e-04
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9156 - dice_coef: 0.4101 - iou_coef: 0.2665 - loss: 0.5899
# Epoch 7: val_dice_coef did not improve from 0.46319
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 297ms/step - accuracy: 0.9175 - dice_coef: 0.4180 - iou_coef: 0.2707 - loss: 0.5820 - val_accuracy: 0.8736 - val_dice_coef: 0.4551 - val_iou_coef: 0.3038 - val_loss: 0.5473 - learning_rate: 1.0000e-04
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9236 - dice_coef: 0.4470 - iou_coef: 0.2938 - loss: 0.5530
# Epoch 8: val_dice_coef improved from 0.46319 to 0.50734, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 309ms/step - accuracy: 0.9225 - dice_coef: 0.4478 - iou_coef: 0.2954 - loss: 0.5522 - val_accuracy: 0.9113 - val_dice_coef: 0.5073 - val_iou_coef: 0.3503 - val_loss: 0.4945 - learning_rate: 1.0000e-04
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9188 - dice_coef: 0.4724 - iou_coef: 0.3162 - loss: 0.5276
# Epoch 9: val_dice_coef did not improve from 0.50734
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 296ms/step - accuracy: 0.9253 - dice_coef: 0.4644 - iou_coef: 0.3098 - loss: 0.5356 - val_accuracy: 0.9323 - val_dice_coef: 0.4077 - val_iou_coef: 0.2695 - val_loss: 0.5982 - learning_rate: 1.0000e-04
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9319 - dice_coef: 0.5015 - iou_coef: 0.3425 - loss: 0.4985
# Epoch 10: val_dice_coef improved from 0.50734 to 0.53479, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 310ms/step - accuracy: 0.9284 - dice_coef: 0.4795 - iou_coef: 0.3246 - loss: 0.5205 - val_accuracy: 0.9301 - val_dice_coef: 0.5348 - val_iou_coef: 0.3758 - val_loss: 0.4702 - learning_rate: 1.0000e-04
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9317 - dice_coef: 0.4935 - iou_coef: 0.3366 - loss: 0.5065
# Epoch 11: val_dice_coef did not improve from 0.53479
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 300ms/step - accuracy: 0.9331 - dice_coef: 0.4907 - iou_coef: 0.3339 - loss: 0.5093 - val_accuracy: 0.9386 - val_dice_coef: 0.4863 - val_iou_coef: 0.3386 - val_loss: 0.5219 - learning_rate: 1.0000e-04
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9381 - dice_coef: 0.5071 - iou_coef: 0.3503 - loss: 0.4929
# Epoch 12: val_dice_coef improved from 0.53479 to 0.55557, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 311ms/step - accuracy: 0.9367 - dice_coef: 0.5102 - iou_coef: 0.3528 - loss: 0.4898 - val_accuracy: 0.9343 - val_dice_coef: 0.5556 - val_iou_coef: 0.3986 - val_loss: 0.4503 - learning_rate: 1.0000e-04
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9281 - dice_coef: 0.5268 - iou_coef: 0.3679 - loss: 0.4732
# Epoch 13: val_dice_coef did not improve from 0.55557
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 289ms/step - accuracy: 0.9352 - dice_coef: 0.5236 - iou_coef: 0.3639 - loss: 0.4764 - val_accuracy: 0.9371 - val_dice_coef: 0.5444 - val_iou_coef: 0.3896 - val_loss: 0.4607 - learning_rate: 1.0000e-04
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9408 - dice_coef: 0.5327 - iou_coef: 0.3710 - loss: 0.4673
# Epoch 14: val_dice_coef did not improve from 0.55557
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 288ms/step - accuracy: 0.9414 - dice_coef: 0.5359 - iou_coef: 0.3753 - loss: 0.4641 - val_accuracy: 0.9135 - val_dice_coef: 0.5394 - val_iou_coef: 0.3811 - val_loss: 0.4631 - learning_rate: 1.0000e-04
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9469 - dice_coef: 0.5702 - iou_coef: 0.4071 - loss: 0.4298
# Epoch 15: val_dice_coef did not improve from 0.55557
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 286ms/step - accuracy: 0.9439 - dice_coef: 0.5652 - iou_coef: 0.4026 - loss: 0.4348 - val_accuracy: 0.9301 - val_dice_coef: 0.5348 - val_iou_coef: 0.3846 - val_loss: 0.4714 - learning_rate: 1.0000e-04
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9448 - dice_coef: 0.5391 - iou_coef: 0.3812 - loss: 0.4609
# Epoch 16: val_dice_coef improved from 0.55557 to 0.57110, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 309ms/step - accuracy: 0.9425 - dice_coef: 0.5470 - iou_coef: 0.3869 - loss: 0.4530 - val_accuracy: 0.9426 - val_dice_coef: 0.5711 - val_iou_coef: 0.4208 - val_loss: 0.4349 - learning_rate: 1.0000e-04
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9448 - dice_coef: 0.5449 - iou_coef: 0.3842 - loss: 0.4551
# Epoch 17: val_dice_coef did not improve from 0.57110
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 300ms/step - accuracy: 0.9450 - dice_coef: 0.5636 - iou_coef: 0.4030 - loss: 0.4364 - val_accuracy: 0.9096 - val_dice_coef: 0.5398 - val_iou_coef: 0.3861 - val_loss: 0.4658 - learning_rate: 1.0000e-04
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9468 - dice_coef: 0.5899 - iou_coef: 0.4248 - loss: 0.4101
# Epoch 18: val_dice_coef improved from 0.57110 to 0.58528, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 25s 313ms/step - accuracy: 0.9480 - dice_coef: 0.5858 - iou_coef: 0.4213 - loss: 0.4142 - val_accuracy: 0.9306 - val_dice_coef: 0.5853 - val_iou_coef: 0.4269 - val_loss: 0.4184 - learning_rate: 1.0000e-04
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9454 - dice_coef: 0.5534 - iou_coef: 0.3967 - loss: 0.4466
# Epoch 19: val_dice_coef did not improve from 0.58528
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 287ms/step - accuracy: 0.9454 - dice_coef: 0.5712 - iou_coef: 0.4119 - loss: 0.4288 - val_accuracy: 0.8908 - val_dice_coef: 0.4995 - val_iou_coef: 0.3449 - val_loss: 0.5045 - learning_rate: 1.0000e-04
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9497 - dice_coef: 0.6014 - iou_coef: 0.4376 - loss: 0.3986
# Epoch 20: val_dice_coef did not improve from 0.58528
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 288ms/step - accuracy: 0.9470 - dice_coef: 0.5932 - iou_coef: 0.4306 - loss: 0.4068 - val_accuracy: 0.9203 - val_dice_coef: 0.5770 - val_iou_coef: 0.4201 - val_loss: 0.4266 - learning_rate: 1.0000e-04
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9470 - dice_coef: 0.5834 - iou_coef: 0.4239 - loss: 0.4166
# Epoch 21: val_dice_coef did not improve from 0.58528
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 301ms/step - accuracy: 0.9474 - dice_coef: 0.5854 - iou_coef: 0.4248 - loss: 0.4146 - val_accuracy: 0.9201 - val_dice_coef: 0.5700 - val_iou_coef: 0.4139 - val_loss: 0.4352 - learning_rate: 1.0000e-04
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9391 - dice_coef: 0.5681 - iou_coef: 0.4103 - loss: 0.4319
# Epoch 22: val_dice_coef did not improve from 0.58528
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 299ms/step - accuracy: 0.9466 - dice_coef: 0.5972 - iou_coef: 0.4393 - loss: 0.4028 - val_accuracy: 0.9188 - val_dice_coef: 0.5552 - val_iou_coef: 0.4011 - val_loss: 0.4496 - learning_rate: 1.0000e-04
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9514 - dice_coef: 0.6028 - iou_coef: 0.4452 - loss: 0.3972
# Epoch 23: val_dice_coef improved from 0.58528 to 0.59260, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 299ms/step - accuracy: 0.9523 - dice_coef: 0.6196 - iou_coef: 0.4604 - loss: 0.3804 - val_accuracy: 0.9389 - val_dice_coef: 0.5926 - val_iou_coef: 0.4414 - val_loss: 0.4147 - learning_rate: 5.0000e-05
# Epoch 24/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9589 - dice_coef: 0.6653 - iou_coef: 0.5083 - loss: 0.3347
# Epoch 24: val_dice_coef did not improve from 0.59260
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 288ms/step - accuracy: 0.9535 - dice_coef: 0.6307 - iou_coef: 0.4750 - loss: 0.3693 - val_accuracy: 0.9271 - val_dice_coef: 0.5799 - val_iou_coef: 0.4265 - val_loss: 0.4249 - learning_rate: 5.0000e-05
# Epoch 25/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9553 - dice_coef: 0.6477 - iou_coef: 0.4876 - loss: 0.3523
# Epoch 25: val_dice_coef improved from 0.59260 to 0.63078, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 299ms/step - accuracy: 0.9533 - dice_coef: 0.6311 - iou_coef: 0.4707 - loss: 0.3689 - val_accuracy: 0.9435 - val_dice_coef: 0.6308 - val_iou_coef: 0.4804 - val_loss: 0.3750 - learning_rate: 5.0000e-05
# Epoch 26/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9491 - dice_coef: 0.6192 - iou_coef: 0.4608 - loss: 0.3808
# Epoch 26: val_dice_coef did not improve from 0.63078
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 287ms/step - accuracy: 0.9521 - dice_coef: 0.6147 - iou_coef: 0.4551 - loss: 0.3853 - val_accuracy: 0.9412 - val_dice_coef: 0.6257 - val_iou_coef: 0.4737 - val_loss: 0.3794 - learning_rate: 5.0000e-05
# Epoch 27/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9524 - dice_coef: 0.6249 - iou_coef: 0.4648 - loss: 0.3751
# Epoch 27: val_dice_coef did not improve from 0.63078
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 295ms/step - accuracy: 0.9528 - dice_coef: 0.6280 - iou_coef: 0.4691 - loss: 0.3720 - val_accuracy: 0.9395 - val_dice_coef: 0.6201 - val_iou_coef: 0.4668 - val_loss: 0.3847 - learning_rate: 5.0000e-05
# Epoch 28/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9519 - dice_coef: 0.5970 - iou_coef: 0.4426 - loss: 0.4030
# Epoch 28: val_dice_coef did not improve from 0.63078
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 22s 286ms/step - accuracy: 0.9517 - dice_coef: 0.6197 - iou_coef: 0.4615 - loss: 0.3803 - val_accuracy: 0.9335 - val_dice_coef: 0.6053 - val_iou_coef: 0.4532 - val_loss: 0.4005 - learning_rate: 5.0000e-05
# Epoch 29/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9550 - dice_coef: 0.6370 - iou_coef: 0.4831 - loss: 0.3630
# Epoch 29: val_dice_coef did not improve from 0.63078
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 299ms/step - accuracy: 0.9534 - dice_coef: 0.6317 - iou_coef: 0.4756 - loss: 0.3683 - val_accuracy: 0.9349 - val_dice_coef: 0.6084 - val_iou_coef: 0.4576 - val_loss: 0.3974 - learning_rate: 5.0000e-05
# Epoch 30/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9514 - dice_coef: 0.6208 - iou_coef: 0.4668 - loss: 0.3792
# Epoch 30: val_dice_coef did not improve from 0.63078
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 299ms/step - accuracy: 0.9519 - dice_coef: 0.6243 - iou_coef: 0.4726 - loss: 0.3757 - val_accuracy: 0.9449 - val_dice_coef: 0.6298 - val_iou_coef: 0.4817 - val_loss: 0.3764 - learning_rate: 2.5000e-05
# Epoch 31/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9547 - dice_coef: 0.6182 - iou_coef: 0.4596 - loss: 0.3818
# Epoch 31: val_dice_coef improved from 0.63078 to 0.63290, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 310ms/step - accuracy: 0.9530 - dice_coef: 0.6214 - iou_coef: 0.4649 - loss: 0.3786 - val_accuracy: 0.9429 - val_dice_coef: 0.6329 - val_iou_coef: 0.4833 - val_loss: 0.3731 - learning_rate: 2.5000e-05
# Epoch 32/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9540 - dice_coef: 0.6408 - iou_coef: 0.4869 - loss: 0.3592
# Epoch 32: val_dice_coef improved from 0.63290 to 0.63861, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 296ms/step - accuracy: 0.9548 - dice_coef: 0.6416 - iou_coef: 0.4891 - loss: 0.3584 - val_accuracy: 0.9448 - val_dice_coef: 0.6386 - val_iou_coef: 0.4899 - val_loss: 0.3668 - learning_rate: 2.5000e-05
# Epoch 33/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9584 - dice_coef: 0.6650 - iou_coef: 0.5095 - loss: 0.3350
# Epoch 33: val_dice_coef did not improve from 0.63861
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 295ms/step - accuracy: 0.9560 - dice_coef: 0.6525 - iou_coef: 0.4967 - loss: 0.3475 - val_accuracy: 0.9435 - val_dice_coef: 0.6338 - val_iou_coef: 0.4847 - val_loss: 0.3711 - learning_rate: 2.5000e-05
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9557 - dice_coef: 0.6415 - iou_coef: 0.4839 - loss: 0.3585
# Epoch 34: val_dice_coef improved from 0.63861 to 0.64368, saving model to best_unet.keras
#
# Epoch 34: finished saving model to best_unet.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 299ms/step - accuracy: 0.9576 - dice_coef: 0.6708 - iou_coef: 0.5145 - loss: 0.3292 - val_accuracy: 0.9455 - val_dice_coef: 0.6437 - val_iou_coef: 0.4953 - val_loss: 0.3617 - learning_rate: 2.5000e-05
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9605 - dice_coef: 0.6710 - iou_coef: 0.5172 - loss: 0.3290
# Epoch 35: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 289ms/step - accuracy: 0.9570 - dice_coef: 0.6511 - iou_coef: 0.4949 - loss: 0.3489 - val_accuracy: 0.9454 - val_dice_coef: 0.6369 - val_iou_coef: 0.4889 - val_loss: 0.3690 - learning_rate: 2.5000e-05
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9578 - dice_coef: 0.6820 - iou_coef: 0.5281 - loss: 0.3180
# Epoch 36: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 290ms/step - accuracy: 0.9559 - dice_coef: 0.6596 - iou_coef: 0.5065 - loss: 0.3404 - val_accuracy: 0.9449 - val_dice_coef: 0.6323 - val_iou_coef: 0.4844 - val_loss: 0.3739 - learning_rate: 2.5000e-05
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9564 - dice_coef: 0.6477 - iou_coef: 0.4905 - loss: 0.3523
# Epoch 37: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 288ms/step - accuracy: 0.9574 - dice_coef: 0.6608 - iou_coef: 0.5043 - loss: 0.3392 - val_accuracy: 0.9459 - val_dice_coef: 0.6306 - val_iou_coef: 0.4828 - val_loss: 0.3756 - learning_rate: 2.5000e-05
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9569 - dice_coef: 0.6496 - iou_coef: 0.4947 - loss: 0.3504
# Epoch 38: val_dice_coef did not improve from 0.64368
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 300ms/step - accuracy: 0.9573 - dice_coef: 0.6587 - iou_coef: 0.5036 - loss: 0.3413 - val_accuracy: 0.9448 - val_dice_coef: 0.6255 - val_iou_coef: 0.4778 - val_loss: 0.3807 - learning_rate: 2.5000e-05
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9609 - dice_coef: 0.6586 - iou_coef: 0.5056 - loss: 0.3414
# Epoch 39: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 287ms/step - accuracy: 0.9573 - dice_coef: 0.6554 - iou_coef: 0.5011 - loss: 0.3446 - val_accuracy: 0.9435 - val_dice_coef: 0.6370 - val_iou_coef: 0.4876 - val_loss: 0.3680 - learning_rate: 1.2500e-05
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9550 - dice_coef: 0.6559 - iou_coef: 0.5081 - loss: 0.3441
# Epoch 40: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 299ms/step - accuracy: 0.9568 - dice_coef: 0.6590 - iou_coef: 0.5082 - loss: 0.3410 - val_accuracy: 0.9449 - val_dice_coef: 0.6355 - val_iou_coef: 0.4874 - val_loss: 0.3700 - learning_rate: 1.2500e-05
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9586 - dice_coef: 0.6724 - iou_coef: 0.5179 - loss: 0.3276
# Epoch 41: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 300ms/step - accuracy: 0.9589 - dice_coef: 0.6743 - iou_coef: 0.5199 - loss: 0.3257 - val_accuracy: 0.9451 - val_dice_coef: 0.6411 - val_iou_coef: 0.4925 - val_loss: 0.3642 - learning_rate: 1.2500e-05
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9630 - dice_coef: 0.7021 - iou_coef: 0.5510 - loss: 0.2979
# Epoch 42: val_dice_coef did not improve from 0.64368
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 301ms/step - accuracy: 0.9590 - dice_coef: 0.6754 - iou_coef: 0.5230 - loss: 0.3246 - val_accuracy: 0.9434 - val_dice_coef: 0.6280 - val_iou_coef: 0.4800 - val_loss: 0.3780 - learning_rate: 1.2500e-05
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9573 - dice_coef: 0.6895 - iou_coef: 0.5398 - loss: 0.3105
# Epoch 43: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 293ms/step - accuracy: 0.9584 - dice_coef: 0.6743 - iou_coef: 0.5234 - loss: 0.3257 - val_accuracy: 0.9445 - val_dice_coef: 0.6362 - val_iou_coef: 0.4878 - val_loss: 0.3694 - learning_rate: 6.2500e-06
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9608 - dice_coef: 0.7092 - iou_coef: 0.5577 - loss: 0.2908
# Epoch 44: val_dice_coef did not improve from 0.64368
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 23s 287ms/step - accuracy: 0.9589 - dice_coef: 0.6759 - iou_coef: 0.5207 - loss: 0.3241 - val_accuracy: 0.9432 - val_dice_coef: 0.6321 - val_iou_coef: 0.4833 - val_loss: 0.3733 - learning_rate: 6.2500e-06
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.

# %%
show_prediction(model, val_pairs[8])
show_prediction(model, val_pairs[9])
show_prediction(model, val_pairs[79])
show_prediction(model, val_pairs[80])
